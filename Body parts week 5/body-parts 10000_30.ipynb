# %%
from numpy.random import normal
from math import sqrt
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch
import torchvision.transforms as transforms
import os
from torch.autograd import Variable
import torch.utils.data as Data
from torch.utils.data import Dataset
from PIL import Image, ImageChops
import matplotlib.pyplot as plt
import torchvision
import warnings
torch.set_default_tensor_type(torch.FloatTensor)
import copy
import random
warnings.filterwarnings("ignore")

# %%
def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    torch.backends.cudnn.deterministic = True
    random.seed(seed)
# 设置随机数种子
setup_seed(20)

# %%
def make_txt_file(path):
    
    # Classes: train, eval, test
    img_path=os.path.join(path,'TrainVal_images')
    label_path=os.path.join(path,'TrainVal_parsing_annotations')
    train_data=open('train.txt', 'w')
    eval_data=open('eval.txt','w')
    test_data=open('test.txt','w')
    train_data.truncate()
    eval_data.truncate()
    test_data.truncate()
    train_id=open(os.path.join(path,'train_id.txt'))
    val_id=open(os.path.join(path,'val_id.txt'))
    
    train_data_path=os.path.join(img_path,'train_images')
    val_data_path=os.path.join(img_path,'val_images')
    train_label_path=os.path.join(label_path,'train_segmentations')
    val_label_path=os.path.join(label_path,'val_segmentations')
    
    lines=train_id.readlines()
    count=0
    for line in lines:
        line=line.strip()
        name=os.path.join(train_data_path,line+'.jpg')+'*'+os.path.join(train_label_path,line+'.png')+'\n'
        train_data.write(name)
        count+=1
        if count>=10000:
            break
    train_data.close()
    train_id.close()
    
    lines=val_id.readlines()
    s=0
    count=0
    for line in lines:
        line=line.strip()
        name=os.path.join(val_data_path,line+'.jpg')+'*'+os.path.join(val_label_path,line+'.png')+'\n'
        if s%2==0:
            eval_data.write(name)
        else:
            test_data.write(name)
        s+=1
        
        count+=1
        if count>=2000:
            break
            
    val_id.close() 
    eval_data.close()
    test_data.close()

# %%
class MyDataSet(Dataset):
    def __init__(self, dataset_type, transform=None,update_dataset=False):
        """
        dataset_type: [train, eval, test]
        """
 
        dataset_path = '/kaggle/input/pil-data/LIP'

        read_path=''
 
        if update_dataset:
            make_txt_file(dataset_path) 
 
        self.transform = transform
        self.sample_list = list()
        self.dataset_type = dataset_type
        f = open(os.path.join(read_path , self.dataset_type + '.txt'))
        lines = f.readlines()
        for line in lines:
            self.sample_list.append(line.strip())
        f.close()
 
    def __getitem__(self, index):
        item = self.sample_list[index]
        img = Image.open(item.split('*')[0]).convert('RGB')       
        label = Image.open(item.split('*')[1]).convert('L')
        
        if self.transform is not None:
            img,label = self.transform(img,label)
           
        return img, label
 
    def __len__(self):
        return len(self.sample_list)

# %%
def train_transform(data,label):
    data=transforms.functional.pad(data,padding=((max(data.size)-data.size[0])//2,(max(data.size)-data.size[1])//2))
    label=transforms.functional.pad(label,padding=((max(label.size)-label.size[0])//2,(max(label.size)-label.size[1])//2))
    data=transforms.functional.resize(data,(256,256))
    label=transforms.functional.resize(label,(256,256))   
   

    data=transforms.functional.to_tensor(data).float()
    
    label=np.array(label,dtype='int64')
    label=torch.from_numpy(label)
    return data,label

def test_transfrom(data,label):
    data=transforms.functional.resize(data,(256,256))
    label=transforms.functional.resize(label,(256,256))
    data=transforms.functional.to_tensor(data).float()

    label=np.array(label,dtype='int64')
    label=torch.from_numpy(label)
    return data,label

# %%
train_data=MyDataSet('train',transform=train_transform,update_dataset=True)
eval_data=MyDataSet('eval',test_transfrom)
num_train=train_data.__len__()
num_eval=eval_data.__len__()

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3,padding=1),
            nn.BatchNorm2d(out_ch), 
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3,padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )
 
    def forward(self, input):        
        return self.conv(input)

# %%
class UNet(nn.Module):
    def __init__(self,colordim =1):
        super(UNet, self).__init__()
        self.conv1=DoubleConv(3,64)
        self.conv2=DoubleConv(64,128)
        self.conv3=DoubleConv(128,256)
        self.conv4=DoubleConv(256,512)
        
        self.conv5=DoubleConv(512,1024)
        self.upconv5=nn.Conv2d(1024, 512, 1)
        
        self.conv6=DoubleConv(1024,512)
        self.upconv6=nn.Conv2d(512, 256, 1)
        self.conv7=DoubleConv(512,256)
        self.upconv7=nn.Conv2d(256,128, 1)
        self.conv8=DoubleConv(256,128)
        self.upconv8=nn.Conv2d(128,64, 1)
        self.conv9=DoubleConv(128,64)
        
        self.maxpool=nn.MaxPool2d(2, stride=2)
        self.upsample = nn.UpsamplingBilinear2d(scale_factor=2)

        self.output=nn.Sequential(
            nn.Conv2d(64, colordim, 1),
#             nn.Tanh()
        )
        self._initialize_weights()
    
    def forward(self, x):
        x1=self.conv1(x)
        x2=self.conv2(self.maxpool(x1))
        x3=self.conv3(self.maxpool(x2))
        x4=self.conv4(self.maxpool(x3))
        upx=self.conv5(self.maxpool(x4))
        
        upx=self.upconv5(self.upsample(upx))     

        upx=self.conv6(torch.cat((x4, upx), 1))
        upx=self.upconv6(self.upsample(upx))   

        upx=self.conv7(torch.cat((x3, upx), 1))
        upx=self.upconv7(self.upsample(upx))  

        upx=self.conv8(torch.cat((x2, upx), 1))
        upx=self.upconv8(self.upsample(upx)) 

        upx=self.conv9(torch.cat((x1, upx), 1))
        upx=self.output(upx)
        
        return upx
        
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
unet = UNet(colordim=20).cuda()

# %%
EPOCH = 30
BATCH_SIZE=32
LR=0.001

optimizer=torch.optim.Adam(unet.parameters(),lr=LR)
scheduler=torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, 
    verbose=True, threshold=0.0001, threshold_mode='rel', cooldown=2, min_lr=1e-08, eps=1e-08)
#weights=torch.ones(20)
#weights[0]=0.1
#loss_func=nn.CrossEntropyLoss(weight=weights).cuda()
loss_func=nn.CrossEntropyLoss()



train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)

# %%
def mIoUAcc(inputs, targets,numclass=20, smooth=1):
   
    inputs = inputs.cpu().detach()
    targets = targets.cpu().detach().view(-1)      
    inputs=torch.softmax(inputs,dim=1)
    IoU=[]
    for i in range(numclass):        
        pre=torch.tensor(inputs[:,i,:,:]).view(-1)
        target=targets==i
        intersection = (pre * target).sum().numpy()
        total = (pre + target).sum().numpy()
        union = total - intersection         
        IoU.append((intersection + smooth)/(union + smooth))
    return np.mean(IoU)

# %%
train_losses=[]
eval_losses=[]
train_accs=[]
eval_accs=[]


for epoch in range(EPOCH):
    print('Epoch: %4s'%epoch)
    

    batch_loss=0
    acc=0
    unet.train()  
    
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=unet(b_x)   
        loss=loss_func(output,b_y)
        batch_loss+=loss.data*b_y.size(0)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step() 
        torch.cuda.empty_cache() 
        acc+=mIoUAcc(output,b_y)*b_y.size(0)

    train_loss=batch_loss/num_train
    train_acc=acc/num_train
    
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    scheduler.step(train_loss) 
    
    print('| train loss: ',train_loss,'| train accuracy: ',train_acc)
    
    
    
    with torch.no_grad():
        unet.eval()         
        acc=0
        batch_loss=0
        for step,(x,y) in enumerate(eval_loader):
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()    
            output=unet(b_x) 
            batch_loss+=loss_func(output,b_y).data*b_y.size(0)            
            torch.cuda.empty_cache()   
            acc+=mIoUAcc(output,b_y)*b_y.size(0)

        eval_loss=batch_loss/num_eval
        eval_acc=acc/num_eval
        eval_losses.append(eval_loss)
        eval_accs.append(eval_acc)

    
    print('| eval loss: ',eval_loss,'| eval accuracy: ',eval_acc)
# Out:
# Epoch:    0
# | train loss:  tensor(0.9995, device='cuda:0') | train accuracy:  0.06328102158265975
# | eval loss:  tensor(1.5963, device='cuda:0') | eval accuracy:  0.05142533162779491
# Epoch:    1
# | train loss:  tensor(0.8846, device='cuda:0') | train accuracy:  0.08009712254351094
# | eval loss:  tensor(1.4597, device='cuda:0') | eval accuracy:  0.06032201241248151
# Epoch:    2
# | train loss:  tensor(0.8290, device='cuda:0') | train accuracy:  0.09356718413016317
# | eval loss:  tensor(1.3621, device='cuda:0') | eval accuracy:  0.07607078907154165
# Epoch:    3
# | train loss:  tensor(0.7790, device='cuda:0') | train accuracy:  0.10718007326311517
# | eval loss:  tensor(1.3447, device='cuda:0') | eval accuracy:  0.0788045070692181
# Epoch:    4
# | train loss:  tensor(0.7429, device='cuda:0') | train accuracy:  0.11754821428919252
# | eval loss:  tensor(1.1966, device='cuda:0') | eval accuracy:  0.10055259436678812
# Epoch:    5
# | train loss:  tensor(0.7047, device='cuda:0') | train accuracy:  0.1281987433477513
# | eval loss:  tensor(1.1238, device='cuda:0') | eval accuracy:  0.10788175492450326
# Epoch:    6
# | train loss:  tensor(0.6767, device='cuda:0') | train accuracy:  0.1371165640137057
# | eval loss:  tensor(1.0758, device='cuda:0') | eval accuracy:  0.115185341596877
# Epoch:    7
# | train loss:  tensor(0.6538, device='cuda:0') | train accuracy:  0.1445365807406343
# | eval loss:  tensor(1.1080, device='cuda:0') | eval accuracy:  0.1134073336833742
# Epoch:    8
# | train loss:  tensor(0.6357, device='cuda:0') | train accuracy:  0.15100974705410905
# | eval loss:  tensor(1.0925, device='cuda:0') | eval accuracy:  0.12245988580483391
# Epoch:    9
# | train loss:  tensor(0.6141, device='cuda:0') | train accuracy:  0.15825781816782197
# | eval loss:  tensor(1.0448, device='cuda:0') | eval accuracy:  0.12819088408608423
# Epoch:   10
# | train loss:  tensor(0.5944, device='cuda:0') | train accuracy:  0.16572804984132697
# | eval loss:  tensor(1.0165, device='cuda:0') | eval accuracy:  0.13883648107307192
# Epoch:   11
# | train loss:  tensor(0.5752, device='cuda:0') | train accuracy:  0.1737587122375999
# | eval loss:  tensor(1.0947, device='cuda:0') | eval accuracy:  0.12052136042629986
# Epoch:   12
# | train loss:  tensor(0.5610, device='cuda:0') | train accuracy:  0.17962541600996404
# | eval loss:  tensor(1.0445, device='cuda:0') | eval accuracy:  0.13376754761016094
# Epoch:   13
# | train loss:  tensor(0.5382, device='cuda:0') | train accuracy:  0.187582279028875
# | eval loss:  tensor(1.0914, device='cuda:0') | eval accuracy:  0.1416284884198007
# Epoch:   14
# | train loss:  tensor(0.5179, device='cuda:0') | train accuracy:  0.19697812280890492
# | eval loss:  tensor(0.9918, device='cuda:0') | eval accuracy:  0.15091735497532902
# Epoch:   15
# | train loss:  tensor(0.5002, device='cuda:0') | train accuracy:  0.20374582464817148
# | eval loss:  tensor(1.0427, device='cuda:0') | eval accuracy:  0.1506608674986473
# Epoch:   16
# | train loss:  tensor(0.4752, device='cuda:0') | train accuracy:  0.21508981184639855
# | eval loss:  tensor(1.0491, device='cuda:0') | eval accuracy:  0.14792353997535454
# Epoch:   17
# | train loss:  tensor(0.4481, device='cuda:0') | train accuracy:  0.22797830034642183
# | eval loss:  tensor(1.0903, device='cuda:0') | eval accuracy:  0.1567933381817517
# Epoch:   18
# | train loss:  tensor(0.4173, device='cuda:0') | train accuracy:  0.24298467955163186
# | eval loss:  tensor(1.1054, device='cuda:0') | eval accuracy:  0.15457282847885068
# Epoch:   19
# | train loss:  tensor(0.3912, device='cuda:0') | train accuracy:  0.25665205771212063
# | eval loss:  tensor(1.1378, device='cuda:0') | eval accuracy:  0.16197040723708814
# Epoch:   20
# | train loss:  tensor(0.3571, device='cuda:0') | train accuracy:  0.27731557318313077
# | eval loss:  tensor(1.0987, device='cuda:0') | eval accuracy:  0.16797625129402222
# Epoch:   21
# | train loss:  tensor(0.3232, device='cuda:0') | train accuracy:  0.2986576190480912
# | eval loss:  tensor(1.2524, device='cuda:0') | eval accuracy:  0.16653479909161895
# Epoch:   22
# | train loss:  tensor(0.2987, device='cuda:0') | train accuracy:  0.3169266132854301
# | eval loss:  tensor(1.2280, device='cuda:0') | eval accuracy:  0.17732956479815248
# Epoch:   23
# | train loss:  tensor(0.2687, device='cuda:0') | train accuracy:  0.34175036494511607
# | eval loss:  tensor(1.3037, device='cuda:0') | eval accuracy:  0.17450272360632424
# Epoch:   24
# | train loss:  tensor(0.2508, device='cuda:0') | train accuracy:  0.35988149815303005
# | eval loss:  tensor(1.3042, device='cuda:0') | eval accuracy:  0.17578515165331307
# Epoch:   25
# | train loss:  tensor(0.2343, device='cuda:0') | train accuracy:  0.37852596617407086
# | eval loss:  tensor(1.3024, device='cuda:0') | eval accuracy:  0.1795058998834122
# Epoch:   26
# | train loss:  tensor(0.2215, device='cuda:0') | train accuracy:  0.3940209808372531
# | eval loss:  tensor(1.4289, device='cuda:0') | eval accuracy:  0.16903942482748946
# Epoch:   27
# | train loss:  tensor(0.2136, device='cuda:0') | train accuracy:  0.40550545499158513
# | eval loss:  tensor(1.4165, device='cuda:0') | eval accuracy:  0.17669310097439295
# Epoch:   28
# | train loss:  tensor(0.1922, device='cuda:0') | train accuracy:  0.4332349025192968
# | eval loss:  tensor(1.4570, device='cuda:0') | eval accuracy:  0.1844896776258272
# Epoch:   29
# | train loss:  tensor(0.1932, device='cuda:0') | train accuracy:  0.43956327904681874
# | eval loss:  tensor(1.4543, device='cuda:0') | eval accuracy:  0.18441264600373455

# %%
x=np.arange(len(train_losses))
plt.plot(x,train_losses,label='train')
plt.plot(x,eval_losses,label='eval')
plt.title('Unet small number')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(x,train_accs,label='train')
plt.plot(x,eval_accs,label='eval')
plt.title('Unet small number')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
num_figure=8
imgs=np.arange(num_figure)*10

# %%
plt.figure(figsize=(9,24))
count=1
for i in imgs:
    
    img,label=train_data.__getitem__(i)
    
    plt.subplot(num_figure,3,count)
    plt.imshow(np.transpose(img.numpy(),(1,2,0)))
    plt.title('Image')
    
    plt.axis('off')
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    plt.imshow(label.numpy())
    plt.axis('off')
    plt.title('Label')
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    img=torch.unsqueeze(img,dim=0)
    b_x=Variable(img).cuda()
    output=unet(b_x).to(torch.float64)
    output=torch.max(output,1)[1]
    plt.imshow(output.cpu().detach().numpy()[0])
    plt.title('Prediction')
    plt.axis('off')
    
    count+=1
plt.suptitle('train')    
plt.show()

# %%
plt.figure(figsize=(9,24))
count=1
for i in imgs:
    
    img,label=eval_data.__getitem__(i)
    
    plt.subplot(num_figure,3,count)
    plt.imshow(np.transpose(img.numpy(),(1,2,0)))
    plt.title('Image')
    
    plt.axis('off')
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    plt.imshow(label.numpy())
    plt.title('Label')
    plt.axis('off')
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    img=torch.unsqueeze(img,dim=0)
    b_x=Variable(img).cuda()
    output=unet(b_x).to(torch.float64)
    output=torch.max(output,1)[1]
    plt.imshow(output.cpu().detach().numpy()[0])
    plt.title('Prediction')
    plt.axis('off')
    
    count+=1
plt.suptitle('eval')    
plt.show()

# %%
test_data=MyDataSet('test',test_transfrom)
plt.figure(figsize=(9,24))
count=1
for i in imgs:
    
    img,label=test_data.__getitem__(i)
    
    plt.subplot(num_figure,3,count)
    plt.imshow(np.transpose(img.numpy(),(1,2,0)))
    plt.title('Image')
   
    plt.axis('off')
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    plt.imshow(label.numpy())
    plt.title('Label')
    plt.axis('off')
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    img=torch.unsqueeze(img,dim=0)
    b_x=Variable(img).cuda()
    output=unet(b_x).to(torch.float64)
    output=torch.max(output,1)[1]
    plt.imshow(output.cpu().detach().numpy()[0])
    plt.title('Prediction')
    plt.axis('off')
    
    count+=1
plt.suptitle('test')    
plt.show()

# %%
torch.save(unet.state_dict(),'10000_30.pkl')

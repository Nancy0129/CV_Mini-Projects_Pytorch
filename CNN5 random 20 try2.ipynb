# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
warnings.filterwarnings("ignore")

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN5(nn.Module):
    def __init__(self):
        super(CNN5,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(
                in_channels=3,    #前面的层有多高
                out_channels=32,   #filter 的个数
                kernel_size=7,
                stride=1,
                padding=(3,3)  # if stride=1, padding=(kernel_size-1)/2
            ), 
            nn.ReLU(),   
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(32,64,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(64,128,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(128,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,128,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
        )


        self.dense1=nn.Sequential(
            nn.Linear(8*8*128,4096),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(4096,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(2048,1024),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(1024,101)
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn5=CNN5().cuda()
print(cnn5)
# Out:
# CNN5(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=8192, out_features=4096, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=4096, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense3): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=1024, out_features=101, bias=True)
# )

# %%
EPOCH = 30
BATCH_SIZE=64
LR=0.001
optimizer=torch.optim.Adam(cnn5.parameters(),lr=LR,weight_decay=0.001)
torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, 
    verbose=False, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))
eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
    torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=True, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=True, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
for epoch in range(EPOCH):
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn5(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if step%10==0:
            with torch.no_grad():
                pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                train_accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                train_accs.append(train_accuracy)
                losses.append(loss.data)
                torch.cuda.empty_cache()
                eval_acc=[]
                for x,y in eval_loader:
                    b_x=Variable(x).cuda()
                    b_y=Variable(y).cuda()        
                    output=cnn5(b_x)         #change
                    pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                    accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                    eval_acc.append(accuracy)
                eval_accs.append(np.mean(eval_acc))
                print('Epoch: ',epoch,'| Step: ',step,'| loss: ',loss.data,
                      '| Train_acc: ', train_accuracy,'| Eval_acc: ', np.mean(eval_acc))
# Out:
# Epoch:  0 | Step:  0 | loss:  tensor(4.6105, device='cuda:0') | Train_acc:  0.0 | Eval_acc:  0.098
# Epoch:  0 | Step:  10 | loss:  tensor(3.9361, device='cuda:0') | Train_acc:  0.171875 | Eval_acc:  0.21199999999999997
# Epoch:  0 | Step:  20 | loss:  tensor(3.5847, device='cuda:0') | Train_acc:  0.234375 | Eval_acc:  0.26899999999999996
# Epoch:  0 | Step:  30 | loss:  tensor(3.5080, device='cuda:0') | Train_acc:  0.234375 | Eval_acc:  0.28700000000000003
# Epoch:  0 | Step:  40 | loss:  tensor(3.7790, device='cuda:0') | Train_acc:  0.265625 | Eval_acc:  0.304
# Epoch:  0 | Step:  50 | loss:  tensor(3.5247, device='cuda:0') | Train_acc:  0.265625 | Eval_acc:  0.3
# Epoch:  0 | Step:  60 | loss:  tensor(3.2839, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.278
# Epoch:  0 | Step:  70 | loss:  tensor(3.3721, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.329
# Epoch:  0 | Step:  80 | loss:  tensor(3.1896, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.33599999999999997
# Epoch:  0 | Step:  90 | loss:  tensor(3.3190, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.366
# Epoch:  1 | Step:  0 | loss:  tensor(2.7919, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.344
# Epoch:  1 | Step:  10 | loss:  tensor(2.6848, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.397
# Epoch:  1 | Step:  20 | loss:  tensor(3.2899, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.40700000000000003
# Epoch:  1 | Step:  30 | loss:  tensor(2.7969, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.406
# Epoch:  1 | Step:  40 | loss:  tensor(3.0369, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.404
# Epoch:  1 | Step:  50 | loss:  tensor(3.4869, device='cuda:0') | Train_acc:  0.25 | Eval_acc:  0.392
# Epoch:  1 | Step:  60 | loss:  tensor(3.2364, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.388
# Epoch:  1 | Step:  70 | loss:  tensor(2.7443, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.4050000000000001
# Epoch:  1 | Step:  80 | loss:  tensor(2.7686, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.38999999999999996
# Epoch:  1 | Step:  90 | loss:  tensor(3.0214, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.387
# Epoch:  2 | Step:  0 | loss:  tensor(3.2609, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.38499999999999995
# Epoch:  2 | Step:  10 | loss:  tensor(2.5597, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.39
# Epoch:  2 | Step:  20 | loss:  tensor(2.7681, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.39099999999999996
# Epoch:  2 | Step:  30 | loss:  tensor(2.5225, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.434
# Epoch:  2 | Step:  40 | loss:  tensor(2.2168, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.41800000000000004
# Epoch:  2 | Step:  50 | loss:  tensor(2.6783, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.395
# Epoch:  2 | Step:  60 | loss:  tensor(3.0716, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.396
# Epoch:  2 | Step:  70 | loss:  tensor(2.6792, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.41500000000000004
# Epoch:  2 | Step:  80 | loss:  tensor(2.7754, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.426
# Epoch:  2 | Step:  90 | loss:  tensor(3.1960, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.44000000000000006
# Epoch:  3 | Step:  0 | loss:  tensor(2.2211, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.414
# Epoch:  3 | Step:  10 | loss:  tensor(2.9688, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.457
# Epoch:  3 | Step:  20 | loss:  tensor(2.4672, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.466
# Epoch:  3 | Step:  30 | loss:  tensor(3.0401, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.42000000000000004
# Epoch:  3 | Step:  40 | loss:  tensor(2.3095, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.462
# Epoch:  3 | Step:  50 | loss:  tensor(2.2921, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.442
# Epoch:  3 | Step:  60 | loss:  tensor(3.3020, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.44799999999999995
# Epoch:  3 | Step:  70 | loss:  tensor(2.1970, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.46299999999999997
# Epoch:  3 | Step:  80 | loss:  tensor(2.5395, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.491
# Epoch:  3 | Step:  90 | loss:  tensor(1.8407, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.43899999999999995
# Epoch:  4 | Step:  0 | loss:  tensor(2.3249, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.43099999999999994
# Epoch:  4 | Step:  10 | loss:  tensor(2.4319, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.46799999999999997
# Epoch:  4 | Step:  20 | loss:  tensor(2.6750, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.47400000000000003
# Epoch:  4 | Step:  30 | loss:  tensor(2.5307, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.462
# Epoch:  4 | Step:  40 | loss:  tensor(2.0366, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.476
# Epoch:  4 | Step:  50 | loss:  tensor(2.0184, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.501
# Epoch:  4 | Step:  60 | loss:  tensor(2.0052, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.49000000000000005
# Epoch:  4 | Step:  70 | loss:  tensor(1.9441, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.477
# Epoch:  4 | Step:  80 | loss:  tensor(2.0797, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.4880000000000001
# Epoch:  4 | Step:  90 | loss:  tensor(2.5284, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.51
# Epoch:  5 | Step:  0 | loss:  tensor(1.9305, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.49499999999999994
# Epoch:  5 | Step:  10 | loss:  tensor(1.9724, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.445
# Epoch:  5 | Step:  20 | loss:  tensor(1.8312, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.499
# Epoch:  5 | Step:  30 | loss:  tensor(2.2791, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.47800000000000004
# Epoch:  5 | Step:  40 | loss:  tensor(2.4106, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.47400000000000003
# Epoch:  5 | Step:  50 | loss:  tensor(1.7928, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.433
# Epoch:  5 | Step:  60 | loss:  tensor(2.2357, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.491
# Epoch:  5 | Step:  70 | loss:  tensor(1.7187, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.523
# Epoch:  5 | Step:  80 | loss:  tensor(1.7385, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.5189999999999999
# Epoch:  5 | Step:  90 | loss:  tensor(1.7442, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.525
# Epoch:  6 | Step:  0 | loss:  tensor(1.8375, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.506
# Epoch:  6 | Step:  10 | loss:  tensor(2.3355, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.519
# Epoch:  6 | Step:  20 | loss:  tensor(1.6942, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.47700000000000004
# Epoch:  6 | Step:  30 | loss:  tensor(1.5896, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.5349999999999999
# Epoch:  6 | Step:  40 | loss:  tensor(2.1318, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.522
# Epoch:  6 | Step:  50 | loss:  tensor(1.8627, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.505
# Epoch:  6 | Step:  60 | loss:  tensor(1.7701, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.508
# Epoch:  6 | Step:  70 | loss:  tensor(1.8929, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.5080000000000001
# Epoch:  6 | Step:  80 | loss:  tensor(1.7719, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.5080000000000001
# Epoch:  6 | Step:  90 | loss:  tensor(1.4189, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.5090000000000001
# Epoch:  7 | Step:  0 | loss:  tensor(1.6571, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.502
# Epoch:  7 | Step:  10 | loss:  tensor(1.8955, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.526
# Epoch:  7 | Step:  20 | loss:  tensor(1.3333, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.577
# Epoch:  7 | Step:  30 | loss:  tensor(1.3273, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.543
# Epoch:  7 | Step:  40 | loss:  tensor(1.7799, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.536
# Epoch:  7 | Step:  50 | loss:  tensor(1.5288, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.575
# Epoch:  7 | Step:  60 | loss:  tensor(1.2950, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.519
# Epoch:  7 | Step:  70 | loss:  tensor(1.6137, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.509
# Epoch:  7 | Step:  80 | loss:  tensor(1.4936, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.5469999999999999
# Epoch:  7 | Step:  90 | loss:  tensor(1.8115, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.557
# Epoch:  8 | Step:  0 | loss:  tensor(1.2957, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.528
# Epoch:  8 | Step:  10 | loss:  tensor(1.4433, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.553
# Epoch:  8 | Step:  20 | loss:  tensor(1.7766, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5309999999999999
# Epoch:  8 | Step:  30 | loss:  tensor(1.4016, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5349999999999999
# Epoch:  8 | Step:  40 | loss:  tensor(1.7594, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.541
# Epoch:  8 | Step:  50 | loss:  tensor(1.6301, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.5439999999999999
# Epoch:  8 | Step:  60 | loss:  tensor(1.4457, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.5860000000000001
# Epoch:  8 | Step:  70 | loss:  tensor(1.2741, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.58
# Epoch:  8 | Step:  80 | loss:  tensor(1.5550, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.577
# Epoch:  8 | Step:  90 | loss:  tensor(1.8930, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.52
# Epoch:  9 | Step:  0 | loss:  tensor(1.2516, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.514
# Epoch:  9 | Step:  10 | loss:  tensor(1.1875, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.5189999999999999
# Epoch:  9 | Step:  20 | loss:  tensor(1.3126, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.567
# Epoch:  9 | Step:  30 | loss:  tensor(1.1448, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.548
# Epoch:  9 | Step:  40 | loss:  tensor(1.2731, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.533
# Epoch:  9 | Step:  50 | loss:  tensor(1.4090, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.5589999999999999
# Epoch:  9 | Step:  60 | loss:  tensor(0.7229, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5589999999999999
# Epoch:  9 | Step:  70 | loss:  tensor(1.0571, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.562
# Epoch:  9 | Step:  80 | loss:  tensor(1.2065, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.568
# Epoch:  9 | Step:  90 | loss:  tensor(1.3850, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.55
# Epoch:  10 | Step:  0 | loss:  tensor(1.2892, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.5630000000000001
# Epoch:  10 | Step:  10 | loss:  tensor(1.3495, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.53
# Epoch:  10 | Step:  20 | loss:  tensor(1.1195, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.5660000000000001
# Epoch:  10 | Step:  30 | loss:  tensor(1.6417, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.565
# Epoch:  10 | Step:  40 | loss:  tensor(1.0519, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.5640000000000001
# Epoch:  10 | Step:  50 | loss:  tensor(0.7213, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.586
# Epoch:  10 | Step:  60 | loss:  tensor(1.0720, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.54
# Epoch:  10 | Step:  70 | loss:  tensor(0.9518, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.569
# Epoch:  10 | Step:  80 | loss:  tensor(1.0860, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.583
# Epoch:  10 | Step:  90 | loss:  tensor(1.2799, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.544
# Epoch:  11 | Step:  0 | loss:  tensor(0.7328, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.579
# Epoch:  11 | Step:  10 | loss:  tensor(1.0852, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.546
# Epoch:  11 | Step:  20 | loss:  tensor(0.5934, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.573
# Epoch:  11 | Step:  30 | loss:  tensor(0.8983, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5599999999999999
# Epoch:  11 | Step:  40 | loss:  tensor(0.4767, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.585
# Epoch:  11 | Step:  50 | loss:  tensor(0.7757, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5549999999999999
# Epoch:  11 | Step:  60 | loss:  tensor(0.5422, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.592
# Epoch:  11 | Step:  70 | loss:  tensor(0.8516, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.589
# Epoch:  11 | Step:  80 | loss:  tensor(0.9734, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.5820000000000001
# Epoch:  11 | Step:  90 | loss:  tensor(0.9147, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.591
# Epoch:  12 | Step:  0 | loss:  tensor(0.5032, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5660000000000001
# Epoch:  12 | Step:  10 | loss:  tensor(0.5597, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.575
# Epoch:  12 | Step:  20 | loss:  tensor(0.6926, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.559
# Epoch:  12 | Step:  30 | loss:  tensor(0.9101, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.558
# Epoch:  12 | Step:  40 | loss:  tensor(1.3708, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.587
# Epoch:  12 | Step:  50 | loss:  tensor(0.7955, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5609999999999999
# Epoch:  12 | Step:  60 | loss:  tensor(0.6629, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.593
# Epoch:  12 | Step:  70 | loss:  tensor(0.8480, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.556
# Epoch:  12 | Step:  80 | loss:  tensor(0.7196, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.585
# Epoch:  12 | Step:  90 | loss:  tensor(0.7021, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.597
# Epoch:  13 | Step:  0 | loss:  tensor(0.4533, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5700000000000001
# Epoch:  13 | Step:  10 | loss:  tensor(0.5668, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.579
# Epoch:  13 | Step:  20 | loss:  tensor(0.3818, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.553
# Epoch:  13 | Step:  30 | loss:  tensor(0.3624, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.566
# Epoch:  13 | Step:  40 | loss:  tensor(0.6303, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.642
# Epoch:  13 | Step:  50 | loss:  tensor(0.6275, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.547
# Epoch:  13 | Step:  60 | loss:  tensor(0.7119, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5940000000000001
# Epoch:  13 | Step:  70 | loss:  tensor(0.4227, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.602
# Epoch:  13 | Step:  80 | loss:  tensor(1.0853, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.583
# Epoch:  13 | Step:  90 | loss:  tensor(0.5524, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6209999999999999
# Epoch:  14 | Step:  0 | loss:  tensor(0.5167, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.58
# Epoch:  14 | Step:  10 | loss:  tensor(0.6462, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5960000000000001
# Epoch:  14 | Step:  20 | loss:  tensor(0.6870, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5980000000000001
# Epoch:  14 | Step:  30 | loss:  tensor(0.3984, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.559
# Epoch:  14 | Step:  40 | loss:  tensor(0.4319, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5810000000000001
# Epoch:  14 | Step:  50 | loss:  tensor(0.6602, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.571
# Epoch:  14 | Step:  60 | loss:  tensor(0.5582, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5820000000000001
# Epoch:  14 | Step:  70 | loss:  tensor(0.9524, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.603
# Epoch:  14 | Step:  80 | loss:  tensor(0.5190, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5830000000000001
# Epoch:  14 | Step:  90 | loss:  tensor(0.8014, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.598
# Epoch:  15 | Step:  0 | loss:  tensor(0.3291, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.58
# Epoch:  15 | Step:  10 | loss:  tensor(0.3383, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.591
# Epoch:  15 | Step:  20 | loss:  tensor(0.1824, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.616
# Epoch:  15 | Step:  30 | loss:  tensor(0.4465, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.578
# Epoch:  15 | Step:  40 | loss:  tensor(0.4004, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.543
# Epoch:  15 | Step:  50 | loss:  tensor(0.6070, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5839999999999999
# Epoch:  15 | Step:  60 | loss:  tensor(0.4849, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5940000000000001
# Epoch:  15 | Step:  70 | loss:  tensor(0.4439, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.638
# Epoch:  15 | Step:  80 | loss:  tensor(0.6036, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5879999999999999
# Epoch:  15 | Step:  90 | loss:  tensor(0.6016, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.592
# Epoch:  16 | Step:  0 | loss:  tensor(0.4697, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.546
# Epoch:  16 | Step:  10 | loss:  tensor(0.5459, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.582
# Epoch:  16 | Step:  20 | loss:  tensor(0.3323, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.581
# Epoch:  16 | Step:  30 | loss:  tensor(0.5699, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5569999999999999
# Epoch:  16 | Step:  40 | loss:  tensor(0.3833, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.619
# Epoch:  16 | Step:  50 | loss:  tensor(0.4192, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.535
# Epoch:  16 | Step:  60 | loss:  tensor(0.6684, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.587
# Epoch:  16 | Step:  70 | loss:  tensor(0.4215, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6089999999999999
# Epoch:  16 | Step:  80 | loss:  tensor(0.3892, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.614
# Epoch:  16 | Step:  90 | loss:  tensor(0.4473, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.634
# Epoch:  17 | Step:  0 | loss:  tensor(0.2639, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.595
# Epoch:  17 | Step:  10 | loss:  tensor(0.6152, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.627
# Epoch:  17 | Step:  20 | loss:  tensor(0.3806, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5780000000000001
# Epoch:  17 | Step:  30 | loss:  tensor(0.6041, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6060000000000001
# Epoch:  17 | Step:  40 | loss:  tensor(0.3594, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.575
# Epoch:  17 | Step:  50 | loss:  tensor(0.2724, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5799999999999998
# Epoch:  17 | Step:  60 | loss:  tensor(0.4734, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.612
# Epoch:  17 | Step:  70 | loss:  tensor(0.4261, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.615
# Epoch:  17 | Step:  80 | loss:  tensor(0.3501, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.624
# Epoch:  17 | Step:  90 | loss:  tensor(0.5396, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5860000000000001
# Epoch:  18 | Step:  0 | loss:  tensor(0.5221, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.576
# Epoch:  18 | Step:  10 | loss:  tensor(0.2844, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6299999999999999
# Epoch:  18 | Step:  20 | loss:  tensor(0.3389, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.618
# Epoch:  18 | Step:  30 | loss:  tensor(0.0906, device='cuda:0') | Train_acc:  1.0 | Eval_acc:  0.592
# Epoch:  18 | Step:  40 | loss:  tensor(0.3319, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6220000000000001
# Epoch:  18 | Step:  50 | loss:  tensor(0.5905, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.636
# Epoch:  18 | Step:  60 | loss:  tensor(0.1718, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.583
# Epoch:  18 | Step:  70 | loss:  tensor(0.3878, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.575
# Epoch:  18 | Step:  80 | loss:  tensor(0.5740, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5810000000000001
# Epoch:  18 | Step:  90 | loss:  tensor(0.2888, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5650000000000001
# Epoch:  19 | Step:  0 | loss:  tensor(0.1450, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.6
# Epoch:  19 | Step:  10 | loss:  tensor(0.2067, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.616
# Epoch:  19 | Step:  20 | loss:  tensor(0.1336, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5429999999999999
# Epoch:  19 | Step:  30 | loss:  tensor(0.5303, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.569
# Epoch:  19 | Step:  40 | loss:  tensor(0.3358, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.598
# Epoch:  19 | Step:  50 | loss:  tensor(0.3232, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.585
# Epoch:  19 | Step:  60 | loss:  tensor(0.5962, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.568
# Epoch:  19 | Step:  70 | loss:  tensor(0.2516, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6060000000000001
# Epoch:  19 | Step:  80 | loss:  tensor(0.1118, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.5800000000000001
# Epoch:  19 | Step:  90 | loss:  tensor(0.4429, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6279999999999999
# Epoch:  20 | Step:  0 | loss:  tensor(0.2479, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.623
# Epoch:  20 | Step:  10 | loss:  tensor(0.2577, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.5660000000000001
# Epoch:  20 | Step:  20 | loss:  tensor(0.2018, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.5740000000000001
# Epoch:  20 | Step:  30 | loss:  tensor(0.3775, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.61
# Epoch:  20 | Step:  40 | loss:  tensor(0.4248, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.571
# Epoch:  20 | Step:  50 | loss:  tensor(0.2606, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5700000000000001
# Epoch:  20 | Step:  60 | loss:  tensor(0.3492, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.589
# Epoch:  20 | Step:  70 | loss:  tensor(0.5334, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.644
# Epoch:  20 | Step:  80 | loss:  tensor(0.5252, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5940000000000001
# Epoch:  20 | Step:  90 | loss:  tensor(0.3915, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.572
# Epoch:  21 | Step:  0 | loss:  tensor(0.3512, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6220000000000001
# Epoch:  21 | Step:  10 | loss:  tensor(0.2599, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.577
# Epoch:  21 | Step:  20 | loss:  tensor(0.5409, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6050000000000001
# Epoch:  21 | Step:  30 | loss:  tensor(0.3399, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5549999999999999
# Epoch:  21 | Step:  40 | loss:  tensor(0.4952, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.605
# Epoch:  21 | Step:  50 | loss:  tensor(0.3653, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6140000000000001
# Epoch:  21 | Step:  60 | loss:  tensor(0.3997, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.578
# Epoch:  21 | Step:  70 | loss:  tensor(0.3832, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.595
# Epoch:  21 | Step:  80 | loss:  tensor(0.5946, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5900000000000001
# Epoch:  21 | Step:  90 | loss:  tensor(0.3787, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6119999999999999
# Epoch:  22 | Step:  0 | loss:  tensor(0.4348, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5900000000000001
# Epoch:  22 | Step:  10 | loss:  tensor(0.0881, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.663
# Epoch:  22 | Step:  20 | loss:  tensor(0.2379, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.6359999999999999
# Epoch:  22 | Step:  30 | loss:  tensor(0.3385, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.63
# Epoch:  22 | Step:  40 | loss:  tensor(0.1522, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.651
# Epoch:  22 | Step:  50 | loss:  tensor(0.2180, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.586
# Epoch:  22 | Step:  60 | loss:  tensor(0.2373, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.607
# Epoch:  22 | Step:  70 | loss:  tensor(0.2495, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.615
# Epoch:  22 | Step:  80 | loss:  tensor(0.0757, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.5990000000000001
# Epoch:  22 | Step:  90 | loss:  tensor(0.4848, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5690000000000001
# Epoch:  23 | Step:  0 | loss:  tensor(0.2612, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5660000000000001
# Epoch:  23 | Step:  10 | loss:  tensor(0.2051, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.575
# Epoch:  23 | Step:  20 | loss:  tensor(0.2789, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5489999999999999
# Epoch:  23 | Step:  30 | loss:  tensor(0.3954, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5770000000000001
# Epoch:  23 | Step:  40 | loss:  tensor(0.3030, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.586
# Epoch:  23 | Step:  50 | loss:  tensor(0.2049, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.5589999999999999
# Epoch:  23 | Step:  60 | loss:  tensor(0.1949, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.604
# Epoch:  23 | Step:  70 | loss:  tensor(0.3440, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.618
# Epoch:  23 | Step:  80 | loss:  tensor(0.3120, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.638
# Epoch:  23 | Step:  90 | loss:  tensor(0.4462, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.594
# Epoch:  24 | Step:  0 | loss:  tensor(0.3027, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.571
# Epoch:  24 | Step:  10 | loss:  tensor(0.1479, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.595
# Epoch:  24 | Step:  20 | loss:  tensor(0.2447, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.587
# Epoch:  24 | Step:  30 | loss:  tensor(0.3421, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.586
# Epoch:  24 | Step:  40 | loss:  tensor(0.1819, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.626
# Epoch:  24 | Step:  50 | loss:  tensor(0.2053, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.6050000000000001
# Epoch:  24 | Step:  60 | loss:  tensor(0.2660, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.619
# Epoch:  24 | Step:  70 | loss:  tensor(0.3024, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.5810000000000001
# Epoch:  24 | Step:  80 | loss:  tensor(0.4036, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.616
# Epoch:  24 | Step:  90 | loss:  tensor(0.2346, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5810000000000001
# Epoch:  25 | Step:  0 | loss:  tensor(0.3451, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.5810000000000001
# Epoch:  25 | Step:  10 | loss:  tensor(0.2180, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.566
# Epoch:  25 | Step:  20 | loss:  tensor(0.4142, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.583
# Epoch:  25 | Step:  30 | loss:  tensor(0.3807, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.614
# Epoch:  25 | Step:  40 | loss:  tensor(0.3098, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.587
# Epoch:  25 | Step:  50 | loss:  tensor(0.2671, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.595
# Epoch:  25 | Step:  60 | loss:  tensor(0.3888, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6020000000000001
# Epoch:  25 | Step:  70 | loss:  tensor(0.4886, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5670000000000001
# Epoch:  25 | Step:  80 | loss:  tensor(0.4956, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6289999999999999
# Epoch:  25 | Step:  90 | loss:  tensor(0.5482, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.607
# Epoch:  26 | Step:  0 | loss:  tensor(0.2407, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6119999999999999
# Epoch:  26 | Step:  10 | loss:  tensor(0.3323, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.591
# Epoch:  26 | Step:  20 | loss:  tensor(0.4584, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5890000000000001
# Epoch:  26 | Step:  30 | loss:  tensor(0.2434, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6159999999999999
# Epoch:  26 | Step:  40 | loss:  tensor(0.3873, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.631
# Epoch:  26 | Step:  50 | loss:  tensor(0.1459, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.6319999999999999
# Epoch:  26 | Step:  60 | loss:  tensor(0.2364, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.616
# Epoch:  26 | Step:  70 | loss:  tensor(0.4370, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.608
# Epoch:  26 | Step:  80 | loss:  tensor(0.3067, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.567
# Epoch:  26 | Step:  90 | loss:  tensor(0.2311, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6079999999999999
# Epoch:  27 | Step:  0 | loss:  tensor(0.1183, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.64
# Epoch:  27 | Step:  10 | loss:  tensor(0.0460, device='cuda:0') | Train_acc:  1.0 | Eval_acc:  0.591
# Epoch:  27 | Step:  20 | loss:  tensor(0.2509, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5680000000000001
# Epoch:  27 | Step:  30 | loss:  tensor(0.1319, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.627
# Epoch:  27 | Step:  40 | loss:  tensor(0.0891, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.619
# Epoch:  27 | Step:  50 | loss:  tensor(0.2625, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5960000000000001
# Epoch:  27 | Step:  60 | loss:  tensor(0.1172, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.602
# Epoch:  27 | Step:  70 | loss:  tensor(0.4628, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.584
# Epoch:  27 | Step:  80 | loss:  tensor(0.2014, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.5969999999999999
# Epoch:  27 | Step:  90 | loss:  tensor(0.2500, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.591
# Epoch:  28 | Step:  0 | loss:  tensor(0.0308, device='cuda:0') | Train_acc:  1.0 | Eval_acc:  0.5810000000000001
# Epoch:  28 | Step:  10 | loss:  tensor(0.0679, device='cuda:0') | Train_acc:  1.0 | Eval_acc:  0.575
# Epoch:  28 | Step:  20 | loss:  tensor(0.2101, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5519999999999999
# Epoch:  28 | Step:  30 | loss:  tensor(0.1058, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.639
# Epoch:  28 | Step:  40 | loss:  tensor(0.0767, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.6130000000000001
# Epoch:  28 | Step:  50 | loss:  tensor(0.2337, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.633
# Epoch:  28 | Step:  60 | loss:  tensor(0.2157, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.615
# Epoch:  28 | Step:  70 | loss:  tensor(0.3063, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.601
# Epoch:  28 | Step:  80 | loss:  tensor(0.2427, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.608
# Epoch:  28 | Step:  90 | loss:  tensor(0.0453, device='cuda:0') | Train_acc:  1.0 | Eval_acc:  0.5890000000000001
# Epoch:  29 | Step:  0 | loss:  tensor(0.2553, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.641
# Epoch:  29 | Step:  10 | loss:  tensor(0.2138, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.597
# Epoch:  29 | Step:  20 | loss:  tensor(0.2528, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.605
# Epoch:  29 | Step:  30 | loss:  tensor(0.3344, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.602
# Epoch:  29 | Step:  40 | loss:  tensor(0.2003, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6140000000000001
# Epoch:  29 | Step:  50 | loss:  tensor(0.2419, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.607
# Epoch:  29 | Step:  60 | loss:  tensor(0.1397, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.58
# Epoch:  29 | Step:  70 | loss:  tensor(0.2950, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.618
# Epoch:  29 | Step:  80 | loss:  tensor(0.3593, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.587
# Epoch:  29 | Step:  90 | loss:  tensor(0.3345, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.624

# %%
x=np.arange(len(losses))*10
plt.plot(x,losses)
plt.title('CNN5 TRY 2')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN5 TRY 2')
plt.xlabel('Step')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
warnings.filterwarnings("ignore")

# %%
torch.cuda.empty_cache()

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN5(nn.Module):
    def __init__(self):
        super(CNN5,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(
                in_channels=3,    #前面的层有多高
                out_channels=32,   #filter 的个数
                kernel_size=7,
                stride=1,
                padding=(3,3)  # if stride=1, padding=(kernel_size-1)/2
            ), 
            nn.ReLU(),   
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(32,64,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(64,128,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(128,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,128,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
        )


        self.dense1=nn.Sequential(
            nn.Linear(8*8*128,4096),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(4096,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(2048,1024),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(1024,101)
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn5=CNN5().cuda()
print(cnn5)
# Out:
# CNN5(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=8192, out_features=4096, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=4096, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense3): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=1024, out_features=101, bias=True)
# )

# %%
EPOCH = 30
BATCH_SIZE=64
LR=0.001
optimizer=torch.optim.Adam(cnn5.parameters(),lr=LR,weight_decay=0.001)
torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, 
    verbose=False, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5),
            torchvision.transforms.ToTensor()]))

eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
    torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=True, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=True, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
for epoch in range(EPOCH):
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn5(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if step%10==0:
            with torch.no_grad():
                pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                train_accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                train_accs.append(train_accuracy)
                losses.append(loss.data)
                torch.cuda.empty_cache()
                eval_acc=[]
                for x,y in eval_loader:
                    b_x=Variable(x).cuda()
                    b_y=Variable(y).cuda()        
                    output=cnn5(b_x)         #change
                    pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                    accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                    eval_acc.append(accuracy)
                eval_accs.append(np.mean(eval_acc))
                print('Epoch: ',epoch,'| Step: ',step,'| loss: ',loss.data,
                      '| Train_acc: ', train_accuracy,'| Eval_acc: ', np.mean(eval_acc))
# Out:
# Epoch:  0 | Step:  0 | loss:  tensor(4.6081, device='cuda:0') | Train_acc:  0.0 | Eval_acc:  0.08800000000000001
# Epoch:  0 | Step:  10 | loss:  tensor(4.6050, device='cuda:0') | Train_acc:  0.09375 | Eval_acc:  0.152
# Epoch:  0 | Step:  20 | loss:  tensor(4.2300, device='cuda:0') | Train_acc:  0.09375 | Eval_acc:  0.154
# Epoch:  0 | Step:  30 | loss:  tensor(4.4480, device='cuda:0') | Train_acc:  0.09375 | Eval_acc:  0.221
# Epoch:  0 | Step:  40 | loss:  tensor(3.9983, device='cuda:0') | Train_acc:  0.234375 | Eval_acc:  0.168
# Epoch:  0 | Step:  50 | loss:  tensor(3.9451, device='cuda:0') | Train_acc:  0.1875 | Eval_acc:  0.24100000000000002
# Epoch:  0 | Step:  60 | loss:  tensor(3.6728, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.181
# Epoch:  0 | Step:  70 | loss:  tensor(3.8646, device='cuda:0') | Train_acc:  0.21875 | Eval_acc:  0.211
# Epoch:  0 | Step:  80 | loss:  tensor(3.7266, device='cuda:0') | Train_acc:  0.21875 | Eval_acc:  0.198
# Epoch:  0 | Step:  90 | loss:  tensor(3.8971, device='cuda:0') | Train_acc:  0.234375 | Eval_acc:  0.22800000000000004
# Epoch:  1 | Step:  0 | loss:  tensor(3.8733, device='cuda:0') | Train_acc:  0.1875 | Eval_acc:  0.244
# Epoch:  1 | Step:  10 | loss:  tensor(3.6119, device='cuda:0') | Train_acc:  0.265625 | Eval_acc:  0.255
# Epoch:  1 | Step:  20 | loss:  tensor(3.3914, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.26599999999999996
# Epoch:  1 | Step:  30 | loss:  tensor(3.4291, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.274
# Epoch:  1 | Step:  40 | loss:  tensor(3.7935, device='cuda:0') | Train_acc:  0.21875 | Eval_acc:  0.269
# Epoch:  1 | Step:  50 | loss:  tensor(3.0876, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.28900000000000003
# Epoch:  1 | Step:  60 | loss:  tensor(3.7452, device='cuda:0') | Train_acc:  0.203125 | Eval_acc:  0.308
# Epoch:  1 | Step:  70 | loss:  tensor(3.6821, device='cuda:0') | Train_acc:  0.203125 | Eval_acc:  0.304
# Epoch:  1 | Step:  80 | loss:  tensor(3.2568, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.32199999999999995
# Epoch:  1 | Step:  90 | loss:  tensor(3.2648, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.336
# Epoch:  2 | Step:  0 | loss:  tensor(3.2094, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.302
# Epoch:  2 | Step:  10 | loss:  tensor(3.9255, device='cuda:0') | Train_acc:  0.203125 | Eval_acc:  0.37
# Epoch:  2 | Step:  20 | loss:  tensor(3.5494, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.324
# Epoch:  2 | Step:  30 | loss:  tensor(3.0890, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.333
# Epoch:  2 | Step:  40 | loss:  tensor(3.1232, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.326
# Epoch:  2 | Step:  50 | loss:  tensor(3.2875, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.314
# Epoch:  2 | Step:  60 | loss:  tensor(3.3350, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.32399999999999995
# Epoch:  2 | Step:  70 | loss:  tensor(3.0394, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.33899999999999997
# Epoch:  2 | Step:  80 | loss:  tensor(3.0499, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.358
# Epoch:  2 | Step:  90 | loss:  tensor(3.2926, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.398
# Epoch:  3 | Step:  0 | loss:  tensor(3.1265, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.335
# Epoch:  3 | Step:  10 | loss:  tensor(3.1957, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.339
# Epoch:  3 | Step:  20 | loss:  tensor(2.8925, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.38
# Epoch:  3 | Step:  30 | loss:  tensor(2.8692, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.356
# Epoch:  3 | Step:  40 | loss:  tensor(2.7361, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.34900000000000003
# Epoch:  3 | Step:  50 | loss:  tensor(3.4582, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.41200000000000003
# Epoch:  3 | Step:  60 | loss:  tensor(3.4810, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.425
# Epoch:  3 | Step:  70 | loss:  tensor(3.3502, device='cuda:0') | Train_acc:  0.265625 | Eval_acc:  0.39499999999999996
# Epoch:  3 | Step:  80 | loss:  tensor(2.9584, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.403
# Epoch:  3 | Step:  90 | loss:  tensor(3.0102, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.376
# Epoch:  4 | Step:  0 | loss:  tensor(3.2228, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.384
# Epoch:  4 | Step:  10 | loss:  tensor(3.7505, device='cuda:0') | Train_acc:  0.265625 | Eval_acc:  0.42300000000000004
# Epoch:  4 | Step:  20 | loss:  tensor(3.3434, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.38999999999999996
# Epoch:  4 | Step:  30 | loss:  tensor(3.0942, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.378
# Epoch:  4 | Step:  40 | loss:  tensor(3.0725, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.388
# Epoch:  4 | Step:  50 | loss:  tensor(3.5650, device='cuda:0') | Train_acc:  0.234375 | Eval_acc:  0.391
# Epoch:  4 | Step:  60 | loss:  tensor(3.1967, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.42699999999999994
# Epoch:  4 | Step:  70 | loss:  tensor(3.1525, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.44799999999999995
# Epoch:  4 | Step:  80 | loss:  tensor(3.2946, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.376
# Epoch:  4 | Step:  90 | loss:  tensor(3.1251, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.44299999999999995
# Epoch:  5 | Step:  0 | loss:  tensor(3.1599, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.41500000000000004
# Epoch:  5 | Step:  10 | loss:  tensor(2.3954, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.403
# Epoch:  5 | Step:  20 | loss:  tensor(2.8734, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.42200000000000004
# Epoch:  5 | Step:  30 | loss:  tensor(2.6537, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.433
# Epoch:  5 | Step:  40 | loss:  tensor(3.1471, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.41800000000000004
# Epoch:  5 | Step:  50 | loss:  tensor(2.6769, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.449
# Epoch:  5 | Step:  60 | loss:  tensor(2.7653, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.41600000000000004
# Epoch:  5 | Step:  70 | loss:  tensor(2.4377, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.40199999999999997
# Epoch:  5 | Step:  80 | loss:  tensor(2.2955, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.44699999999999995
# Epoch:  5 | Step:  90 | loss:  tensor(2.8420, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.425
# Epoch:  6 | Step:  0 | loss:  tensor(2.5371, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.42299999999999993
# Epoch:  6 | Step:  10 | loss:  tensor(2.4693, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.41200000000000003
# Epoch:  6 | Step:  20 | loss:  tensor(2.9724, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.45
# Epoch:  6 | Step:  30 | loss:  tensor(2.0565, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.493
# Epoch:  6 | Step:  40 | loss:  tensor(2.2806, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.43200000000000005
# Epoch:  6 | Step:  50 | loss:  tensor(2.6262, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.42000000000000004
# Epoch:  6 | Step:  60 | loss:  tensor(2.9962, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.421
# Epoch:  6 | Step:  70 | loss:  tensor(2.4226, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.40099999999999997
# Epoch:  6 | Step:  80 | loss:  tensor(2.6217, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.438
# Epoch:  6 | Step:  90 | loss:  tensor(3.0342, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.43
# Epoch:  7 | Step:  0 | loss:  tensor(2.4979, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.41200000000000003
# Epoch:  7 | Step:  10 | loss:  tensor(2.3006, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.41900000000000004
# Epoch:  7 | Step:  20 | loss:  tensor(2.7676, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.43200000000000005
# Epoch:  7 | Step:  30 | loss:  tensor(2.4978, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.44800000000000006
# Epoch:  7 | Step:  40 | loss:  tensor(2.6478, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.441
# Epoch:  7 | Step:  50 | loss:  tensor(2.5392, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.45500000000000007
# Epoch:  7 | Step:  60 | loss:  tensor(2.4027, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.45499999999999996
# Epoch:  7 | Step:  70 | loss:  tensor(2.4178, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.438
# Epoch:  7 | Step:  80 | loss:  tensor(2.4549, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.465
# Epoch:  7 | Step:  90 | loss:  tensor(1.9758, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.425
# Epoch:  8 | Step:  0 | loss:  tensor(2.4852, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.46099999999999997
# Epoch:  8 | Step:  10 | loss:  tensor(2.1663, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.45099999999999996
# Epoch:  8 | Step:  20 | loss:  tensor(1.8628, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.442
# Epoch:  8 | Step:  30 | loss:  tensor(2.4434, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.438
# Epoch:  8 | Step:  40 | loss:  tensor(2.4077, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.438
# Epoch:  8 | Step:  50 | loss:  tensor(2.4321, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.492
# Epoch:  8 | Step:  60 | loss:  tensor(2.5129, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.48100000000000004
# Epoch:  8 | Step:  70 | loss:  tensor(1.9966, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.5109999999999999
# Epoch:  8 | Step:  80 | loss:  tensor(2.6853, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.488
# Epoch:  8 | Step:  90 | loss:  tensor(2.0890, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.511
# Epoch:  9 | Step:  0 | loss:  tensor(2.0913, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.46900000000000003
# Epoch:  9 | Step:  10 | loss:  tensor(2.3999, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.49399999999999994
# Epoch:  9 | Step:  20 | loss:  tensor(1.9604, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.47800000000000004
# Epoch:  9 | Step:  30 | loss:  tensor(2.1475, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.454
# Epoch:  9 | Step:  40 | loss:  tensor(2.2392, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.519
# Epoch:  9 | Step:  50 | loss:  tensor(1.3679, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.47300000000000003
# Epoch:  9 | Step:  60 | loss:  tensor(2.2197, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.485
# Epoch:  9 | Step:  70 | loss:  tensor(2.5645, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.492
# Epoch:  9 | Step:  80 | loss:  tensor(2.2631, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.471
# Epoch:  9 | Step:  90 | loss:  tensor(2.0340, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.5189999999999999
# Epoch:  10 | Step:  0 | loss:  tensor(2.1101, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.4830000000000001
# Epoch:  10 | Step:  10 | loss:  tensor(2.0236, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.4640000000000001
# Epoch:  10 | Step:  20 | loss:  tensor(2.1502, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.44800000000000006
# Epoch:  10 | Step:  30 | loss:  tensor(1.6861, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.479
# Epoch:  10 | Step:  40 | loss:  tensor(1.6969, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.505
# Epoch:  10 | Step:  50 | loss:  tensor(2.5927, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.5029999999999999
# Epoch:  10 | Step:  60 | loss:  tensor(1.9707, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.425
# Epoch:  10 | Step:  70 | loss:  tensor(2.5905, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.473
# Epoch:  10 | Step:  80 | loss:  tensor(2.2243, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.483
# Epoch:  10 | Step:  90 | loss:  tensor(2.2291, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.47700000000000004
# Epoch:  11 | Step:  0 | loss:  tensor(2.1736, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.503
# Epoch:  11 | Step:  10 | loss:  tensor(2.2852, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.5199999999999999
# Epoch:  11 | Step:  20 | loss:  tensor(1.7632, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.481
# Epoch:  11 | Step:  30 | loss:  tensor(2.1734, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.47300000000000003
# Epoch:  11 | Step:  40 | loss:  tensor(2.0522, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.49700000000000005
# Epoch:  11 | Step:  50 | loss:  tensor(2.4158, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.506
# Epoch:  11 | Step:  60 | loss:  tensor(1.6826, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.5439999999999999
# Epoch:  11 | Step:  70 | loss:  tensor(2.3146, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.485
# Epoch:  11 | Step:  80 | loss:  tensor(2.2499, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.492
# Epoch:  11 | Step:  90 | loss:  tensor(2.1492, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.507
# Epoch:  12 | Step:  0 | loss:  tensor(1.3771, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.48900000000000005
# Epoch:  12 | Step:  10 | loss:  tensor(1.9380, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.4800000000000001
# Epoch:  12 | Step:  20 | loss:  tensor(1.9344, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.5000000000000001
# Epoch:  12 | Step:  30 | loss:  tensor(2.0241, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.549
# Epoch:  12 | Step:  40 | loss:  tensor(1.6769, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.531
# Epoch:  12 | Step:  50 | loss:  tensor(1.6170, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.538
# Epoch:  12 | Step:  60 | loss:  tensor(1.8942, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.5439999999999999
# Epoch:  12 | Step:  70 | loss:  tensor(2.0918, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.5090000000000001
# Epoch:  12 | Step:  80 | loss:  tensor(1.8901, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.521
# Epoch:  12 | Step:  90 | loss:  tensor(2.3347, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.526
# Epoch:  13 | Step:  0 | loss:  tensor(1.7620, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.5080000000000001
# Epoch:  13 | Step:  10 | loss:  tensor(1.7535, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.493
# Epoch:  13 | Step:  20 | loss:  tensor(1.6593, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.54
# Epoch:  13 | Step:  30 | loss:  tensor(1.6856, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.5309999999999999
# Epoch:  13 | Step:  40 | loss:  tensor(1.9249, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.525
# Epoch:  13 | Step:  50 | loss:  tensor(1.9535, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.501
# Epoch:  13 | Step:  60 | loss:  tensor(1.9572, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.5120000000000001
# Epoch:  13 | Step:  70 | loss:  tensor(2.0214, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.485
# Epoch:  13 | Step:  80 | loss:  tensor(2.7170, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.544
# Epoch:  13 | Step:  90 | loss:  tensor(1.7747, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.5820000000000001
# Epoch:  14 | Step:  0 | loss:  tensor(2.0012, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.5640000000000001
# Epoch:  14 | Step:  10 | loss:  tensor(1.8440, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.511
# Epoch:  14 | Step:  20 | loss:  tensor(1.5851, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.491
# Epoch:  14 | Step:  30 | loss:  tensor(1.5417, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.5210000000000001
# Epoch:  14 | Step:  40 | loss:  tensor(1.3377, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.5389999999999999
# Epoch:  14 | Step:  50 | loss:  tensor(1.7900, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.514
# Epoch:  14 | Step:  60 | loss:  tensor(1.6834, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.535
# Epoch:  14 | Step:  70 | loss:  tensor(1.9072, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.539
# Epoch:  14 | Step:  80 | loss:  tensor(2.0832, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.525
# Epoch:  14 | Step:  90 | loss:  tensor(1.7858, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.534
# Epoch:  15 | Step:  0 | loss:  tensor(1.5935, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.52
# Epoch:  15 | Step:  10 | loss:  tensor(1.6652, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.508
# Epoch:  15 | Step:  20 | loss:  tensor(1.7637, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.5200000000000001
# Epoch:  15 | Step:  30 | loss:  tensor(1.4897, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.52
# Epoch:  15 | Step:  40 | loss:  tensor(1.2605, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.561
# Epoch:  15 | Step:  50 | loss:  tensor(1.8565, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.5549999999999999
# Epoch:  15 | Step:  60 | loss:  tensor(1.3127, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.5349999999999999
# Epoch:  15 | Step:  70 | loss:  tensor(2.0834, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.493
# Epoch:  15 | Step:  80 | loss:  tensor(1.2414, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.547
# Epoch:  15 | Step:  90 | loss:  tensor(1.4312, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.556
# Epoch:  16 | Step:  0 | loss:  tensor(1.0177, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.48500000000000004
# Epoch:  16 | Step:  10 | loss:  tensor(1.3982, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.546
# Epoch:  16 | Step:  20 | loss:  tensor(1.4099, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.523
# Epoch:  16 | Step:  30 | loss:  tensor(1.4286, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.567
# Epoch:  16 | Step:  40 | loss:  tensor(1.9841, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.516
# Epoch:  16 | Step:  50 | loss:  tensor(1.3262, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.546
# Epoch:  16 | Step:  60 | loss:  tensor(1.3741, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.5660000000000001
# Epoch:  16 | Step:  70 | loss:  tensor(1.3817, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.531
# Epoch:  16 | Step:  80 | loss:  tensor(1.3977, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.55
# Epoch:  16 | Step:  90 | loss:  tensor(1.2794, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.558
# Epoch:  17 | Step:  0 | loss:  tensor(1.1897, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.5650000000000001
# Epoch:  17 | Step:  10 | loss:  tensor(1.5289, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.546
# Epoch:  17 | Step:  20 | loss:  tensor(1.5872, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.5599999999999999
# Epoch:  17 | Step:  30 | loss:  tensor(1.3019, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.556
# Epoch:  17 | Step:  40 | loss:  tensor(1.3363, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.617
# Epoch:  17 | Step:  50 | loss:  tensor(1.1755, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.567
# Epoch:  17 | Step:  60 | loss:  tensor(1.5233, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.52
# Epoch:  17 | Step:  70 | loss:  tensor(1.2867, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.528
# Epoch:  17 | Step:  80 | loss:  tensor(0.9528, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.5469999999999999
# Epoch:  17 | Step:  90 | loss:  tensor(1.0792, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.5770000000000001
# Epoch:  18 | Step:  0 | loss:  tensor(1.0464, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.5670000000000001
# Epoch:  18 | Step:  10 | loss:  tensor(1.3537, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.518
# Epoch:  18 | Step:  20 | loss:  tensor(1.4728, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.571
# Epoch:  18 | Step:  30 | loss:  tensor(1.1619, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.563
# Epoch:  18 | Step:  40 | loss:  tensor(1.4314, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.5650000000000001
# Epoch:  18 | Step:  50 | loss:  tensor(1.2235, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.58
# Epoch:  18 | Step:  60 | loss:  tensor(1.6355, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5519999999999999
# Epoch:  18 | Step:  70 | loss:  tensor(0.7554, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.534
# Epoch:  18 | Step:  80 | loss:  tensor(1.5252, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.539
# Epoch:  18 | Step:  90 | loss:  tensor(1.4016, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.53
# Epoch:  19 | Step:  0 | loss:  tensor(0.9675, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5529999999999999
# Epoch:  19 | Step:  10 | loss:  tensor(1.7346, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.53
# Epoch:  19 | Step:  20 | loss:  tensor(1.6236, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.564
# Epoch:  19 | Step:  30 | loss:  tensor(1.2244, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.598
# Epoch:  19 | Step:  40 | loss:  tensor(1.3349, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.5439999999999999
# Epoch:  19 | Step:  50 | loss:  tensor(0.8660, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.545
# Epoch:  19 | Step:  60 | loss:  tensor(1.2912, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.629
# Epoch:  19 | Step:  70 | loss:  tensor(1.4507, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.562
# Epoch:  19 | Step:  80 | loss:  tensor(1.9175, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.5720000000000001
# Epoch:  19 | Step:  90 | loss:  tensor(1.2896, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.56
# Epoch:  20 | Step:  0 | loss:  tensor(1.2205, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.599
# Epoch:  20 | Step:  10 | loss:  tensor(1.2112, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.555
# Epoch:  20 | Step:  20 | loss:  tensor(0.7718, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5589999999999999
# Epoch:  20 | Step:  30 | loss:  tensor(1.2365, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.5589999999999999
# Epoch:  20 | Step:  40 | loss:  tensor(1.3496, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.553
# Epoch:  20 | Step:  50 | loss:  tensor(1.3396, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.601
# Epoch:  20 | Step:  60 | loss:  tensor(1.4030, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.544
# Epoch:  20 | Step:  70 | loss:  tensor(1.4888, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.563
# Epoch:  20 | Step:  80 | loss:  tensor(0.8985, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.584
# Epoch:  20 | Step:  90 | loss:  tensor(1.3953, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.5720000000000001
# Epoch:  21 | Step:  0 | loss:  tensor(0.9374, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.58
# Epoch:  21 | Step:  10 | loss:  tensor(1.1626, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.5439999999999998
# Epoch:  21 | Step:  20 | loss:  tensor(0.9999, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.625
# Epoch:  21 | Step:  30 | loss:  tensor(1.0415, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.59
# Epoch:  21 | Step:  40 | loss:  tensor(0.9374, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.5660000000000001
# Epoch:  21 | Step:  50 | loss:  tensor(1.5550, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.5660000000000001
# Epoch:  21 | Step:  60 | loss:  tensor(1.1699, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.603
# Epoch:  21 | Step:  70 | loss:  tensor(1.3783, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5559999999999999
# Epoch:  21 | Step:  80 | loss:  tensor(1.0027, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.544
# Epoch:  21 | Step:  90 | loss:  tensor(1.3166, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.5589999999999999
# Epoch:  22 | Step:  0 | loss:  tensor(0.9254, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.596
# Epoch:  22 | Step:  10 | loss:  tensor(0.8340, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.591
# Epoch:  22 | Step:  20 | loss:  tensor(1.1804, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.588
# Epoch:  22 | Step:  30 | loss:  tensor(1.0320, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.57
# Epoch:  22 | Step:  40 | loss:  tensor(1.0215, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.587
# Epoch:  22 | Step:  50 | loss:  tensor(1.1074, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5650000000000001
# Epoch:  22 | Step:  60 | loss:  tensor(1.3246, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.576
# Epoch:  22 | Step:  70 | loss:  tensor(1.0948, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.584
# Epoch:  22 | Step:  80 | loss:  tensor(1.4679, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.5880000000000001
# Epoch:  22 | Step:  90 | loss:  tensor(1.1823, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.572
# Epoch:  23 | Step:  0 | loss:  tensor(0.9368, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.615
# Epoch:  23 | Step:  10 | loss:  tensor(0.8797, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6
# Epoch:  23 | Step:  20 | loss:  tensor(1.1190, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.567
# Epoch:  23 | Step:  30 | loss:  tensor(1.0153, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.595
# Epoch:  23 | Step:  40 | loss:  tensor(0.7844, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5549999999999999
# Epoch:  23 | Step:  50 | loss:  tensor(1.1214, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.534
# Epoch:  23 | Step:  60 | loss:  tensor(0.9708, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.5589999999999999
# Epoch:  23 | Step:  70 | loss:  tensor(0.9854, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.578
# Epoch:  23 | Step:  80 | loss:  tensor(1.1346, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.576
# Epoch:  23 | Step:  90 | loss:  tensor(0.9361, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.59
# Epoch:  24 | Step:  0 | loss:  tensor(0.6892, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5930000000000001
# Epoch:  24 | Step:  10 | loss:  tensor(0.7462, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.591
# Epoch:  24 | Step:  20 | loss:  tensor(0.8663, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.591
# Epoch:  24 | Step:  30 | loss:  tensor(0.7408, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5810000000000001
# Epoch:  24 | Step:  40 | loss:  tensor(0.8192, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.619
# Epoch:  24 | Step:  50 | loss:  tensor(0.9512, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.617
# Epoch:  24 | Step:  60 | loss:  tensor(0.9740, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.5729999999999998
# Epoch:  24 | Step:  70 | loss:  tensor(0.6252, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.553
# Epoch:  24 | Step:  80 | loss:  tensor(1.0054, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.616
# Epoch:  24 | Step:  90 | loss:  tensor(1.1045, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.605
# Epoch:  25 | Step:  0 | loss:  tensor(0.7924, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.568
# Epoch:  25 | Step:  10 | loss:  tensor(0.9571, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.578
# Epoch:  25 | Step:  20 | loss:  tensor(0.7056, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6
# Epoch:  25 | Step:  30 | loss:  tensor(0.9565, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5489999999999999
# Epoch:  25 | Step:  40 | loss:  tensor(0.8057, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.599
# Epoch:  25 | Step:  50 | loss:  tensor(0.8912, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.608
# Epoch:  25 | Step:  60 | loss:  tensor(0.8564, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.617
# Epoch:  25 | Step:  70 | loss:  tensor(0.5338, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.588
# Epoch:  25 | Step:  80 | loss:  tensor(0.9118, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.575
# Epoch:  25 | Step:  90 | loss:  tensor(1.2664, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6050000000000001
# Epoch:  26 | Step:  0 | loss:  tensor(0.9261, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.597
# Epoch:  26 | Step:  10 | loss:  tensor(0.9647, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.616
# Epoch:  26 | Step:  20 | loss:  tensor(0.6292, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6130000000000001
# Epoch:  26 | Step:  30 | loss:  tensor(0.8017, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5690000000000001
# Epoch:  26 | Step:  40 | loss:  tensor(0.8964, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.567
# Epoch:  26 | Step:  50 | loss:  tensor(0.9954, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.625
# Epoch:  26 | Step:  60 | loss:  tensor(0.9104, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.57
# Epoch:  26 | Step:  70 | loss:  tensor(0.7502, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.596
# Epoch:  26 | Step:  80 | loss:  tensor(1.0345, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.597
# Epoch:  26 | Step:  90 | loss:  tensor(0.8894, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6210000000000001
# Epoch:  27 | Step:  0 | loss:  tensor(0.6418, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.587
# Epoch:  27 | Step:  10 | loss:  tensor(0.7907, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5800000000000001
# Epoch:  27 | Step:  20 | loss:  tensor(0.6151, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5890000000000001
# Epoch:  27 | Step:  30 | loss:  tensor(0.8089, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.589
# Epoch:  27 | Step:  40 | loss:  tensor(0.6845, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.601
# Epoch:  27 | Step:  50 | loss:  tensor(0.7903, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.591
# Epoch:  27 | Step:  60 | loss:  tensor(0.8478, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.631
# Epoch:  27 | Step:  70 | loss:  tensor(0.7389, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.607
# Epoch:  27 | Step:  80 | loss:  tensor(0.8284, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5690000000000001
# Epoch:  27 | Step:  90 | loss:  tensor(0.8191, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.617
# Epoch:  28 | Step:  0 | loss:  tensor(0.7014, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.604
# Epoch:  28 | Step:  10 | loss:  tensor(0.7222, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5549999999999999
# Epoch:  28 | Step:  20 | loss:  tensor(0.6688, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.602
# Epoch:  28 | Step:  30 | loss:  tensor(0.6585, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.537
# Epoch:  28 | Step:  40 | loss:  tensor(0.7491, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.608
# Epoch:  28 | Step:  50 | loss:  tensor(0.6419, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.578
# Epoch:  28 | Step:  60 | loss:  tensor(0.9392, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.63
# Epoch:  28 | Step:  70 | loss:  tensor(0.4701, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6199999999999999
# Epoch:  28 | Step:  80 | loss:  tensor(0.6363, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6010000000000001
# Epoch:  28 | Step:  90 | loss:  tensor(0.7556, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.606
# Epoch:  29 | Step:  0 | loss:  tensor(0.6862, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5970000000000001
# Epoch:  29 | Step:  10 | loss:  tensor(0.3451, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.592
# Epoch:  29 | Step:  20 | loss:  tensor(0.6546, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6199999999999999
# Epoch:  29 | Step:  30 | loss:  tensor(0.5941, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.593
# Epoch:  29 | Step:  40 | loss:  tensor(0.7363, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5810000000000001
# Epoch:  29 | Step:  50 | loss:  tensor(0.5058, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.607
# Epoch:  29 | Step:  60 | loss:  tensor(0.7993, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.592
# Epoch:  29 | Step:  70 | loss:  tensor(0.7436, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.577
# Epoch:  29 | Step:  80 | loss:  tensor(0.5126, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5960000000000001
# Epoch:  29 | Step:  90 | loss:  tensor(0.6268, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.584

# %%
x=np.arange(len(losses))*10
plt.plot(x,losses)
plt.title('CNN5 TRY 3')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN5 TRY 3')
plt.xlabel('Step')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

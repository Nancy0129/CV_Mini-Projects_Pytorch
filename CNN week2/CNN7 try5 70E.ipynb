# %% [markdown]
# Tried weight initialize
# More Conv2d layers, less channles
# Less neurons

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
import copy
warnings.filterwarnings("ignore")

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN7(nn.Module):
    def __init__(self):
        super(CNN7,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(3,32,3,1,1,bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(), 
            nn.Conv2d(32,32,3,1,1,bias=False),               
            nn.BatchNorm2d(32),
            nn.ReLU(), 
            nn.Conv2d(32,32,3,1,1,bias=False),               
            nn.BatchNorm2d(32),
            nn.ReLU(), 
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(32,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),               
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),               
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(64,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(128,256,3,1,1,bias=False),            
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(256,256,3,1,1,bias=False),            
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,128,3,1,1),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )        


        self.dense1=nn.Sequential(
            nn.Linear(4*4*128,2048,bias=True),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(2048,1024,bias=True),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(1024,512,bias=True),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(512,101)
        
        

        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn7=CNN7().cuda()

for m in cnn7.modules():
            if isinstance(m, (nn.Conv2d, nn.Linear)):
                nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('relu'))
            if isinstance(m, ( nn.Linear)):
                nn.init.constant_(m.bias, 0.0)

print(cnn7)
# Out:
# CNN7(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=2048, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense3): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=512, out_features=101, bias=True)
# )

# %%
EPOCH = 70
BATCH_SIZE=64
LR=0.001
optimizer=torch.optim.Adam(cnn7.parameters(),lr=LR,weight_decay=0.01)
scheduler=torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5, 
    verbose=True, threshold=0.0001, threshold_mode='rel', cooldown=2, min_lr=1e-08, eps=1e-08)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),
            torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5),
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=False, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=False, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
best_model_wts = copy.deepcopy(cnn7.state_dict())         #change
best_acc = 0.0

for epoch in range(EPOCH):
    print('Step:')
    cnn7.train()   #change
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn7(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()    
        
        if step%30==0:
            print(step)
           

    losses.append(loss.data)
    with torch.no_grad():
        cnn7.eval()   #change
        
        train_acc=[]
        for x,y in train_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn7(b_x)   #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0) 
            train_acc.append(accuracy)
            torch.cuda.empty_cache()
        train_acc=sum(train_acc)/len(train_acc)
        train_accs.append(train_acc)
        
        eval_acc=[]
        for x,y in eval_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn7(b_x)         #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0)
            eval_acc.append(accuracy)
            torch.cuda.empty_cache()
        eval_acc=sum(eval_acc)/len(eval_acc)
        eval_accs.append(eval_acc)
        
        
        if eval_acc>best_acc:
            best_acc = eval_acc
            best_model_wts = copy.deepcopy(cnn7.state_dict())         #change
            
    scheduler.step(train_acc) 
    
    print('Epoch: %4s'%epoch,'| loss: ',loss.data,
            '| Train_acc: %6s'% train_acc.data,'| Eval_acc: %6s'%eval_acc.data) 
print('Best Eval acc: %6s'%best_acc)
# Out:
# Step:
# 0
# 30
# 60
# 90
# Epoch:    0 | loss:  tensor(4.9846, device='cuda:0') | Train_acc: tensor(0.0919, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.0940, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    1 | loss:  tensor(3.8825, device='cuda:0') | Train_acc: tensor(0.0969, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.0970, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    2 | loss:  tensor(3.9695, device='cuda:0') | Train_acc: tensor(0.1610, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.1550, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    3 | loss:  tensor(3.7459, device='cuda:0') | Train_acc: tensor(0.1878, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.1910, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    4 | loss:  tensor(4.1878, device='cuda:0') | Train_acc: tensor(0.2537, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2170, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    5 | loss:  tensor(3.0943, device='cuda:0') | Train_acc: tensor(0.3135, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2910, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    6 | loss:  tensor(1.9573, device='cuda:0') | Train_acc: tensor(0.3472, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3050, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    7 | loss:  tensor(2.8129, device='cuda:0') | Train_acc: tensor(0.3586, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3130, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    8 | loss:  tensor(2.4770, device='cuda:0') | Train_acc: tensor(0.3601, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3220, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    9 | loss:  tensor(2.6000, device='cuda:0') | Train_acc: tensor(0.4022, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3840, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   10 | loss:  tensor(2.0017, device='cuda:0') | Train_acc: tensor(0.4071, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3840, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   11 | loss:  tensor(2.8338, device='cuda:0') | Train_acc: tensor(0.4068, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3450, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   12 | loss:  tensor(2.9437, device='cuda:0') | Train_acc: tensor(0.4229, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3990, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   13 | loss:  tensor(2.1558, device='cuda:0') | Train_acc: tensor(0.4464, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3940, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   14 | loss:  tensor(1.9744, device='cuda:0') | Train_acc: tensor(0.4665, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3950, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   15 | loss:  tensor(2.7268, device='cuda:0') | Train_acc: tensor(0.4716, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4440, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   16 | loss:  tensor(2.1879, device='cuda:0') | Train_acc: tensor(0.4701, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4280, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   17 | loss:  tensor(1.2249, device='cuda:0') | Train_acc: tensor(0.4778, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4280, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   18 | loss:  tensor(2.5563, device='cuda:0') | Train_acc: tensor(0.5120, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4810, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   19 | loss:  tensor(2.9850, device='cuda:0') | Train_acc: tensor(0.5134, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5030, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   20 | loss:  tensor(1.9623, device='cuda:0') | Train_acc: tensor(0.4878, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4420, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   21 | loss:  tensor(1.9722, device='cuda:0') | Train_acc: tensor(0.5044, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4590, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   22 | loss:  tensor(1.5391, device='cuda:0') | Train_acc: tensor(0.5096, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4420, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   23 | loss:  tensor(1.7081, device='cuda:0') | Train_acc: tensor(0.5209, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5230, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   24 | loss:  tensor(2.2246, device='cuda:0') | Train_acc: tensor(0.5774, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5170, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   25 | loss:  tensor(1.9576, device='cuda:0') | Train_acc: tensor(0.5362, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4670, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   26 | loss:  tensor(2.1598, device='cuda:0') | Train_acc: tensor(0.5468, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4830, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   27 | loss:  tensor(1.5962, device='cuda:0') | Train_acc: tensor(0.5485, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4810, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   28 | loss:  tensor(1.5759, device='cuda:0') | Train_acc: tensor(0.5954, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5570, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   29 | loss:  tensor(2.0743, device='cuda:0') | Train_acc: tensor(0.6105, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5900, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   30 | loss:  tensor(2.1522, device='cuda:0') | Train_acc: tensor(0.6093, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5860, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   31 | loss:  tensor(1.5323, device='cuda:0') | Train_acc: tensor(0.4775, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4440, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   32 | loss:  tensor(2.0751, device='cuda:0') | Train_acc: tensor(0.5848, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5490, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   33 | loss:  tensor(0.8630, device='cuda:0') | Train_acc: tensor(0.5633, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5610, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   34 | loss:  tensor(0.6913, device='cuda:0') | Train_acc: tensor(0.6017, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5600, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   35 | loss:  tensor(1.9693, device='cuda:0') | Train_acc: tensor(0.6187, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5690, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   36 | loss:  tensor(1.9958, device='cuda:0') | Train_acc: tensor(0.6298, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5980, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   37 | loss:  tensor(0.8956, device='cuda:0') | Train_acc: tensor(0.6059, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5360, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   38 | loss:  tensor(1.8692, device='cuda:0') | Train_acc: tensor(0.6406, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6060, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   39 | loss:  tensor(1.6262, device='cuda:0') | Train_acc: tensor(0.6687, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6010, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   40 | loss:  tensor(1.6743, device='cuda:0') | Train_acc: tensor(0.6021, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5330, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   41 | loss:  tensor(1.1823, device='cuda:0') | Train_acc: tensor(0.6626, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6140, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   42 | loss:  tensor(1.1572, device='cuda:0') | Train_acc: tensor(0.6212, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5600, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   43 | loss:  tensor(1.2303, device='cuda:0') | Train_acc: tensor(0.6827, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6040, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   44 | loss:  tensor(1.4007, device='cuda:0') | Train_acc: tensor(0.6888, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6110, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   45 | loss:  tensor(0.7674, device='cuda:0') | Train_acc: tensor(0.6332, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5510, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   46 | loss:  tensor(1.4399, device='cuda:0') | Train_acc: tensor(0.6728, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6080, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   47 | loss:  tensor(1.2621, device='cuda:0') | Train_acc: tensor(0.6580, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5940, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   48 | loss:  tensor(1.1559, device='cuda:0') | Train_acc: tensor(0.6825, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6210, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   49 | loss:  tensor(1.4128, device='cuda:0') | Train_acc: tensor(0.6897, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6190, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   50 | loss:  tensor(1.0425, device='cuda:0') | Train_acc: tensor(0.6448, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5900, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   51 | loss:  tensor(1.7738, device='cuda:0') | Train_acc: tensor(0.7344, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6230, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   52 | loss:  tensor(1.0872, device='cuda:0') | Train_acc: tensor(0.6230, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5560, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   53 | loss:  tensor(1.4890, device='cuda:0') | Train_acc: tensor(0.6946, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6140, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   54 | loss:  tensor(0.9469, device='cuda:0') | Train_acc: tensor(0.6961, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5900, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   55 | loss:  tensor(1.3638, device='cuda:0') | Train_acc: tensor(0.6732, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5670, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   56 | loss:  tensor(1.4972, device='cuda:0') | Train_acc: tensor(0.6863, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5980, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch    58: reducing learning rate of group 0 to 5.0000e-04.
# Epoch:   57 | loss:  tensor(1.7939, device='cuda:0') | Train_acc: tensor(0.7233, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6090, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   58 | loss:  tensor(0.8944, device='cuda:0') | Train_acc: tensor(0.7896, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6400, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   59 | loss:  tensor(1.2393, device='cuda:0') | Train_acc: tensor(0.7904, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6700, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   60 | loss:  tensor(1.3309, device='cuda:0') | Train_acc: tensor(0.8234, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6720, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   61 | loss:  tensor(0.9315, device='cuda:0') | Train_acc: tensor(0.8217, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6470, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   62 | loss:  tensor(1.1065, device='cuda:0') | Train_acc: tensor(0.8059, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6410, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   63 | loss:  tensor(1.0443, device='cuda:0') | Train_acc: tensor(0.8158, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6360, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   64 | loss:  tensor(1.0668, device='cuda:0') | Train_acc: tensor(0.7988, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6750, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   65 | loss:  tensor(0.6357, device='cuda:0') | Train_acc: tensor(0.8434, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6630, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   66 | loss:  tensor(0.8287, device='cuda:0') | Train_acc: tensor(0.8184, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6420, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   67 | loss:  tensor(2.0985, device='cuda:0') | Train_acc: tensor(0.8065, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6110, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   68 | loss:  tensor(0.6645, device='cuda:0') | Train_acc: tensor(0.8017, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6390, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   69 | loss:  tensor(1.4052, device='cuda:0') | Train_acc: tensor(0.8531, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6940, device='cuda:0', dtype=torch.float64)
# Best Eval acc: tensor(0.6940, device='cuda:0', dtype=torch.float64)

# %%
x=np.arange(len(losses))
plt.plot(x,losses)
plt.title('CNN7 TRY 5')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN7 TRY5')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
torch.save(cnn7.state_dict(),'CNN7 5 70E.pkl')

# %%
optimizer.state_dict
# Out:
# defaultdict(dict,
#             {Parameter containing:
#              tensor([[[[ 7.2538e-04, -2.3812e-04, -7.8103e-04],
#                        [-2.9033e-04, -6.7567e-04, -1.0740e-03],
#                        [-2.8482e-04, -7.4727e-04, -7.7650e-04]],
#
#                       [[ 1.4587e-03,  7.1145e-05, -1.2543e-03],
#                        [ 1.0988e-03, -7.8861e-04, -1.4003e-03],
#                        [ 4.3647e-04, -7.2144e-04, -1.0568e-03]],
#
#                       [[ 7.2225e-04, -2.1748e-04, -8.8051e-04],
#                        [-1.0869e-04, -7.5555e-04, -1.0320e-03],
#                        [-5.8581e-04, -1.0072e-03, -9.1479e-04]]],
#
#
#                      [[[-2.4765e-04, -4.9575e-04, -6.4041e-04],
#                        [-8.9322e-05, -2.5125e-04, -5.1719e-04],
#                        [ 1.0833e-04, -2.8819e-04, -2.8525e-04]],
#
#                       [[-3.3288e-04, -3.7905e-04, -6.4184e-04],
#                        [-2.2884e-04, -3.5214e-04, -5.4793e-04],
#                        [ 8.2891e-05, -4.2721e-04, -6.4532e-04]],
#
#                       [[-6.6271e-04, -4.3883e-04, -5.6098e-04],
#                        [-4.5709e-04, -3.4175e-04, -5.3033e-04],
#                        [ 2.9314e-04, -3.3196e-04, -4.2635e-04]]],
#
#
#                      [[[ 5.1698e-02, -7.3268e-03, -4.7690e-02],
#                        [ 1.2455e-02,  2.8167e-02,  7.1279e-03],
#                        [-2.2592e-02,  2.5823e-03, -3.0585e-02]],
#
#                       [[ 4.0617e-02, -9.8590e-04,  1.2478e-02],
#                        [ 2.9545e-02,  3.5532e-02, -1.7932e-02],
#                        [-2.2809e-02,  1.6735e-02, -5.6339e-02]],
#
#                       [[ 2.6071e-02, -2.5818e-02, -3.9853e-02],
#                        [ 4.7895e-02,  4.4205e-02, -5.0228e-02],
#                        [-2.6480e-02,  1.7857e-02, -1.4142e-02]]],
#
#
#                      [[[ 3.9956e-03,  3.7857e-03,  4.3935e-03],
#                        [ 6.0955e-03,  5.3099e-03,  1.0286e-02],
#                        [ 4.0430e-03,  4.0372e-03,  1.1087e-02]],
#
#                       [[-9.3079e-04,  5.6406e-04,  1.3670e-03],
#                        [ 3.3898e-03,  3.9798e-03,  6.8782e-03],
#                        [ 1.6561e-03,  4.0300e-03,  6.4480e-03]],
#
#                       [[ 2.9531e-03,  4.3615e-04,  2.7866e-03],
#                        [ 3.6487e-03,  9.2563e-03,  5.7667e-03],
#                        [ 5.0496e-03,  7.7594e-03,  1.1014e-02]]],
#
#
#                      [[[ 4.3414e-02, -1.4237e-02,  7.2214e-02],
#                        [-1.3258e-02, -3.0696e-02,  2.7600e-02],
#                        [ 3.1862e-02, -6.0684e-02, -6.1566e-02]],
#
#                       [[ 7.4667e-02, -2.6719e-02,  3.8312e-02],
#                        [-4.2072e-02, -9.6375e-03, -7.0274e-02],
#                        [ 5.9817e-02, -7.3651e-02, -2.5635e-02]],
#
#                       [[-2.6838e-02, -3.7602e-02,  4.8063e-02],
#                        [ 4.9287e-02,  7.4817e-03, -4.0004e-02],
#                        [-5.1031e-03,  1.5991e-02,  1.0107e-03]]],
#
#
#                      [[[-2.8588e-04, -2.8308e-04, -3.5104e-04],
#                        [-3.5200e-04, -3.6025e-04, -3.6746e-04],
#                        [-2.6890e-04, -2.8205e-04, -2.8278e-04]],
#
#                       [[-3.6360e-04, -3.9412e-04, -4.7171e-04],
#                        [-4.5917e-04, -4.5412e-04, -4.7974e-04],
#                        [-4.4220e-04, -3.9533e-04, -3.9398e-04]],
#
#                       [[-2.0848e-04, -2.1923e-04, -3.0810e-04],
#                        [-3.5922e-04, -2.9008e-04, -3.4375e-04],
#                        [-3.2092e-04, -2.7170e-04, -2.4530e-04]]],
#
#
#                      [[[-3.3643e-03, -4.6687e-03, -1.3014e-03],
#                        [-4.7793e-03, -3.5478e-03,  1.7877e-03],
#                        [ 2.4312e-03,  2.2844e-03, -1.0985e-03]],
#
#                       [[-1.2815e-04,  3.4520e-04, -2.7873e-04],
#                        [-3.7484e-03, -4.1405e-04, -1.5416e-04],
#                        [-5.0961e-04, -5.7614e-04, -1.3311e-04]],
#
#                       [[ 3.3241e-03, -5.6381e-04, -6.9297e-04],
#                        [-6.7778e-03, -1.0803e-03, -5.1621e-04],
#                        [ 4.1989e-04, -1.5903e-03, -2.5569e-04]]],
#
#
#                      [[[ 1.0521e-02, -5.1977e-04,  2.2640e-03],
#                        [ 9.1662e-03, -7.8619e-03, -1.5918e-03],
#                        [ 3.7197e-03, -2.0689e-03, -1.5039e-02]],
#
#                       [[ 1.2125e-02,  5.5170e-03,  5.2157e-03],
#                        [ 1.1838e-02, -4.7995e-03, -1.2488e-02],
#                        [ 4.9076e-03, -1.9230e-03, -1.2773e-02]],
#
#                       [[ 1.0441e-02,  1.0108e-02,  1.9059e-02],
#                        [ 8.3186e-03, -1.0476e-03, -4.6967e-03],
#                        [ 5.7158e-03, -8.2073e-03, -8.0147e-03]]],
#
#
#                      [[[-5.1349e-04, -1.1064e-03,  1.1377e-03],
#                        [ 1.4628e-04,  1.2541e-03,  5.2609e-03],
#                        [ 2.6996e-04,  9.7739e-05, -4.3182e-03]],
#
#                       [[ 3.3215e-04, -1.6368e-03, -1.2059e-03],
#                        [ 2.2646e-04,  1.1510e-04,  2.4404e-04],
#                        [ 3.5933e-04, -6.5580e-06,  2.1185e-04]],
#
#                       [[ 2.6366e-04,  8.6485e-05,  3.5280e-04],
#                        [ 5.6521e-04, -1.3208e-04,  5.1885e-04],
#                        [ 2.4930e-04,  2.3772e-04, -2.5655e-03]]],
#
#
#                      [[[-7.4714e-06,  1.1909e-05,  1.6591e-05],
#                        [ 9.1856e-06,  6.9226e-06,  2.8515e-05],
#                        [-3.5376e-06,  4.8024e-06,  1.4708e-04]],
#
#                       [[ 4.0061e-05,  8.8949e-07,  2.1811e-05],
#                        [ 1.5740e-05,  1.6024e-06,  1.4612e-05],
#                        [ 1.1672e-04,  1.7362e-05,  3.9861e-05]],
#
#                       [[ 2.8118e-07,  3.3862e-06,  3.6925e-07],
#                        [ 5.3390e-07, -6.2077e-06,  3.4231e-06],
#                        [ 1.1010e-06,  8.6086e-06, -3.2402e-06]]],
#
#
#                      [[[ 6.2122e-05, -9.1791e-05,  7.7623e-04],
#                        [-1.4403e-03,  1.0910e-04,  6.0858e-04],
#                        [-1.4467e-03, -1.8589e-03,  2.3666e-04]],
#
#                       [[-6.4321e-04,  1.6028e-04,  3.2876e-04],
#                        [-5.5585e-05, -4.6442e-04, -2.6620e-04],
#                        [-6.4346e-04,  1.4912e-04, -9.0665e-04]],
#
#                       [[-2.8615e-05,  2.7669e-04, -1.4713e-04],
#                        [-1.3540e-03, -6.3965e-04,  3.5309e-04],
#                        [-6.4561e-04, -6.7223e-04, -1.2662e-04]]],
#
#
#                      [[[ 3.9350e-02, -7.2877e-03,  5.9438e-02],
#                        [ 1.6109e-03,  5.3920e-02,  7.0971e-02],
#                        [-3.7447e-03, -5.4105e-03,  7.7743e-02]],
#
#                       [[-1.1432e-02, -4.1459e-02, -2.4305e-02],
#                        [-4.6861e-02, -2.6364e-02, -2.8017e-02],
#                        [-5.9916e-03, -4.3259e-03, -2.0941e-02]],
#
#                       [[-1.7774e-02, -2.6828e-02, -4.9995e-02],
#                        [-3.0812e-02, -4.6688e-02, -5.8731e-02],
#                        [-3.0871e-02, -1.1706e-02, -5.1647e-03]]],
#
#
#                      [[[ 2.7778e-02, -1.5489e-02, -4.8180e-02],
#                        [-4.7981e-03,  2.2399e-02, -3.2725e-02],
#                        [ 7.9892e-02, -7.8682e-02, -1.4177e-02]],
#
#                       [[ 4.5979e-02, -6.1867e-02,  1.0282e-02],
#                        [ 6.4272e-02, -2.3749e-02, -9.4250e-02],
#                        [ 7.8985e-02, -5.2109e-02, -2.8873e-03]],
#
#                       [[-1.7813e-03, -4.3813e-02, -5.4537e-02],
#                        [ 6.5112e-02, -6.8432e-02, -8.4843e-02],
#                        [ 9.2775e-02, -4.9067e-03,  4.7025e-02]]],
#
#
#                      [[[ 6.4052e-03,  5.1470e-03,  3.9464e-03],
#                        [ 5.5462e-03,  4.9132e-03,  4.1701e-03],
#                        [ 5.1428e-03,  5.7645e-03,  5.6673e-03]],
#                        [-1.1092e-02,  1.0434e-03, -3.1816e-02]],
#
#                       [[-4.5619e-02, -2.8424e-02, -1.8796e-02],
#                        [-4.1643e-02, -6.9505e-03,  8.1148e-03],
#                        [ 8.0985e-03,  1.8652e-02,  2.6280e-02]]],
#
#
#                      [[[-1.5087e-03,  7.2834e-03,  6.4257e-03],
#                        [-7.2220e-05,  1.6541e-04,  6.5579e-03],
#                        [-6.7331e-03,  5.4889e-03,  7.8582e-03]],
#
#                       [[-1.9884e-03,  5.8214e-03,  4.9602e-03],
#                        [ 1.0291e-03,  2.9839e-03,  9.6237e-04],
#                        [-5.1985e-03,  2.2369e-03,  7.7118e-03]],
#
#                       [[-3.8402e-03, -5.0236e-03, -7.1310e-03],
#                        [-9.2059e-04,  6.0458e-03,  4.7579e-03],
#                        [ 8.8792e-04,  1.2614e-02,  1.4402e-02]]],
#
#
#                      [[[-5.7747e-02, -1.2055e-03, -1.3363e-02],
#                        [-6.9412e-02,  2.3072e-02, -3.3455e-03],
#                        [-4.6143e-02, -1.8520e-03,  8.8473e-02]],
#
#                       [[-2.6174e-02, -3.2669e-02,  3.2025e-02],
#                        [-6.4989e-02,  8.1370e-03,  1.2401e-02],
#                        [-2.5946e-02,  5.8216e-04,  3.0998e-02]],
#
#                       [[-5.8177e-02, -3.0036e-02,  4.5046e-02],
#                        [-6.2474e-02,  8.1263e-03, -2.2782e-02],
#                        [-3.7251e-02,  1.0436e-02,  5.7416e-02]]],
#
#
#                      [[[-4.6777e-03, -3.1836e-03, -4.0188e-04],
#                        [ 1.5857e-03, -3.2149e-03, -2.6589e-03],
#                        [-3.2249e-03,  5.8216e-03,  2.7728e-03]],
#
#                       [[ 4.5524e-05,  4.5431e-05, -1.8571e-03],
#                        [ 5.4756e-03, -2.4515e-03,  1.9156e-03],
#                        [ 1.0450e-02,  4.5409e-03,  1.6588e-02]],
#
#                       [[-6.6262e-03, -9.9095e-04,  2.5569e-03],
#                        [-4.5199e-03,  7.9776e-04,  6.8735e-03],
#                        [-3.4652e-03, -6.9539e-03,  7.3004e-03]]]], device='cuda:0',
#                     requires_grad=True): {'step': 6790,
#               'exp_avg': tensor([[[[ 2.0401e-05, -2.4965e-06, -9.7522e-06],
#                         [ 1.4099e-05, -3.7450e-06, -1.2062e-05],
#                         [ 1.3423e-05, -5.2013e-06, -8.9233e-06]],
#
#                        [[ 3.4876e-05,  6.5288e-06, -1.0282e-05],
#                         [ 3.7119e-05,  2.5928e-06, -9.2801e-06],
#                         [ 3.0952e-05,  3.1620e-06, -5.9367e-06]],
#
#                        [[ 1.5903e-05, -3.6575e-06, -1.0737e-05],
#                         [ 1.3123e-05, -4.1954e-06, -1.0355e-05],
#                         [ 9.0109e-06, -7.1162e-06, -9.5247e-06]]],
#
#
#                       [[[-2.5763e-05, -2.4538e-05, -2.4758e-05],
#                         [-1.9516e-05, -1.9240e-05, -2.0080e-05],
#                         [-1.2005e-05, -1.5917e-05, -1.6715e-05]],
#
#                        [[-6.8111e-06, -5.8471e-06, -7.9268e-06],
#                         [ 1.3102e-06, -4.4099e-06, -7.0044e-06],
#                         [ 1.2505e-05, -2.2793e-07, -7.8907e-06]],
#
#                        [[-3.3997e-05, -2.3581e-05, -2.4175e-05],
#                         [-2.8374e-05, -2.2612e-05, -2.4281e-05],
#                         [-1.5736e-05, -2.1395e-05, -2.3990e-05]]],
#
#
#                       [[[ 1.0347e-03,  8.9810e-04,  1.1159e-03],
#                         [-2.3647e-04,  2.5576e-04,  9.4553e-04],
#                         [-5.6486e-04, -2.3301e-04,  4.0789e-05]],
#
#                        [[ 5.4106e-03,  4.7595e-03,  4.8787e-03],
#                         [ 4.7677e-03,  4.4295e-03,  4.0539e-03],
#                         [ 4.4763e-03,  4.3262e-03,  3.5205e-03]],
#
#                        [[ 2.3376e-03,  2.3190e-03,  2.6743e-03],
#                         [ 1.9618e-03,  2.3470e-03,  2.0955e-03],
#                         [ 1.2422e-03,  1.8772e-03,  1.9910e-03]]],
#
#
#                       [[[-1.0758e-04, -2.3209e-04, -1.8343e-04],
#                         [-1.5557e-04, -2.7601e-04, -1.7795e-04],
#                         [-3.0901e-04, -3.9916e-04, -2.6305e-04]],
#
#                        [[ 4.9677e-04,  4.4587e-04,  5.5279e-04],
#                         [ 4.8525e-04,  4.0200e-04,  5.1748e-04],
#                         [ 3.2321e-04,  2.6185e-04,  3.8159e-04]],
#
#                        [[ 2.9632e-04,  1.9220e-04,  3.0673e-04],
#                         [ 2.3059e-04,  1.9937e-04,  2.4903e-04],
#                         [ 8.1596e-05,  4.8476e-05,  1.6747e-04]]],
#
#
#                       [[[-1.2906e-03, -1.6076e-03, -3.4160e-04],
#                         [-3.3020e-03, -2.8282e-03, -1.5451e-03],
#                         [-2.7868e-03, -3.1057e-03, -2.5597e-03]],
#
#                        [[ 5.1764e-03,  4.0722e-03,  5.1599e-03],
#                         [ 3.1070e-03,  3.6549e-03,  3.7341e-03],
#                         [ 4.7663e-03,  3.3325e-03,  4.2504e-03]],
#
#                        [[ 2.4577e-03,  2.5375e-03,  3.8244e-03],
#                         [ 2.0445e-03,  2.0461e-03,  2.1087e-03],
#                         [ 1.5840e-03,  2.0060e-03,  2.0777e-03]]],
#
#
#                       [[[-1.7244e-05, -1.6943e-05, -2.0549e-05],
#                         [-1.7360e-05, -1.5335e-05, -1.6931e-05],
#                         [-1.6550e-05, -1.3622e-05, -1.5557e-05]],
#
#                        [[-7.3393e-06, -6.4728e-06, -7.9481e-06],
#                         [-8.0020e-06, -6.0860e-06, -6.1312e-06],
#                         [-7.0208e-06, -4.7407e-06, -6.0440e-06]],
#
#                        [[-2.1231e-05, -1.9164e-05, -2.1904e-05],
#                         [-2.2994e-05, -1.8764e-05, -2.0515e-05],
#                         [-2.2464e-05, -1.8212e-05, -2.0151e-05]]],
#
#
#                       [[[-3.4177e-05, -4.9650e-05, -1.7953e-05],
#                         [-4.6142e-05, -3.5115e-05,  1.4467e-05],
#                         [ 2.5572e-05,  2.3107e-05, -1.4637e-05]],
#
#                        [[ 5.6413e-06,  7.7089e-06,  2.8419e-07],
#                         [-2.9370e-05,  8.9727e-07, -3.0139e-07],
#                         [ 3.3634e-06, -1.4088e-06, -1.5447e-06]],
#
#                        [[ 2.0223e-05, -1.7509e-05, -1.9622e-05],
#                         [-8.2387e-05, -2.3394e-05, -1.9985e-05],
#                         [-1.0527e-05, -2.9423e-05, -1.8964e-05]]],
#
#
#                       [[[ 1.0347e-04, -7.9169e-06, -1.1087e-05],
#                         [ 9.4848e-05, -7.7621e-05, -4.9703e-05],
#                         [ 4.8130e-05, -5.9758e-06, -1.7914e-04]],
#
#                        [[ 6.3249e-05, -3.3229e-06, -3.6693e-05],
#                         [ 7.8520e-05, -9.6566e-05, -2.0695e-04],
#                         [ 1.5948e-05, -6.5187e-05, -2.1808e-04]],
#
#                        [[ 8.8189e-05,  9.0011e-05,  1.5620e-04],
#                         [ 6.4146e-05, -2.2002e-05, -8.3180e-05],
#                         [ 4.6185e-05, -8.3812e-05, -1.1661e-04]]],
#
#
#                       [[[-5.2507e-06, -1.1256e-05,  1.1463e-05],
#                         [ 1.4560e-06,  1.2725e-05,  5.3170e-05],
#                         [ 2.7167e-06,  9.6237e-07, -4.3657e-05]],
#
#                        [[ 3.4251e-06, -1.6565e-05, -1.2213e-05],
#                         [ 2.3452e-06,  1.2101e-06,  2.5198e-06],
#                         [ 3.7080e-06, -3.5519e-08,  2.1844e-06]],
#
#                        [[ 2.6787e-06,  8.6133e-07,  3.5446e-06],
#                         [ 5.7387e-06, -1.3705e-06,  5.2366e-06],
#                         [ 2.5160e-06,  2.3942e-06, -2.6037e-05]]],
#
#
#                       [[[-7.6825e-08,  1.2341e-07,  1.7196e-07],
#                         [ 9.4787e-08,  7.1740e-08,  2.9410e-07],
#                         [-3.6398e-08,  4.9572e-08,  1.5073e-06]],
#
#                        [[ 4.1015e-07,  9.2274e-09,  2.2532e-07],
#                         [ 1.6202e-07,  1.6767e-08,  1.5043e-07],
#                         [ 1.1962e-06,  1.7956e-07,  4.0787e-07]],
#
#                        [[ 2.9742e-09,  3.5162e-08,  3.8621e-09],
#                         [ 5.6093e-09, -6.3978e-08,  3.5562e-08],
#                         [ 1.1518e-08,  8.8579e-08, -3.3502e-08]]],
#
#
#                       [[[ 7.0745e-07, -8.8567e-07,  7.8802e-06],
#                         [-1.4659e-05,  1.1237e-06,  6.1439e-06],
#                         [-1.4716e-05, -1.8897e-05,  2.3325e-06]],
#
#                        [[-6.4626e-06,  1.6877e-06,  3.3683e-06],
#                         [-5.5919e-07, -4.7164e-06, -2.7205e-06],
#                         [-6.5430e-06,  1.5120e-06, -9.2659e-06]],
#
#                        [[-2.1303e-07,  2.8643e-06, -1.5098e-06],
#                         [-1.3761e-05, -6.5025e-06,  3.5574e-06],
#                         [-6.5614e-06, -6.8395e-06, -1.3413e-06]]],
#
#
#                       [[[ 4.3074e-03,  3.9490e-03,  4.4142e-03],
#                         [ 4.1392e-03,  3.7170e-03,  3.2039e-03],
#                         [ 4.0562e-03,  2.6121e-03,  1.8898e-03]],
#
#                        [[ 4.4538e-03,  4.4079e-03,  4.7709e-03],
#                         [ 4.2848e-03,  3.9337e-03,  3.9889e-03],
#                         [ 4.8107e-03,  4.0077e-03,  3.2856e-03]],
#
#                        [[ 4.9065e-04, -3.4259e-04, -1.5858e-03],
#                         [ 9.4447e-04, -8.5536e-04, -2.2313e-03],
#                         [ 8.0210e-04, -9.1277e-04, -2.6437e-03]]],
#
#
#                       [[[-9.5299e-03, -8.3600e-03, -6.0130e-03],
#                         [-8.0437e-03, -6.7914e-03, -5.2107e-03],
#                         [-9.9655e-03, -9.7388e-03, -6.5961e-03]],
#
#                        [[ 9.4027e-03,  6.3086e-03,  6.1234e-03],
#                         [ 1.0522e-02,  6.4379e-03,  3.4725e-03],
#                         [ 6.8832e-03,  2.8672e-03,  8.5412e-04]],
#
#                        [[-1.8982e-03, -1.6944e-04,  2.9414e-03],
#                         [ 9.3490e-04,  5.0697e-04,  2.2700e-03],
#                         [-1.3886e-03, -8.2348e-04,  1.5445e-03]]],
#
#
#                       [[[ 6.1264e-04,  4.6186e-04,  4.2378e-04],
#                         [ 2.3204e-04,  8.8722e-05,  6.8181e-05],
#                         [-9.2142e-05, -2.2017e-04, -1.8249e-04]],
#
#                        [[ 3.2957e-04,  2.6908e-04,  2.8625e-04],
#                         [ 4.2782e-05, -2.5077e-05, -3.4512e-05],
#                         [-2.3569e-04, -2.7902e-04, -2.3955e-04]],
#
#                        [[ 1.4117e-03,  1.4861e-03,  1.7375e-03],
#                         [ 1.1202e-03,  1.2628e-03,  1.5544e-03],
#                         [ 8.7746e-04,  1.0643e-03,  1.4073e-03]]],
#
#
#                       [[[ 1.6159e-02,  1.1302e-02,  5.2078e-03],
#                         [ 1.3361e-02,  8.4582e-03,  3.9635e-03],
#                         [ 9.9149e-03,  3.9608e-03, -5.5281e-05]],
#
#                        [[ 5.7568e-04, -3.7274e-03, -6.3680e-03],
#                         [-7.1696e-04, -4.6151e-03, -5.9099e-03],
#                         [-2.7530e-03, -6.2565e-03, -9.1286e-03]],
#
#                        [[ 6.1303e-03,  2.5973e-03, -2.9534e-03],
#                         [ 4.9809e-03,  2.2643e-03, -9.7445e-04],
#                         [ 2.0357e-03, -7.8267e-04, -4.8356e-03]]],
#
#
#                       [[[-2.1019e-03, -5.3248e-03, -1.0615e-02],
#                         [ 4.8434e-03,  2.3678e-03, -4.1800e-03],
#                         [ 1.0386e-02,  8.9549e-03,  2.6331e-03]],
#
#                        [[-2.0349e-02, -1.9042e-02, -2.1070e-02],
#                         [-1.5601e-02, -1.3499e-02, -1.5453e-02],
#                         [-1.1577e-02, -7.4812e-03, -1.0052e-02]],
#
#                        [[-7.4721e-03, -1.0396e-02, -1.3340e-02],
#                         [-2.8182e-03, -4.5928e-03, -8.5181e-03],
#                         [ 9.8164e-04,  3.6093e-04, -3.1541e-03]]],
#
#
#                       [[[ 1.7314e-05, -4.2347e-06, -1.0552e-05],
#                         [ 4.0909e-06, -9.5683e-06, -1.1766e-05],
#                         [-8.0519e-07, -1.1612e-05, -1.9750e-05]],
#
#                        [[ 1.3874e-05, -3.2517e-07, -5.4700e-06],
#                         [ 5.5020e-06, -5.8177e-06, -1.8976e-05],
#                         [-2.2856e-06, -1.4194e-05, -1.5768e-05]],
#
#                        [[ 1.9965e-05, -1.2325e-06, -5.9111e-06],
#                         [ 7.0337e-06, -1.1704e-05, -1.7162e-05],
#                         [-7.6105e-06, -1.5683e-05, -9.9255e-06]]],
#
#
#                       [[[-2.0385e-05, -9.0230e-06, -1.1554e-05],
#                         [-1.4201e-05, -5.0133e-06,  3.3779e-06],
#                         [-8.5670e-06, -4.2038e-06,  4.3972e-06]],
#
#                        [[-2.5998e-06, -3.4318e-06,  7.3096e-07],
#                         [-5.9027e-06, -7.7306e-06, -3.5339e-07],
#                         [-2.9747e-06, -7.6020e-06,  7.6539e-07]],
#
#                        [[-9.2123e-06, -3.0312e-06,  3.0249e-06],
#                         [-1.4633e-05, -1.3817e-05,  2.7320e-06],
#                         [-4.2885e-06, -6.0042e-06, -3.0511e-06]]],
#
#
#                       [[[-1.7531e-03, -2.0480e-03, -1.4697e-03],
#                         [-1.7344e-03, -2.0648e-03, -1.4554e-03],
#                         [-1.8483e-03, -2.0066e-03, -1.3876e-03]],
#
#                        [[ 2.2350e-03,  2.1317e-03,  2.7852e-03],
#                         [ 2.4133e-03,  2.1154e-03,  2.5895e-03],
#                         [ 2.2232e-03,  2.1163e-03,  2.5518e-03]],
#
#                        [[ 9.3960e-04,  7.5762e-04,  1.4251e-03],
#                         [ 8.3769e-04,  6.2162e-04,  1.3312e-03],
#                         [ 5.0532e-04,  4.9959e-04,  1.1635e-03]]],
#
#
#                       [[[ 3.2630e-06,  5.4762e-06,  7.4032e-06],
#                         [-4.8095e-06,  7.9106e-06,  8.2267e-06],
#                         [-1.2813e-05, -2.2784e-05,  1.9088e-06]],
#
#                        [[ 4.4411e-06,  2.3762e-05,  2.7981e-05],
#                         [ 1.5853e-05,  2.3338e-05,  4.3199e-06],
#                         [ 7.0123e-06,  5.6524e-08, -1.0668e-06]],
#
#                        [[ 8.3773e-06,  2.9790e-05,  2.3602e-05],
#                         [ 6.1431e-06,  1.5381e-05,  8.7352e-06],
#                         [-1.5402e-05, -3.4112e-07, -1.3258e-05]]],
#
#
#                       [[[ 4.3753e-02,  4.5904e-02,  4.3595e-02],
#                         [ 6.5447e-02,  6.7840e-02,  6.1015e-02],
#                         [ 5.2859e-02,  5.3983e-02,  4.7145e-02]],
#
#                        [[-3.6205e-02, -2.6898e-02, -2.6224e-02],
#                         [-1.2563e-02, -6.5823e-03, -1.1235e-02],
#                         [-2.3706e-02, -1.7275e-02, -2.2842e-02]],
#
#                        [[ 3.0079e-02,  2.8934e-02,  2.7122e-02],
#                         [ 5.5587e-02,  5.4267e-02,  5.0006e-02],
#                         [ 4.2330e-02,  4.2419e-02,  4.3239e-02]]],
#
#
#                       [[[ 2.9041e-02,  2.9037e-02,  3.2338e-02],
#                         [ 3.1011e-02,  2.8406e-02,  3.6784e-02],
#                         [ 1.2991e-02,  1.8295e-02,  2.6894e-02]],
#
#                        [[ 1.1773e-01,  1.0054e-01,  9.4673e-02],
#                         [ 1.2015e-01,  1.0136e-01,  9.1311e-02],
#                         [ 1.0331e-01,  9.4354e-02,  8.6061e-02]],
#                         [-1.1968e-02, -4.1217e-03,  2.6810e-03],
#                         [-3.4436e-03, -9.1157e-04,  2.1344e-03]]],
#
#
#                       [[[ 1.1379e-02,  1.2200e-02,  1.6736e-02],
#                         [ 8.8837e-03,  1.1058e-02,  1.3105e-02],
#                         [ 1.3110e-02,  1.4393e-02,  1.4610e-02]],
#
#                        [[ 2.3166e-02,  2.0517e-02,  2.3328e-02],
#                         [ 2.5522e-02,  2.3152e-02,  2.3560e-02],
#                         [ 3.1181e-02,  2.5666e-02,  2.2653e-02]],
#
#                        [[ 2.5994e-02,  2.9481e-02,  3.3764e-02],
#                         [ 2.6683e-02,  3.0790e-02,  3.1699e-02],
#                         [ 3.1069e-02,  3.1151e-02,  3.2008e-02]]],
#
#
#                       [[[ 4.7825e-04,  7.4973e-04,  1.4242e-03],
#                         [ 1.1567e-03,  1.2702e-03,  1.8402e-03],
#                         [ 1.5543e-03,  1.5481e-03,  1.9394e-03]],
#
#                        [[-1.0920e-04,  1.1162e-03,  1.3505e-03],
#                         [ 4.1332e-04,  1.4637e-03,  1.5105e-03],
#                         [ 1.1884e-03,  1.7518e-03,  1.4207e-03]],
#
#                        [[ 7.7149e-04,  9.6646e-04,  1.3361e-03],
#                         [ 1.2514e-03,  1.5748e-03,  1.8153e-03],
#                         [ 1.9723e-03,  2.0387e-03,  2.1091e-03]]],
#
#
#                       [[[ 9.5763e-06, -6.9935e-05, -1.3034e-04],
#                         [ 4.5239e-05, -1.3601e-04, -1.2138e-04],
#                         [-1.2621e-04, -1.7295e-04, -1.4462e-04]],
#
#                        [[ 4.0987e-04,  3.4621e-04,  3.3210e-04],
#                         [ 4.6035e-04,  2.9963e-04,  2.7194e-04],
#                         [ 2.6443e-04,  1.5361e-04,  2.4773e-04]],
#
#                        [[ 1.3233e-04,  5.4613e-05,  1.1642e-04],
#                         [ 1.7787e-04,  1.7755e-04,  2.4301e-04],
#                         [ 1.1199e-04,  1.7761e-04,  3.0375e-04]]],
#
#
#                       [[[ 9.6927e-03,  9.6687e-03,  8.3052e-03],
#                         [ 1.2745e-02,  1.4612e-02,  1.3670e-02],
#                         [ 1.6240e-02,  2.0257e-02,  2.0845e-02]],
#
#                        [[-1.2758e-02, -1.1092e-02, -1.0924e-02],
#                         [-1.2826e-02, -8.9407e-03, -8.1558e-03],
#                         [-1.1289e-02, -5.4516e-03, -3.9548e-03]],
#
#                        [[ 1.5869e-02,  1.6634e-02,  1.7707e-02],
#                         [ 1.7848e-02,  2.0207e-02,  2.0963e-02],
#                         [ 2.1021e-02,  2.5473e-02,  2.7185e-02]]],
#
#
#                       [[[-4.7332e-05, -3.2216e-05, -4.0696e-06],
#                         [ 1.6023e-05, -3.2515e-05, -2.6876e-05],
#                         [-3.2597e-05,  5.8804e-05,  2.7998e-05]],
#
#                        [[ 4.4919e-07,  4.4887e-07, -1.8758e-05],
#                         [ 5.5275e-05, -2.4759e-05,  1.9330e-05],
#                         [ 1.0548e-04,  4.5824e-05,  1.6738e-04]],
#
#                        [[-6.6985e-05, -1.0027e-05,  2.5824e-05],
#                         [-4.5683e-05,  8.0489e-06,  6.9418e-05],
#                         [-3.5008e-05, -7.0224e-05,  7.3689e-05]]]], device='cuda:0'),
#               'exp_avg_sq': tensor([[[[8.3440e-06, 6.6126e-06, 5.8422e-06],
#                         [7.9512e-06, 5.9461e-06, 5.3349e-06],
#                         [8.2200e-06, 6.2251e-06, 5.2662e-06]],
#
#                        [[1.2533e-05, 1.0588e-05, 9.4624e-06],
#                         [1.2205e-05, 9.8399e-06, 8.8671e-06],
#                         [1.2462e-05, 9.9513e-06, 8.8790e-06]],
#
#                        [[9.0767e-06, 7.3433e-06, 6.7941e-06],
#                         [8.4193e-06, 6.5644e-06, 6.0497e-06],
#                         [8.6207e-06, 6.7187e-06, 5.8522e-06]]],
#
#
#                       [[[6.1247e-06, 3.9607e-06, 4.2575e-06],
#                         [5.0113e-06, 3.7539e-06, 4.2586e-06],
#                         [7.0676e-06, 5.5991e-06, 5.8806e-06]],
#
#                        [[5.6103e-06, 3.8313e-06, 4.5016e-06],
#                         [5.0983e-06, 4.3741e-06, 4.3637e-06],
#                         [6.9396e-06, 6.6120e-06, 6.4308e-06]],
#
#                        [[6.2942e-06, 3.9553e-06, 4.2372e-06],
#                         [5.6700e-06, 4.1542e-06, 4.4647e-06],
#                         [7.7012e-06, 6.4897e-06, 6.4128e-06]]],
#
#
#                       [[[2.1005e-04, 2.1165e-04, 2.1352e-04],
#                         [2.0287e-04, 2.0178e-04, 2.0658e-04],
#                         [2.0532e-04, 2.0188e-04, 2.0627e-04]],
#
#                        [[2.1027e-04, 2.1794e-04, 2.2636e-04],
#                         [2.0554e-04, 2.0672e-04, 2.1714e-04],
#                         [2.1172e-04, 2.0907e-04, 2.1543e-04]],
#
#                        [[2.1556e-04, 2.1765e-04, 2.1841e-04],
#                         [2.0830e-04, 2.0847e-04, 2.1364e-04],
#                         [2.1081e-04, 2.0778e-04, 2.1148e-04]]],
#
#
#                       [[[1.6085e-05, 1.5565e-05, 1.7104e-05],
#                         [1.7148e-05, 1.6831e-05, 1.7728e-05],
#                         [1.8505e-05, 1.8409e-05, 1.8601e-05]],
#
#                        [[2.4832e-05, 2.4329e-05, 2.5127e-05],
#                         [2.6308e-05, 2.5694e-05, 2.6069e-05],
#                         [2.8128e-05, 2.7367e-05, 2.7189e-05]],
#
#                        [[2.0202e-05, 1.9674e-05, 2.0870e-05],
#                         [2.0934e-05, 2.0637e-05, 2.1781e-05],
#                         [2.2241e-05, 2.2259e-05, 2.3103e-05]]],
#
#
#                       [[[3.3980e-04, 3.4490e-04, 3.4217e-04],
#                         [3.3322e-04, 3.4663e-04, 3.5604e-04],
#                         [3.4148e-04, 3.5633e-04, 3.5981e-04]],
#
#                        [[4.1691e-04, 4.2197e-04, 4.0789e-04],
#                         [3.9171e-04, 4.0375e-04, 4.1725e-04],
#                         [3.8889e-04, 4.0576e-04, 4.0922e-04]],
#
#                        [[3.4498e-04, 3.5486e-04, 3.4621e-04],
#                         [3.3817e-04, 3.5386e-04, 3.6166e-04],
#                         [3.4099e-04, 3.6568e-04, 3.6902e-04]]],
#
#
#                       [[[2.8855e-06, 2.6829e-06, 3.0377e-06],
#                         [3.0959e-06, 3.1511e-06, 3.3946e-06],
#                         [2.7412e-06, 2.8778e-06, 3.1088e-06]],
#
#                        [[3.8545e-06, 3.7693e-06, 4.1329e-06],
#                         [3.9803e-06, 4.1624e-06, 4.6277e-06],
#                         [3.7845e-06, 3.9397e-06, 4.3907e-06]],
#
#                        [[2.7120e-06, 2.6535e-06, 3.2413e-06],
#                         [3.3267e-06, 3.3123e-06, 3.6984e-06],
#                         [3.1626e-06, 3.3603e-06, 3.6213e-06]]],
#
#
#                       [[[2.5973e-05, 1.7266e-05, 1.2676e-05],
#                         [3.1580e-05, 2.1177e-05, 1.4490e-05],
#                         [2.3519e-05, 1.8029e-05, 1.3829e-05]],
#
#                        [[1.6953e-05, 8.7171e-06, 5.0290e-06],
#                         [1.8624e-05, 9.7101e-06, 4.6515e-06],
#                         [1.1509e-05, 7.3035e-06, 4.0031e-06]],
#
#                        [[1.5753e-05, 7.8946e-06, 5.6767e-06],
#                         [1.8970e-05, 9.6775e-06, 5.7558e-06],
#                         [1.4028e-05, 7.8881e-06, 5.4069e-06]]],
#
#
#                       [[[3.8741e-05, 3.9156e-05, 3.8145e-05],
#                         [3.6670e-05, 3.6837e-05, 3.5597e-05],
#                         [3.4740e-05, 3.4514e-05, 3.4945e-05]],
#
#                        [[4.4631e-05, 4.4912e-05, 4.5732e-05],
#                         [4.1858e-05, 4.0298e-05, 4.1060e-05],
#                         [4.1160e-05, 3.9401e-05, 4.1336e-05]],
#
#                        [[4.6053e-05, 4.4882e-05, 4.3463e-05],
#                         [4.3613e-05, 4.1507e-05, 4.0215e-05],
#                         [4.1175e-05, 3.9114e-05, 3.9299e-05]]],
#
#
#                       [[[8.7199e-06, 1.3574e-05, 1.7541e-05],
#                         [5.9339e-06, 9.0950e-06, 2.0320e-05],
#                         [8.4931e-06, 1.1561e-05, 2.4208e-05]],
#
#                        [[6.6672e-06, 1.3720e-05, 1.2400e-05],
#                         [4.4913e-06, 6.0942e-06, 8.2210e-06],
#                         [5.4180e-06, 6.0325e-06, 6.5377e-06]],
#
#                        [[6.2030e-06, 8.8986e-06, 1.1657e-05],
#                         [6.3854e-06, 5.8491e-06, 1.1364e-05],
#                         [6.4568e-06, 7.0841e-06, 1.4211e-05]]],
#
#
#                       [[[3.4473e-06, 2.1486e-06, 2.1251e-06],
#                         [2.7376e-06, 2.1473e-06, 2.8265e-06],
#                         [3.3039e-06, 2.6872e-06, 4.4115e-06]],
#
#                        [[4.7715e-06, 2.0343e-06, 2.5658e-06],
#                         [3.2114e-06, 1.3676e-06, 3.1704e-06],
#                         [4.4033e-06, 2.4032e-06, 4.9968e-06]],
#
#                        [[9.1855e-07, 1.9365e-06, 1.3915e-06],
#                         [1.1638e-06, 2.9597e-06, 1.8911e-06],
#                         [1.3818e-06, 3.2864e-06, 2.4340e-06]]],
#
#
#                       [[[8.4752e-06, 7.9573e-06, 7.5276e-06],
#                         [8.7642e-06, 7.9931e-06, 7.5887e-06],
#                       6.7948e-06, 8.5148e-06, 1.2285e-08, 8.5360e-06, 9.0747e-06, 1.1310e-08,
#                       8.8366e-06, 1.0842e-05, 9.8652e-06, 2.3391e-08, 7.5881e-06, 6.5332e-06,
#                       8.7594e-06, 9.3074e-06, 2.0886e-08, 7.4128e-06, 8.4126e-06, 3.4727e-06,
#                       3.1312e-06, 9.1386e-06, 1.0653e-05, 1.0164e-05, 1.0095e-05, 1.4227e-06,
#                       7.5629e-06, 8.7966e-06, 3.2312e-08, 1.3435e-07, 9.3068e-06, 5.2224e-06,
#                       9.5216e-06, 7.6777e-06, 8.6197e-06, 9.5221e-06, 7.6040e-06, 2.9649e-06,
#                       8.6986e-06, 9.4927e-06, 8.5990e-06, 9.5680e-06, 3.2424e-08, 6.6319e-06,
#                       1.0347e-05, 5.7050e-06, 2.7243e-08, 2.9508e-08, 9.6590e-06, 6.5542e-06,
#                       7.3685e-09, 9.3487e-06, 1.0354e-05, 4.4301e-06, 4.9756e-06, 1.1185e-05,
#                       5.3264e-06, 8.7125e-06, 1.0473e-05, 8.0144e-06, 1.4308e-08, 8.4080e-06,
#                       9.7708e-06, 8.5873e-06, 6.9176e-06, 7.6303e-06, 2.1361e-06, 1.5488e-08,
#                       1.1252e-07, 2.3021e-08, 9.7487e-06, 4.9353e-06, 8.8451e-06, 8.2410e-06,
#                       2.3085e-08, 8.6901e-06], device='cuda:0')},
#              Parameter containing:
#              tensor([[-3.3440e-02, -3.0425e-02, -2.2688e-02,  ..., -7.6555e-04,
#                        1.4883e-18, -4.7664e-02],
#                      [ 1.5082e-02,  1.8491e-02, -3.6583e-02,  ..., -5.2401e-02,
#                       -1.5368e-25, -3.3425e-02],
#                      [-3.8350e-02, -2.2488e-02,  1.5539e-03,  ..., -5.2769e-02,
#                        3.5893e-20, -4.7030e-02],
#                      ...,
#                      [ 3.4650e-02,  2.7983e-02, -4.3893e-02,  ...,  3.9059e-02,
#                       -4.0250e-23,  5.2514e-02],
#                      [ 2.7819e-02,  4.2993e-02,  2.0751e-02,  ...,  5.3304e-02,
#                        1.1552e-30,  5.1734e-02],
#                      [-5.1010e-02, -2.4689e-02,  7.9996e-02,  ..., -4.0124e-02,
#                        2.1128e-33, -7.5994e-03]], device='cuda:0', requires_grad=True): {'step': 6790,
#               'exp_avg': tensor([[-7.1031e-04, -6.8331e-04, -2.3459e-03,  ..., -1.7403e-03,
#                         1.7430e-20, -1.7095e-03],
#                       [-1.8323e-03, -7.7206e-04,  3.4608e-04,  ...,  1.0538e-03,
#                        -2.8306e-27, -9.7461e-05],
#                       [-5.2191e-04,  4.5389e-04, -2.3562e-03,  ..., -3.4947e-04,
#                         4.2940e-22,  4.6141e-04],
#                       ...,
#                       [-1.8313e-02,  1.2292e-03,  8.2495e-04,  ...,  6.1183e-03,
#                        -6.0567e-25, -1.5338e-03],
#                       [ 5.0344e-03,  9.5292e-04, -6.3120e-03,  ..., -6.6256e-03,
#                         1.9637e-33, -1.5885e-03],
#                       [ 2.2467e-04,  5.2251e-04,  1.8904e-03,  ...,  9.2628e-04,
#                         2.2256e-35, -1.8034e-05]], device='cuda:0'),
#               'exp_avg_sq': tensor([[7.1262e-05, 4.9869e-05, 6.7114e-05,  ..., 9.7448e-05, 1.5378e-07,
#                        4.3378e-05],
#                       [3.7940e-05, 7.2685e-05, 3.4719e-05,  ..., 4.6550e-05, 3.4929e-08,
#                        7.5965e-06],
#                       [5.1060e-06, 4.9265e-05, 8.4661e-05,  ..., 1.4269e-05, 1.2668e-07,
#                        2.3840e-05],
#                       ...,
#                       [4.3684e-04, 2.8632e-04, 1.2866e-05,  ..., 6.2020e-04, 4.5761e-08,
#                        3.7952e-04],
#                       [5.0342e-04, 7.4284e-04, 4.8694e-04,  ..., 1.4314e-03, 3.0810e-09,
#                        9.9560e-04],
#                       [5.3916e-05, 1.1642e-05, 1.0600e-03,  ..., 5.8210e-05, 9.6078e-09,
#                        7.2023e-07]], device='cuda:0')},
#              Parameter containing:
#              tensor([-0.0148, -0.0420, -0.0419, -0.0533, -0.0094, -0.0038,  0.0471,  0.0099,
#                       0.0079,  0.0293,  0.0320, -0.0039, -0.0338,  0.0125,  0.0059,  0.0152,
#                      -0.0439, -0.0259,  0.0090, -0.0612, -0.0116, -0.0352,  0.0135,  0.0230,
#                       0.0316, -0.0051,  0.0401,  0.0285,  0.0461,  0.0230,  0.0380,  0.0155,
#                      -0.0274,  0.0795, -0.0044,  0.0226,  0.0063,  0.0028, -0.0057, -0.0306,
#                       0.0025,  0.0202,  0.0405, -0.0133,  0.0046,  0.0238, -0.0572,  0.0141,
#                      -0.0057,  0.0031,  0.0349,  0.0259, -0.0088, -0.0163,  0.0033, -0.0263,
#                       0.0205, -0.0085,  0.0131,  0.0203,  0.0212, -0.0141,  0.0348, -0.0240,
#                      -0.0030, -0.0163, -0.0022,  0.0175, -0.0067,  0.0071, -0.0069,  0.0164,
#                      -0.0076,  0.0040, -0.0192,  0.0130,  0.0245, -0.0429,  0.0058, -0.0048,
#                       0.0002,  0.0756,  0.0492, -0.0069,  0.0140,  0.0063,  0.0034, -0.0408,
#                      -0.0498,  0.0188, -0.0189, -0.0128, -0.0288, -0.0211,  0.0094, -0.0109,
#                       0.0214,  0.0218, -0.0427, -0.0165, -0.0647], device='cuda:0',
#                     requires_grad=True): {'step': 6790,
#               'exp_avg': tensor([-1.2232e-03, -6.0705e-04, -1.0614e-03, -6.4710e-04,  5.1510e-04,
#                        6.9216e-04, -3.4613e-03,  2.2171e-03,  3.6348e-04,  2.3608e-03,
#                        6.8760e-03, -7.0182e-04, -1.6028e-03, -2.6190e-03,  2.1561e-03,
#                       -7.5034e-04,  2.9565e-04,  3.4021e-03,  1.6509e-03, -5.5057e-04,
#                       -1.1594e-04,  1.8670e-04,  3.5930e-03, -2.8942e-03, -3.1531e-03,
#                        1.7176e-03,  4.1494e-03, -4.0524e-03, -8.0206e-03,  7.8134e-04,
#                       -3.2089e-03, -3.3126e-04, -2.3055e-03,  1.8373e-03,  2.3991e-04,
#                        4.4022e-03, -2.0053e-03,  3.0445e-03,  5.4942e-04,  3.8641e-03,
#                        5.3050e-04,  4.0619e-06,  1.8343e-03, -1.0004e-03, -4.5554e-03,

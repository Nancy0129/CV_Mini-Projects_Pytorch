# %% [markdown]
# Removed a dense layer + weight initialize

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
import copy
warnings.filterwarnings("ignore")

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN8(nn.Module):
    def __init__(self):
        super(CNN8,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(3,16,3,1,1,bias=False),               
            nn.BatchNorm2d(16),
            nn.ReLU(), 
            nn.Conv2d(16,16,3,1,1,bias=False),               
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16,16,3,1,1,bias=False),               
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(16,32,3,1,1,bias=False),            
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32,32,3,1,1,bias=False),            
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32,32,3,1,1,bias=False),            
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(32,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),            
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(64,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(128,256,3,1,1,bias=False),            
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )


        self.dense1=nn.Sequential(
            nn.Linear(4*4*128,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(2048,1024),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
#         self.dense3=nn.Sequential(
#             nn.Linear(1024,512),
#             nn.ReLU()
#         )
       
        self.out=nn.Linear(1024,101)
        
        
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
#         x=self.dense3(x)
        output=self.out(x)
        return output       
cnn8=CNN8().cuda()

for m in cnn8.modules():
            if isinstance(m, (nn.Conv2d, nn.Linear)):
                nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('relu'))
            if isinstance(m, ( nn.Linear)):
                nn.init.constant_(m.bias, 0.0)

print(cnn8)
# Out:
# CNN8(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=2048, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=1024, out_features=101, bias=True)
# )

# %%
EPOCH = 70
BATCH_SIZE=64
LR=0.001
optimizer=torch.optim.Adam(cnn8.parameters(),lr=LR,weight_decay=0.01)
scheduler=torch.optim.lr_scheduler.StepLR(optimizer,step_size=10,gamma=0.5)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),
            torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5),
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=False, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=False, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
best_model_wts = copy.deepcopy(cnn8.state_dict())         #change
best_acc = 0.0

for epoch in range(EPOCH):
    print('Step:')
    cnn8.train()   #change
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn8(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()    
        
        if step%30==0:
            print(step)
            
    scheduler.step()        
    
    losses.append(loss.data)
    with torch.no_grad():
        cnn8.eval()   #change
        
        train_acc=[]
        for x,y in train_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn8(b_x)   #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0) 
            train_acc.append(accuracy)
            torch.cuda.empty_cache()
        train_acc=sum(train_acc)/len(train_acc)
        train_accs.append(train_acc)
        
        eval_acc=[]
        for x,y in eval_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn8(b_x)         #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0)
            eval_acc.append(accuracy)
            torch.cuda.empty_cache()
        eval_acc=sum(eval_acc)/len(eval_acc)
        eval_accs.append(eval_acc)
        
        
        if eval_acc>best_acc:
            best_acc = eval_acc
            best_model_wts = copy.deepcopy(cnn8.state_dict())         #change
            
    
    
    print('Epoch: %4s'%epoch,'| loss: ',loss.data,
            '| Train_acc: %6s'% train_acc.data,'| Eval_acc: %6s'%eval_acc.data) 
print('Best Eval acc: %6s'%best_acc)
# Out:
# Step:
# 0
# 30
# 60
# 90
# Epoch:    0 | loss:  tensor(4.2196, device='cuda:0') | Train_acc: tensor(0.0920, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.0790, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    1 | loss:  tensor(4.5963, device='cuda:0') | Train_acc: tensor(0.1306, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.1410, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    2 | loss:  tensor(3.7976, device='cuda:0') | Train_acc: tensor(0.2366, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2250, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    3 | loss:  tensor(2.8805, device='cuda:0') | Train_acc: tensor(0.2939, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2690, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    4 | loss:  tensor(2.9157, device='cuda:0') | Train_acc: tensor(0.3295, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2860, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    5 | loss:  tensor(3.2286, device='cuda:0') | Train_acc: tensor(0.3332, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3030, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    6 | loss:  tensor(3.1011, device='cuda:0') | Train_acc: tensor(0.4086, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3820, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    7 | loss:  tensor(2.7039, device='cuda:0') | Train_acc: tensor(0.4231, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4300, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    8 | loss:  tensor(2.6493, device='cuda:0') | Train_acc: tensor(0.4524, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4250, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    9 | loss:  tensor(2.2143, device='cuda:0') | Train_acc: tensor(0.4971, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4180, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   10 | loss:  tensor(2.6098, device='cuda:0') | Train_acc: tensor(0.5369, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5090, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   11 | loss:  tensor(2.1439, device='cuda:0') | Train_acc: tensor(0.5851, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5410, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   12 | loss:  tensor(2.1037, device='cuda:0') | Train_acc: tensor(0.5528, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5310, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   13 | loss:  tensor(1.0146, device='cuda:0') | Train_acc: tensor(0.6037, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5610, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   14 | loss:  tensor(2.4567, device='cuda:0') | Train_acc: tensor(0.6245, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5900, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   15 | loss:  tensor(1.5147, device='cuda:0') | Train_acc: tensor(0.6210, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5620, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   16 | loss:  tensor(0.9467, device='cuda:0') | Train_acc: tensor(0.6317, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5370, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   17 | loss:  tensor(1.6492, device='cuda:0') | Train_acc: tensor(0.6517, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6100, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   18 | loss:  tensor(2.1819, device='cuda:0') | Train_acc: tensor(0.6299, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5760, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   19 | loss:  tensor(2.0185, device='cuda:0') | Train_acc: tensor(0.6812, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6120, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   20 | loss:  tensor(0.8747, device='cuda:0') | Train_acc: tensor(0.7108, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6020, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   21 | loss:  tensor(1.8117, device='cuda:0') | Train_acc: tensor(0.7480, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6670, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   22 | loss:  tensor(1.4543, device='cuda:0') | Train_acc: tensor(0.7293, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6320, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   23 | loss:  tensor(1.1114, device='cuda:0') | Train_acc: tensor(0.7642, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6330, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   24 | loss:  tensor(1.0840, device='cuda:0') | Train_acc: tensor(0.7614, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6570, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   25 | loss:  tensor(1.3681, device='cuda:0') | Train_acc: tensor(0.7744, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6560, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   26 | loss:  tensor(0.9005, device='cuda:0') | Train_acc: tensor(0.7802, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6710, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   27 | loss:  tensor(1.0835, device='cuda:0') | Train_acc: tensor(0.7610, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6170, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   28 | loss:  tensor(1.8032, device='cuda:0') | Train_acc: tensor(0.8082, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6770, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   29 | loss:  tensor(1.2775, device='cuda:0') | Train_acc: tensor(0.7882, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6410, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   30 | loss:  tensor(0.4972, device='cuda:0') | Train_acc: tensor(0.8487, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6830, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   31 | loss:  tensor(0.6791, device='cuda:0') | Train_acc: tensor(0.8768, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6990, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   32 | loss:  tensor(0.8759, device='cuda:0') | Train_acc: tensor(0.8785, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7090, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   33 | loss:  tensor(0.5719, device='cuda:0') | Train_acc: tensor(0.8595, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6560, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   34 | loss:  tensor(0.5812, device='cuda:0') | Train_acc: tensor(0.8977, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7160, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   35 | loss:  tensor(0.6565, device='cuda:0') | Train_acc: tensor(0.9089, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7090, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   36 | loss:  tensor(0.8438, device='cuda:0') | Train_acc: tensor(0.9021, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7090, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   37 | loss:  tensor(0.5236, device='cuda:0') | Train_acc: tensor(0.8842, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6640, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   38 | loss:  tensor(0.6751, device='cuda:0') | Train_acc: tensor(0.9248, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7230, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   39 | loss:  tensor(0.5943, device='cuda:0') | Train_acc: tensor(0.9281, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7090, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   40 | loss:  tensor(0.2306, device='cuda:0') | Train_acc: tensor(0.9599, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7290, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   41 | loss:  tensor(0.3190, device='cuda:0') | Train_acc: tensor(0.9649, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7310, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   42 | loss:  tensor(0.4351, device='cuda:0') | Train_acc: tensor(0.9557, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7210, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   43 | loss:  tensor(0.3354, device='cuda:0') | Train_acc: tensor(0.9775, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7150, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   44 | loss:  tensor(0.2950, device='cuda:0') | Train_acc: tensor(0.9726, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7540, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   45 | loss:  tensor(0.6267, device='cuda:0') | Train_acc: tensor(0.9799, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7390, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   46 | loss:  tensor(0.4898, device='cuda:0') | Train_acc: tensor(0.9814, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7330, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   47 | loss:  tensor(0.3312, device='cuda:0') | Train_acc: tensor(0.9637, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7160, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   48 | loss:  tensor(0.4076, device='cuda:0') | Train_acc: tensor(0.9865, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7340, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   49 | loss:  tensor(0.4469, device='cuda:0') | Train_acc: tensor(0.9866, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7330, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   50 | loss:  tensor(0.5361, device='cuda:0') | Train_acc: tensor(0.9908, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7490, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   51 | loss:  tensor(0.1898, device='cuda:0') | Train_acc: tensor(0.9932, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7500, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   52 | loss:  tensor(0.3693, device='cuda:0') | Train_acc: tensor(0.9953, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7280, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   53 | loss:  tensor(0.4340, device='cuda:0') | Train_acc: tensor(0.9955, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7370, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   54 | loss:  tensor(0.1531, device='cuda:0') | Train_acc: tensor(0.9949, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7430, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   55 | loss:  tensor(0.1107, device='cuda:0') | Train_acc: tensor(0.9960, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7550, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   56 | loss:  tensor(0.3554, device='cuda:0') | Train_acc: tensor(0.9945, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7260, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   57 | loss:  tensor(0.1621, device='cuda:0') | Train_acc: tensor(0.9951, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7410, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   58 | loss:  tensor(0.3901, device='cuda:0') | Train_acc: tensor(0.9973, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7380, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   59 | loss:  tensor(0.1632, device='cuda:0') | Train_acc: tensor(0.9968, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7360, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   60 | loss:  tensor(0.1557, device='cuda:0') | Train_acc: tensor(0.9973, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7570, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   61 | loss:  tensor(0.2479, device='cuda:0') | Train_acc: tensor(0.9982, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7330, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   62 | loss:  tensor(0.3763, device='cuda:0') | Train_acc: tensor(0.9984, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7510, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   63 | loss:  tensor(0.1679, device='cuda:0') | Train_acc: tensor(0.9981, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7500, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   64 | loss:  tensor(0.1397, device='cuda:0') | Train_acc: tensor(0.9985, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7570, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   65 | loss:  tensor(0.1657, device='cuda:0') | Train_acc: tensor(0.9977, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7420, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   66 | loss:  tensor(0.1180, device='cuda:0') | Train_acc: tensor(0.9982, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7410, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   67 | loss:  tensor(0.1651, device='cuda:0') | Train_acc: tensor(0.9990, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7450, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   68 | loss:  tensor(0.1477, device='cuda:0') | Train_acc: tensor(0.9989, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7520, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   69 | loss:  tensor(0.2040, device='cuda:0') | Train_acc: tensor(0.9984, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7420, device='cuda:0', dtype=torch.float64)
# Best Eval acc: tensor(0.7570, device='cuda:0', dtype=torch.float64)

# %%
x=np.arange(len(losses))
plt.plot(x,losses)
plt.title('CNN8 TRY 3')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN8 TRY3')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
torch.save(cnn8.state_dict(),'CNN8 try3 70E.pkl')

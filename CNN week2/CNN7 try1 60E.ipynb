# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
warnings.filterwarnings("ignore")

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN7(nn.Module):
    def __init__(self):
        super(CNN7,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(
                in_channels=3,    #前面的层有多高
                out_channels=32,   #filter 的个数
                kernel_size=7,
                stride=1,
                padding=(3,3)  # if stride=1, padding=(kernel_size-1)/2
            ), 
            nn.ReLU(),   
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(32,64,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(64,128,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(128,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv7=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )


        self.dense1=nn.Sequential(
            nn.Linear(2*2*256,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(2048,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(2048,1024),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(1024,101)
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=self.conv7(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn7=CNN7().cuda()
print(cnn7)

# %%
EPOCH = 30
BATCH_SIZE=64
LR=0.001
optimizer=torch.optim.Adam(cnn7.parameters(),lr=LR,weight_decay=0.001)
torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, 
    verbose=True, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),
            torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5),
            torchvision.transforms.ToTensor()]))

eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
    torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=True, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=True, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
for epoch in range(EPOCH):
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn7(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if step%10==0:
            with torch.no_grad():
                pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                train_accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                train_accs.append(train_accuracy)
                losses.append(loss.data)
                torch.cuda.empty_cache()
                eval_acc=[]
                for x,y in eval_loader:
                    b_x=Variable(x).cuda()
                    b_y=Variable(y).cuda()        
                    output=cnn7(b_x)         #change
                    pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                    accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                    eval_acc.append(accuracy)
                eval_accs.append(np.mean(eval_acc))
                print('Epoch: ',epoch,'| Step: ',step,'| loss: ',loss.data,
                      '| Train_acc: ', train_accuracy,'| Eval_acc: ', np.mean(eval_acc))
# Out:
# Epoch:  0 | Step:  0 | loss:  tensor(0.5539, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.647
# Epoch:  0 | Step:  10 | loss:  tensor(0.6249, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6689999999999999
# Epoch:  0 | Step:  20 | loss:  tensor(0.6785, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6060000000000001
# Epoch:  0 | Step:  30 | loss:  tensor(0.5358, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6530000000000001
# Epoch:  0 | Step:  40 | loss:  tensor(0.8118, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.652
# Epoch:  0 | Step:  50 | loss:  tensor(0.8207, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.636
# Epoch:  0 | Step:  60 | loss:  tensor(0.9695, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.612
# Epoch:  0 | Step:  70 | loss:  tensor(0.6977, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.591
# Epoch:  0 | Step:  80 | loss:  tensor(0.7804, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6439999999999999
# Epoch:  0 | Step:  90 | loss:  tensor(0.6400, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.587
# Epoch:  1 | Step:  0 | loss:  tensor(0.5351, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6419999999999999
# Epoch:  1 | Step:  10 | loss:  tensor(0.6571, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.621
# Epoch:  1 | Step:  20 | loss:  tensor(1.0785, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.618
# Epoch:  1 | Step:  30 | loss:  tensor(0.6237, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.638
# Epoch:  1 | Step:  40 | loss:  tensor(0.7854, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.631
# Epoch:  1 | Step:  50 | loss:  tensor(0.5938, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.617
# Epoch:  1 | Step:  60 | loss:  tensor(0.8086, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.659
# Epoch:  1 | Step:  70 | loss:  tensor(0.9076, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.628
# Epoch:  1 | Step:  80 | loss:  tensor(1.2390, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6540000000000001
# Epoch:  1 | Step:  90 | loss:  tensor(0.5933, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.63
# Epoch:  2 | Step:  0 | loss:  tensor(0.5350, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6529999999999999
# Epoch:  2 | Step:  10 | loss:  tensor(0.7156, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6369999999999999
# Epoch:  2 | Step:  20 | loss:  tensor(0.8592, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.61
# Epoch:  2 | Step:  30 | loss:  tensor(0.5273, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.608
# Epoch:  2 | Step:  40 | loss:  tensor(0.5559, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6420000000000001
# Epoch:  2 | Step:  50 | loss:  tensor(0.8085, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.588
# Epoch:  2 | Step:  60 | loss:  tensor(0.6696, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.666
# Epoch:  2 | Step:  70 | loss:  tensor(1.1202, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.663
# Epoch:  2 | Step:  80 | loss:  tensor(0.9603, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.607
# Epoch:  2 | Step:  90 | loss:  tensor(0.8420, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.659
# Epoch:  3 | Step:  0 | loss:  tensor(0.8367, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.611
# Epoch:  3 | Step:  10 | loss:  tensor(0.7798, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.619
# Epoch:  3 | Step:  20 | loss:  tensor(0.7119, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6540000000000001
# Epoch:  3 | Step:  30 | loss:  tensor(0.6394, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.63
# Epoch:  3 | Step:  40 | loss:  tensor(0.4360, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.662
# Epoch:  3 | Step:  50 | loss:  tensor(0.6285, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.667
# Epoch:  3 | Step:  60 | loss:  tensor(0.5498, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.647
# Epoch:  3 | Step:  70 | loss:  tensor(1.0521, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6130000000000001
# Epoch:  3 | Step:  80 | loss:  tensor(0.6394, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.635
# Epoch:  3 | Step:  90 | loss:  tensor(0.5847, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.628
# Epoch:  4 | Step:  0 | loss:  tensor(0.7033, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.613
# Epoch:  4 | Step:  10 | loss:  tensor(0.7648, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5940000000000001
# Epoch:  4 | Step:  20 | loss:  tensor(0.9032, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6279999999999999
# Epoch:  4 | Step:  30 | loss:  tensor(0.6537, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.683
# Epoch:  4 | Step:  40 | loss:  tensor(0.4895, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.608
# Epoch:  4 | Step:  50 | loss:  tensor(0.5803, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6549999999999999
# Epoch:  4 | Step:  60 | loss:  tensor(0.5249, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.596
# Epoch:  4 | Step:  70 | loss:  tensor(0.5413, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.658
# Epoch:  4 | Step:  80 | loss:  tensor(0.7770, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6220000000000001
# Epoch:  4 | Step:  90 | loss:  tensor(0.8397, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.661
# Epoch:  5 | Step:  0 | loss:  tensor(0.2424, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.679
# Epoch:  5 | Step:  10 | loss:  tensor(0.6217, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.623
# Epoch:  5 | Step:  20 | loss:  tensor(0.3242, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.603
# Epoch:  5 | Step:  30 | loss:  tensor(0.6750, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.65
# Epoch:  5 | Step:  40 | loss:  tensor(0.5353, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.637
# Epoch:  5 | Step:  50 | loss:  tensor(1.0440, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.618
# Epoch:  5 | Step:  60 | loss:  tensor(0.5966, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.641
# Epoch:  5 | Step:  70 | loss:  tensor(0.9124, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6529999999999999
# Epoch:  5 | Step:  80 | loss:  tensor(0.6063, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6479999999999999
# Epoch:  5 | Step:  90 | loss:  tensor(0.8501, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6519999999999999
# Epoch:  6 | Step:  0 | loss:  tensor(0.6157, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.652
# Epoch:  6 | Step:  10 | loss:  tensor(0.7423, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.655
# Epoch:  6 | Step:  20 | loss:  tensor(0.5862, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.646
# Epoch:  6 | Step:  30 | loss:  tensor(0.3896, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6050000000000001
# Epoch:  6 | Step:  40 | loss:  tensor(0.4275, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.645
# Epoch:  6 | Step:  50 | loss:  tensor(0.4168, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6599999999999999
# Epoch:  6 | Step:  60 | loss:  tensor(0.5084, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.619
# Epoch:  6 | Step:  70 | loss:  tensor(0.3860, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.638
# Epoch:  6 | Step:  80 | loss:  tensor(0.4082, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.648
# Epoch:  6 | Step:  90 | loss:  tensor(0.7668, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6280000000000001
# Epoch:  7 | Step:  0 | loss:  tensor(0.6293, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.67
# Epoch:  7 | Step:  10 | loss:  tensor(1.2639, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.648
# Epoch:  7 | Step:  20 | loss:  tensor(0.7048, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6449999999999999
# Epoch:  7 | Step:  30 | loss:  tensor(0.4881, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.659
# Epoch:  7 | Step:  40 | loss:  tensor(0.5944, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.655
# Epoch:  7 | Step:  50 | loss:  tensor(0.7280, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6439999999999999
# Epoch:  7 | Step:  60 | loss:  tensor(0.6989, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.629
# Epoch:  7 | Step:  70 | loss:  tensor(0.6654, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.611
# Epoch:  7 | Step:  80 | loss:  tensor(0.3729, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.625
# Epoch:  7 | Step:  90 | loss:  tensor(0.7497, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6540000000000001
# Epoch:  8 | Step:  0 | loss:  tensor(0.3634, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.617
# Epoch:  8 | Step:  10 | loss:  tensor(0.4951, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.635
# Epoch:  8 | Step:  20 | loss:  tensor(0.4645, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6180000000000001
# Epoch:  8 | Step:  30 | loss:  tensor(0.5054, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.664
# Epoch:  8 | Step:  40 | loss:  tensor(0.4181, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.636
# Epoch:  8 | Step:  50 | loss:  tensor(0.7256, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6479999999999999
# Epoch:  8 | Step:  60 | loss:  tensor(0.3043, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6339999999999999
# Epoch:  8 | Step:  70 | loss:  tensor(0.8103, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.649
# Epoch:  8 | Step:  80 | loss:  tensor(0.5650, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6709999999999999
# Epoch:  8 | Step:  90 | loss:  tensor(0.4668, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6479999999999999
# Epoch:  9 | Step:  0 | loss:  tensor(0.4471, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6779999999999999
# Epoch:  9 | Step:  10 | loss:  tensor(1.0300, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.639
# Epoch:  9 | Step:  20 | loss:  tensor(0.4587, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6300000000000001
# Epoch:  9 | Step:  30 | loss:  tensor(0.6175, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.667
# Epoch:  9 | Step:  40 | loss:  tensor(0.3514, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6260000000000001
# Epoch:  9 | Step:  50 | loss:  tensor(0.6078, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.665
# Epoch:  9 | Step:  60 | loss:  tensor(0.7014, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.657
# Epoch:  9 | Step:  70 | loss:  tensor(0.5896, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.624
# Epoch:  9 | Step:  80 | loss:  tensor(0.4931, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.632
# Epoch:  9 | Step:  90 | loss:  tensor(0.6603, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.623
# Epoch:  10 | Step:  0 | loss:  tensor(0.5487, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.629
# Epoch:  10 | Step:  10 | loss:  tensor(0.3835, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6380000000000001
# Epoch:  10 | Step:  20 | loss:  tensor(0.5286, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.637
# Epoch:  10 | Step:  30 | loss:  tensor(0.4500, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.677
# Epoch:  10 | Step:  40 | loss:  tensor(0.5444, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.65
# Epoch:  10 | Step:  50 | loss:  tensor(0.5650, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6
# Epoch:  10 | Step:  60 | loss:  tensor(0.3345, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.649
# Epoch:  10 | Step:  70 | loss:  tensor(0.5015, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.637
# Epoch:  10 | Step:  80 | loss:  tensor(0.5017, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.644
# Epoch:  10 | Step:  90 | loss:  tensor(0.5196, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6399999999999999
# Epoch:  11 | Step:  0 | loss:  tensor(0.4189, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.664
# Epoch:  11 | Step:  10 | loss:  tensor(0.4256, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6380000000000001
# Epoch:  11 | Step:  20 | loss:  tensor(0.8924, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.636
# Epoch:  11 | Step:  30 | loss:  tensor(0.3631, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6489999999999999
# Epoch:  11 | Step:  40 | loss:  tensor(0.4019, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6609999999999999
# Epoch:  11 | Step:  50 | loss:  tensor(0.3575, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.641
# Epoch:  11 | Step:  60 | loss:  tensor(0.3757, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.615
# Epoch:  11 | Step:  70 | loss:  tensor(0.3342, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.651
# Epoch:  11 | Step:  80 | loss:  tensor(0.2390, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.629
# Epoch:  11 | Step:  90 | loss:  tensor(0.6392, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6689999999999999
# Epoch:  12 | Step:  0 | loss:  tensor(0.8937, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5880000000000001
# Epoch:  12 | Step:  10 | loss:  tensor(0.3117, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6769999999999999
# Epoch:  12 | Step:  20 | loss:  tensor(0.6497, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.665
# Epoch:  12 | Step:  30 | loss:  tensor(0.6405, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.627
# Epoch:  12 | Step:  40 | loss:  tensor(0.3671, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.606
# Epoch:  12 | Step:  50 | loss:  tensor(0.4029, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.639
# Epoch:  12 | Step:  60 | loss:  tensor(0.5035, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.658
# Epoch:  12 | Step:  70 | loss:  tensor(0.7574, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.638
# Epoch:  12 | Step:  80 | loss:  tensor(0.3445, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6489999999999999
# Epoch:  12 | Step:  90 | loss:  tensor(0.5002, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.626
# Epoch:  13 | Step:  0 | loss:  tensor(0.4982, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.687
# Epoch:  13 | Step:  10 | loss:  tensor(0.5062, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.682
# Epoch:  13 | Step:  20 | loss:  tensor(0.4986, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.659
# Epoch:  13 | Step:  30 | loss:  tensor(0.4477, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.66
# Epoch:  13 | Step:  40 | loss:  tensor(1.0662, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.693
# Epoch:  13 | Step:  50 | loss:  tensor(0.5478, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6439999999999999
# Epoch:  13 | Step:  60 | loss:  tensor(0.4311, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.65
# Epoch:  13 | Step:  70 | loss:  tensor(0.4317, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6609999999999999
# Epoch:  13 | Step:  80 | loss:  tensor(0.2926, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.617
# Epoch:  13 | Step:  90 | loss:  tensor(0.2314, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.645
# Epoch:  14 | Step:  0 | loss:  tensor(0.5458, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6900000000000001
# Epoch:  14 | Step:  10 | loss:  tensor(0.6038, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.681
# Epoch:  14 | Step:  20 | loss:  tensor(0.3360, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.633
# Epoch:  14 | Step:  30 | loss:  tensor(0.6776, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.638
# Epoch:  14 | Step:  40 | loss:  tensor(0.5770, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.643
# Epoch:  14 | Step:  50 | loss:  tensor(0.7216, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.63
# Epoch:  14 | Step:  60 | loss:  tensor(0.4724, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.588
# Epoch:  14 | Step:  70 | loss:  tensor(0.1689, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6260000000000001
# Epoch:  14 | Step:  80 | loss:  tensor(0.6397, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.619
# Epoch:  14 | Step:  90 | loss:  tensor(0.8217, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.604
# Epoch:  15 | Step:  0 | loss:  tensor(0.6017, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.663
# Epoch:  15 | Step:  10 | loss:  tensor(0.6145, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.639
# Epoch:  15 | Step:  20 | loss:  tensor(0.6845, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.679
# Epoch:  15 | Step:  30 | loss:  tensor(0.4655, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.679
# Epoch:  15 | Step:  40 | loss:  tensor(0.3423, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.627
# Epoch:  15 | Step:  50 | loss:  tensor(0.5115, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.628
# Epoch:  15 | Step:  60 | loss:  tensor(0.1762, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.635
# Epoch:  15 | Step:  70 | loss:  tensor(0.4830, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6779999999999999
# Epoch:  15 | Step:  80 | loss:  tensor(0.3030, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.649
# Epoch:  15 | Step:  90 | loss:  tensor(0.3335, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.633
# Epoch:  16 | Step:  0 | loss:  tensor(0.3955, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.638
# Epoch:  16 | Step:  10 | loss:  tensor(0.7239, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.667
# Epoch:  16 | Step:  20 | loss:  tensor(0.3709, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6540000000000001
# Epoch:  16 | Step:  30 | loss:  tensor(0.2756, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.63
# Epoch:  16 | Step:  40 | loss:  tensor(0.4449, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.663
# Epoch:  16 | Step:  50 | loss:  tensor(0.4217, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.659
# Epoch:  16 | Step:  60 | loss:  tensor(0.4533, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.627
# Epoch:  16 | Step:  70 | loss:  tensor(0.7316, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.615
# Epoch:  16 | Step:  80 | loss:  tensor(0.4930, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.5880000000000001
# Epoch:  16 | Step:  90 | loss:  tensor(0.4314, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6220000000000001
# Epoch:  17 | Step:  0 | loss:  tensor(0.3120, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6609999999999999
# Epoch:  17 | Step:  10 | loss:  tensor(0.3292, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6679999999999999
# Epoch:  17 | Step:  20 | loss:  tensor(0.2626, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6559999999999999
# Epoch:  17 | Step:  30 | loss:  tensor(0.2833, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.646
# Epoch:  17 | Step:  40 | loss:  tensor(0.2482, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.646
# Epoch:  17 | Step:  50 | loss:  tensor(0.5123, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6359999999999999
# Epoch:  17 | Step:  60 | loss:  tensor(0.2538, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.638
# Epoch:  17 | Step:  70 | loss:  tensor(0.2810, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.608
# Epoch:  17 | Step:  80 | loss:  tensor(0.2322, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.666
# Epoch:  17 | Step:  90 | loss:  tensor(0.3436, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.627
# Epoch:  18 | Step:  0 | loss:  tensor(0.2736, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6359999999999999
# Epoch:  18 | Step:  10 | loss:  tensor(0.5839, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6319999999999999
# Epoch:  18 | Step:  20 | loss:  tensor(0.3694, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6449999999999999
# Epoch:  18 | Step:  30 | loss:  tensor(0.2850, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.679
# Epoch:  18 | Step:  40 | loss:  tensor(0.2449, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.6599999999999999
# Epoch:  18 | Step:  50 | loss:  tensor(0.4405, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6859999999999999
# Epoch:  18 | Step:  60 | loss:  tensor(0.3836, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.63
# Epoch:  18 | Step:  70 | loss:  tensor(0.7786, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.654
# Epoch:  18 | Step:  80 | loss:  tensor(0.5200, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.655
# Epoch:  18 | Step:  90 | loss:  tensor(0.5682, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.638
# Epoch:  19 | Step:  0 | loss:  tensor(0.2807, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.669
# Epoch:  19 | Step:  10 | loss:  tensor(0.2232, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.674
# Epoch:  19 | Step:  20 | loss:  tensor(0.4698, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.674
# Epoch:  19 | Step:  30 | loss:  tensor(0.3659, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5900000000000001
# Epoch:  19 | Step:  40 | loss:  tensor(0.4190, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.65
# Epoch:  19 | Step:  50 | loss:  tensor(0.5260, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.665
# Epoch:  19 | Step:  60 | loss:  tensor(0.2036, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.679
# Epoch:  19 | Step:  70 | loss:  tensor(0.3595, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6900000000000001
# Epoch:  19 | Step:  80 | loss:  tensor(0.3325, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.649
# Epoch:  19 | Step:  90 | loss:  tensor(0.2983, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.659
# Epoch:  20 | Step:  0 | loss:  tensor(0.3476, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.645
# Epoch:  20 | Step:  10 | loss:  tensor(0.4903, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.628
# Epoch:  20 | Step:  20 | loss:  tensor(0.3868, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6599999999999999
# Epoch:  20 | Step:  30 | loss:  tensor(0.6948, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.638
# Epoch:  20 | Step:  40 | loss:  tensor(0.5872, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6599999999999999
# Epoch:  20 | Step:  50 | loss:  tensor(0.4096, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6370000000000001
# Epoch:  20 | Step:  60 | loss:  tensor(0.1964, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.624
# Epoch:  20 | Step:  70 | loss:  tensor(0.5810, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.658
# Epoch:  20 | Step:  80 | loss:  tensor(0.4565, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.675
# Epoch:  20 | Step:  90 | loss:  tensor(0.7595, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6170000000000001
# Epoch:  21 | Step:  0 | loss:  tensor(0.4217, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.631
# Epoch:  21 | Step:  10 | loss:  tensor(0.3933, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.649
# Epoch:  21 | Step:  20 | loss:  tensor(0.4042, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.617
# Epoch:  21 | Step:  30 | loss:  tensor(0.3929, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.646
# Epoch:  21 | Step:  40 | loss:  tensor(0.3425, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6960000000000001
# Epoch:  21 | Step:  50 | loss:  tensor(0.5652, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.672
# Epoch:  21 | Step:  60 | loss:  tensor(0.3453, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6050000000000001
# Epoch:  21 | Step:  70 | loss:  tensor(0.4949, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6319999999999999
# Epoch:  21 | Step:  80 | loss:  tensor(0.7091, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.618
# Epoch:  21 | Step:  90 | loss:  tensor(0.4564, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.665
# Epoch:  22 | Step:  0 | loss:  tensor(0.2261, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6549999999999999
# Epoch:  22 | Step:  10 | loss:  tensor(0.3372, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.673
# Epoch:  22 | Step:  20 | loss:  tensor(0.3872, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6400000000000001
# Epoch:  22 | Step:  30 | loss:  tensor(0.1469, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.646
# Epoch:  22 | Step:  40 | loss:  tensor(0.2859, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.675
# Epoch:  22 | Step:  50 | loss:  tensor(0.4552, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.649
# Epoch:  22 | Step:  60 | loss:  tensor(0.3464, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.645
# Epoch:  22 | Step:  70 | loss:  tensor(0.3203, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.617
# Epoch:  22 | Step:  80 | loss:  tensor(0.2460, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.666
# Epoch:  22 | Step:  90 | loss:  tensor(0.3619, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.677
# Epoch:  23 | Step:  0 | loss:  tensor(0.4510, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.654
# Epoch:  23 | Step:  10 | loss:  tensor(0.3278, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.621
# Epoch:  23 | Step:  20 | loss:  tensor(0.2625, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.659
# Epoch:  23 | Step:  30 | loss:  tensor(0.2800, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.645
# Epoch:  23 | Step:  40 | loss:  tensor(0.6210, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.63
# Epoch:  23 | Step:  50 | loss:  tensor(0.5359, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.655
# Epoch:  23 | Step:  60 | loss:  tensor(0.6792, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6529999999999999
# Epoch:  23 | Step:  70 | loss:  tensor(0.3501, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.608
# Epoch:  23 | Step:  80 | loss:  tensor(0.2311, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.646
# Epoch:  23 | Step:  90 | loss:  tensor(0.4550, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.631
# Epoch:  24 | Step:  0 | loss:  tensor(0.3386, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.626
# Epoch:  24 | Step:  10 | loss:  tensor(0.4608, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5619999999999999
# Epoch:  24 | Step:  20 | loss:  tensor(0.3660, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.647
# Epoch:  24 | Step:  30 | loss:  tensor(0.6331, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.616
# Epoch:  24 | Step:  40 | loss:  tensor(0.3063, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.655
# Epoch:  24 | Step:  50 | loss:  tensor(0.2292, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.636
# Epoch:  24 | Step:  60 | loss:  tensor(0.4592, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.592
# Epoch:  24 | Step:  70 | loss:  tensor(0.2727, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.663
# Epoch:  24 | Step:  80 | loss:  tensor(0.3243, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6319999999999999
# Epoch:  24 | Step:  90 | loss:  tensor(0.2872, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.652
# Epoch:  25 | Step:  0 | loss:  tensor(0.2380, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.6530000000000001
# Epoch:  25 | Step:  10 | loss:  tensor(0.1346, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.607
# Epoch:  25 | Step:  20 | loss:  tensor(0.3224, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.633
# Epoch:  25 | Step:  30 | loss:  tensor(0.2812, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6679999999999999
# Epoch:  25 | Step:  40 | loss:  tensor(0.4989, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.661
# Epoch:  25 | Step:  50 | loss:  tensor(0.3120, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.612
# Epoch:  25 | Step:  60 | loss:  tensor(0.4609, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.641
# Epoch:  25 | Step:  70 | loss:  tensor(0.4196, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.677
# Epoch:  25 | Step:  80 | loss:  tensor(0.6686, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.645
# Epoch:  25 | Step:  90 | loss:  tensor(0.6181, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6020000000000001
# Epoch:  26 | Step:  0 | loss:  tensor(0.2140, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.633
# Epoch:  26 | Step:  10 | loss:  tensor(0.4755, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.635
# Epoch:  26 | Step:  20 | loss:  tensor(0.2904, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.651
# Epoch:  26 | Step:  30 | loss:  tensor(0.3725, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.642
# Epoch:  26 | Step:  40 | loss:  tensor(0.2574, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.671
# Epoch:  26 | Step:  50 | loss:  tensor(0.4708, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.651
# Epoch:  26 | Step:  60 | loss:  tensor(0.5142, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.623
# Epoch:  26 | Step:  70 | loss:  tensor(0.1700, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.6529999999999999
# Epoch:  26 | Step:  80 | loss:  tensor(0.5714, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6420000000000001
# Epoch:  26 | Step:  90 | loss:  tensor(0.3737, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.662
# Epoch:  27 | Step:  0 | loss:  tensor(0.3307, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.643
# Epoch:  27 | Step:  10 | loss:  tensor(0.3419, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.653
# Epoch:  27 | Step:  20 | loss:  tensor(0.3419, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.627
# Epoch:  27 | Step:  30 | loss:  tensor(0.1996, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.617
# Epoch:  27 | Step:  40 | loss:  tensor(0.4037, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.667
# Epoch:  27 | Step:  50 | loss:  tensor(0.6247, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6340000000000001
# Epoch:  27 | Step:  60 | loss:  tensor(0.4625, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6540000000000001
# Epoch:  27 | Step:  70 | loss:  tensor(0.3744, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6799999999999999
# Epoch:  27 | Step:  80 | loss:  tensor(0.5640, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6460000000000001
# Epoch:  27 | Step:  90 | loss:  tensor(0.3254, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.654
# Epoch:  28 | Step:  0 | loss:  tensor(0.2040, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.665
# Epoch:  28 | Step:  10 | loss:  tensor(0.1460, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.658
# Epoch:  28 | Step:  20 | loss:  tensor(0.2456, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6140000000000001
# Epoch:  28 | Step:  30 | loss:  tensor(0.3931, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.666
# Epoch:  28 | Step:  40 | loss:  tensor(0.4192, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6450000000000001
# Epoch:  28 | Step:  50 | loss:  tensor(0.4286, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.66
# Epoch:  28 | Step:  60 | loss:  tensor(0.7441, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.67
# Epoch:  28 | Step:  70 | loss:  tensor(0.7267, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6200000000000001
# Epoch:  28 | Step:  80 | loss:  tensor(0.3679, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.653
# Epoch:  28 | Step:  90 | loss:  tensor(0.2763, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.666
# Epoch:  29 | Step:  0 | loss:  tensor(0.3282, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.653
# Epoch:  29 | Step:  10 | loss:  tensor(0.3060, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.652
# Epoch:  29 | Step:  20 | loss:  tensor(0.3257, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6519999999999999
# Epoch:  29 | Step:  30 | loss:  tensor(0.4619, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6519999999999999
# Epoch:  29 | Step:  40 | loss:  tensor(0.2759, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6220000000000001
# Epoch:  29 | Step:  50 | loss:  tensor(0.2794, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6409999999999999
# Epoch:  29 | Step:  60 | loss:  tensor(0.4513, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.639
# Epoch:  29 | Step:  70 | loss:  tensor(0.4698, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.647
# Epoch:  29 | Step:  80 | loss:  tensor(0.4208, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.63
# Epoch:  29 | Step:  90 | loss:  tensor(0.3196, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.625

# %%
x=3000+np.arange(len(losses))*10
plt.plot(x,losses)
plt.title('CNN7 TRY 1 30-60E')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN7 TRY 1 30-60E')
plt.xlabel('Step')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
train_acc=[]
with torch.no_grad():
    for x,y in train_loader:
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()        
        output=cnn7(b_x)
        pred_y=torch.max(output,1)[1].cuda().data.squeeze()
        accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
        train_acc.append(accuracy)
train_acc
# Out:
# [0.921875,
#  0.90625,
#  0.875,
#  0.859375,
#  0.96875,
#  0.890625,
#  0.90625,
#  0.890625,
#  0.921875,
#  0.953125,
#  0.921875,
#  0.875,
#  0.921875,
#  0.9375,
#  1.0,
#  0.9375,
#  0.9375,
#  0.875,
#  0.9375,
#  0.96875,
#  0.875,
#  0.90625,
#  0.859375,
#  0.921875,
#  0.859375,
#  0.890625,
#  0.9375,
#  0.890625,
#  0.90625,
#  0.875,
#  0.921875,
#  0.890625,
#  0.84375,
#  0.875,
#  0.859375,
#  0.890625,
#  0.96875,
#  0.859375,
#  0.875,
#  0.875,
#  0.921875,
#  0.96875,
#  0.890625,
#  0.859375,
#  0.90625,
#  0.828125,
#  0.90625,
#  0.9375,
#  0.9375,
#  0.921875,
#  0.9375,
#  0.921875,
#  0.875,
#  0.875,
#  0.90625,
#  0.953125,
#  0.890625,
#  0.96875,
#  0.953125,
#  0.90625,
#  0.953125,
#  0.921875,
#  0.90625,
#  0.921875,
#  0.96875,
#  0.9375,
#  0.984375,
#  0.9375,
#  0.9375,
#  0.875,
#  0.90625,
#  0.84375,
#  0.875,
#  0.921875,
#  0.84375,
#  0.96875,
#  0.984375,
#  0.890625,
#  0.9375,
#  0.9375,
#  0.90625,
#  0.875,
#  0.890625,
#  0.921875,
#  0.921875,
#  0.953125,
#  0.921875,
#  0.84375,
#  0.890625,
#  0.890625,
#  0.921875,
#  0.890625,
#  0.875,
#  0.875,
#  0.9375,
#  0.9375,
#  0.8888888888888888]

# %%
eval_acc=[]
with torch.no_grad():
    for x,y in eval_loader:
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()        
        output=cnn7(b_x)
        pred_y=torch.max(output,1)[1].cuda().data.squeeze()
        accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
        eval_acc.append(accuracy)
eval_acc
# Out:
# [0.615, 0.635, 0.66, 0.645, 0.7]

# %%
test_acc=[]
with torch.no_grad():
    for x,y in eval_loader:
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()        
        output=cnn7(b_x)
        pred_y=torch.max(output,1)[1].cuda().data.squeeze()
        accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
        test_acc.append(accuracy)
test_acc
# Out:
# [0.67, 0.67, 0.59, 0.68, 0.55]

# %%
np.mean(train_acc)
# Out:
# 0.9097759163802978

# %%
np.mean(eval_acc)
# Out:
# 0.651

# %%
np.mean(test_acc)
# Out:
# 0.632

# %% [markdown]
# Decreased the batch size

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Xinmeng\AppData\Roaming\Python\Python35\site-packages\pandas\compat\_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.1.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN7(nn.Module):
    def __init__(self):
        super(CNN7,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(
                in_channels=3,    #前面的层有多高
                out_channels=64,   #filter 的个数
                kernel_size=7,
                stride=1,
                padding=(3,3)  # if stride=1, padding=(kernel_size-1)/2
            ), 
            nn.ReLU(),   
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(64,64,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(64,128,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(128,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv7=nn.Sequential(
            nn.Conv2d(256,512,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(512),
            nn.MaxPool2d(2)
        )


        self.dense1=nn.Sequential(
            nn.Linear(2*2*512,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(2048,4096),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(4096,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(2048,101)
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=self.conv7(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn7=CNN7().cuda()
print(cnn7)
# Out:
# CNN7(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv7): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=2048, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=2048, out_features=4096, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense3): Sequential(
#     (0): Linear(in_features=4096, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=2048, out_features=101, bias=True)
# )

# %%
EPOCH = 30
BATCH_SIZE=32
LR=0.001
optimizer=torch.optim.Adam(cnn7.parameters(),lr=LR,weight_decay=0.001)
torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, 
    verbose=True, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),
            torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5),
            torchvision.transforms.ToTensor()]))

eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
    torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=True, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=True, num_workers=2)

# %%
# losses=[]
# train_accs=[]
# eval_accs=[]
for epoch in range(EPOCH):
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn7(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if step%10==0:
            with torch.no_grad():
                pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                train_accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                train_accs.append(train_accuracy)
                losses.append(loss.data)
                torch.cuda.empty_cache()
                eval_acc=[]
                for x,y in eval_loader:
                    b_x=Variable(x).cuda()
                    b_y=Variable(y).cuda()        
                    output=cnn7(b_x)         #change
                    pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                    accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                    eval_acc.append(accuracy)
                eval_accs.append(np.mean(eval_acc))
                print('Epoch: ',epoch,'| Step: ',step,'| loss: ',loss.data,
                      '| Train_acc: ', train_accuracy,'| Eval_acc: ', np.mean(eval_acc))
# Out:
# Epoch:  0 | Step:  0 | loss:  tensor(1.6422, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.608
# Epoch:  0 | Step:  10 | loss:  tensor(1.2012, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.5900000000000001
# Epoch:  0 | Step:  20 | loss:  tensor(0.9602, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.595
# Epoch:  0 | Step:  30 | loss:  tensor(1.1841, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.584
# Epoch:  0 | Step:  40 | loss:  tensor(0.9663, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.6209999999999999
# Epoch:  0 | Step:  50 | loss:  tensor(0.9803, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6140000000000001
# Epoch:  0 | Step:  60 | loss:  tensor(1.9170, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.583
# Epoch:  0 | Step:  70 | loss:  tensor(0.9919, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6199999999999999
# Epoch:  0 | Step:  80 | loss:  tensor(0.7618, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.593
# Epoch:  0 | Step:  90 | loss:  tensor(1.0211, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.625
# Epoch:  0 | Step:  100 | loss:  tensor(0.8806, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6359999999999999
# Epoch:  0 | Step:  110 | loss:  tensor(1.1468, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.642
# Epoch:  0 | Step:  120 | loss:  tensor(1.0597, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.564
# Epoch:  0 | Step:  130 | loss:  tensor(0.8921, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.579
# Epoch:  0 | Step:  140 | loss:  tensor(1.1002, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.626
# Epoch:  0 | Step:  150 | loss:  tensor(0.9978, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.579
# Epoch:  0 | Step:  160 | loss:  tensor(1.4348, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.624
# Epoch:  0 | Step:  170 | loss:  tensor(1.0111, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6439999999999999
# Epoch:  0 | Step:  180 | loss:  tensor(1.5977, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.593
# Epoch:  0 | Step:  190 | loss:  tensor(1.1090, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.625
# Epoch:  1 | Step:  0 | loss:  tensor(0.5821, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.593
# Epoch:  1 | Step:  10 | loss:  tensor(0.8112, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.601
# Epoch:  1 | Step:  20 | loss:  tensor(1.0399, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.61
# Epoch:  1 | Step:  30 | loss:  tensor(1.1022, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6299999999999999
# Epoch:  1 | Step:  40 | loss:  tensor(1.2080, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.611
# Epoch:  1 | Step:  50 | loss:  tensor(0.5560, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.563
# Epoch:  1 | Step:  60 | loss:  tensor(0.5199, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.575
# Epoch:  1 | Step:  70 | loss:  tensor(0.7316, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.626
# Epoch:  1 | Step:  80 | loss:  tensor(1.0870, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.575
# Epoch:  1 | Step:  90 | loss:  tensor(1.3724, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.61
# Epoch:  1 | Step:  100 | loss:  tensor(1.6676, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.5900000000000001
# Epoch:  1 | Step:  110 | loss:  tensor(0.7073, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.62
# Epoch:  1 | Step:  120 | loss:  tensor(1.0051, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.577
# Epoch:  1 | Step:  130 | loss:  tensor(1.2599, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.61
# Epoch:  1 | Step:  140 | loss:  tensor(1.1225, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6449999999999999
# Epoch:  1 | Step:  150 | loss:  tensor(0.7662, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.619
# Epoch:  1 | Step:  160 | loss:  tensor(1.8660, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.573
# Epoch:  1 | Step:  170 | loss:  tensor(1.1718, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.599
# Epoch:  1 | Step:  180 | loss:  tensor(1.3369, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.6050000000000001
# Epoch:  1 | Step:  190 | loss:  tensor(1.4871, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.5940000000000001
# Epoch:  2 | Step:  0 | loss:  tensor(0.7159, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.5900000000000001
# Epoch:  2 | Step:  10 | loss:  tensor(1.2676, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.63
# Epoch:  2 | Step:  20 | loss:  tensor(0.9043, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.621
# Epoch:  2 | Step:  30 | loss:  tensor(0.9039, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.583
# Epoch:  2 | Step:  40 | loss:  tensor(1.5163, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.637
# Epoch:  2 | Step:  50 | loss:  tensor(1.1963, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.604
# Epoch:  2 | Step:  60 | loss:  tensor(1.3088, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.601
# Epoch:  2 | Step:  70 | loss:  tensor(1.0386, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6369999999999999
# Epoch:  2 | Step:  80 | loss:  tensor(1.3837, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.6380000000000001
# Epoch:  2 | Step:  90 | loss:  tensor(0.9004, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.567
# Epoch:  2 | Step:  100 | loss:  tensor(1.0231, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.599
# Epoch:  2 | Step:  110 | loss:  tensor(1.8869, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.609
# Epoch:  2 | Step:  120 | loss:  tensor(0.6509, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.601
# Epoch:  2 | Step:  130 | loss:  tensor(0.5062, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.601
# Epoch:  2 | Step:  140 | loss:  tensor(1.5561, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.617
# Epoch:  2 | Step:  150 | loss:  tensor(0.9569, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.568
# Epoch:  2 | Step:  160 | loss:  tensor(0.9345, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6359999999999999
# Epoch:  2 | Step:  170 | loss:  tensor(1.0866, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6039999999999999
# Epoch:  2 | Step:  180 | loss:  tensor(1.5910, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.683
# Epoch:  2 | Step:  190 | loss:  tensor(0.9445, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6179999999999999
# Epoch:  3 | Step:  0 | loss:  tensor(0.7216, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.611
# Epoch:  3 | Step:  10 | loss:  tensor(1.1099, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.617
# Epoch:  3 | Step:  20 | loss:  tensor(1.2388, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.599
# Epoch:  3 | Step:  30 | loss:  tensor(0.7247, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.631
# Epoch:  3 | Step:  40 | loss:  tensor(1.0016, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.5880000000000001
# Epoch:  3 | Step:  50 | loss:  tensor(1.3800, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.618
# Epoch:  3 | Step:  60 | loss:  tensor(1.0773, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.612
# Epoch:  3 | Step:  70 | loss:  tensor(1.0652, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.633
# Epoch:  3 | Step:  80 | loss:  tensor(2.0621, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.581
# Epoch:  3 | Step:  90 | loss:  tensor(1.2632, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.612
# Epoch:  3 | Step:  100 | loss:  tensor(1.0592, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.623
# Epoch:  3 | Step:  110 | loss:  tensor(0.4532, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.62
# Epoch:  3 | Step:  120 | loss:  tensor(1.0431, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.631
# Epoch:  3 | Step:  130 | loss:  tensor(0.8505, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.593
# Epoch:  3 | Step:  140 | loss:  tensor(1.3774, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.632
# Epoch:  3 | Step:  150 | loss:  tensor(1.3523, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.61
# Epoch:  3 | Step:  160 | loss:  tensor(1.1510, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6060000000000001
# Epoch:  3 | Step:  170 | loss:  tensor(1.0422, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.578
# Epoch:  3 | Step:  180 | loss:  tensor(0.8361, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6529999999999999
# Epoch:  3 | Step:  190 | loss:  tensor(0.8290, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6060000000000001
# Epoch:  4 | Step:  0 | loss:  tensor(0.7029, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.622
# Epoch:  4 | Step:  10 | loss:  tensor(0.4220, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6099999999999999
# Epoch:  4 | Step:  20 | loss:  tensor(0.8024, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.5810000000000001
# Epoch:  4 | Step:  30 | loss:  tensor(1.2083, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.658
# Epoch:  4 | Step:  40 | loss:  tensor(1.0114, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.647
# Epoch:  4 | Step:  50 | loss:  tensor(0.9553, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6
# Epoch:  4 | Step:  60 | loss:  tensor(0.8092, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.61
# Epoch:  4 | Step:  70 | loss:  tensor(1.4447, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.595
# Epoch:  4 | Step:  80 | loss:  tensor(1.4042, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.623
# Epoch:  4 | Step:  90 | loss:  tensor(1.1492, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.664
# Epoch:  4 | Step:  100 | loss:  tensor(1.3298, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.639
# Epoch:  4 | Step:  110 | loss:  tensor(1.2026, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.629
# Epoch:  4 | Step:  120 | loss:  tensor(1.1191, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6449999999999999
# Epoch:  4 | Step:  130 | loss:  tensor(1.4823, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.623
# Epoch:  4 | Step:  140 | loss:  tensor(1.1959, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.61
# Epoch:  4 | Step:  150 | loss:  tensor(1.1492, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.64
# Epoch:  4 | Step:  160 | loss:  tensor(0.9863, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6180000000000001
# Epoch:  4 | Step:  170 | loss:  tensor(0.9495, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6050000000000001
# Epoch:  4 | Step:  180 | loss:  tensor(0.5863, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.616
# Epoch:  4 | Step:  190 | loss:  tensor(1.1730, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.591
# Epoch:  5 | Step:  0 | loss:  tensor(1.3645, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.5820000000000001
# Epoch:  5 | Step:  10 | loss:  tensor(1.0979, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.6250000000000001
# Epoch:  5 | Step:  20 | loss:  tensor(1.1807, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.611
# Epoch:  5 | Step:  30 | loss:  tensor(0.6747, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.627
# Epoch:  5 | Step:  40 | loss:  tensor(0.9841, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.627
# Epoch:  5 | Step:  50 | loss:  tensor(0.7457, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.627
# Epoch:  5 | Step:  60 | loss:  tensor(0.7199, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.638
# Epoch:  5 | Step:  70 | loss:  tensor(1.0379, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.668
# Epoch:  5 | Step:  80 | loss:  tensor(0.6857, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.62
# Epoch:  5 | Step:  90 | loss:  tensor(0.6248, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6319999999999999
# Epoch:  5 | Step:  100 | loss:  tensor(1.2350, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6449999999999999
# Epoch:  5 | Step:  110 | loss:  tensor(1.0862, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6119999999999999
# Epoch:  5 | Step:  120 | loss:  tensor(1.2737, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.604
# Epoch:  5 | Step:  130 | loss:  tensor(0.8000, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6380000000000001
# Epoch:  5 | Step:  140 | loss:  tensor(1.0665, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.604
# Epoch:  5 | Step:  150 | loss:  tensor(1.2132, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.626
# Epoch:  5 | Step:  160 | loss:  tensor(0.9342, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6290000000000001
# Epoch:  5 | Step:  170 | loss:  tensor(0.7280, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.631
# Epoch:  5 | Step:  180 | loss:  tensor(1.1548, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.667
# Epoch:  5 | Step:  190 | loss:  tensor(1.3394, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.616
# Epoch:  6 | Step:  0 | loss:  tensor(1.1280, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.5770000000000001
# Epoch:  6 | Step:  10 | loss:  tensor(1.2665, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.63
# Epoch:  6 | Step:  20 | loss:  tensor(0.7438, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.633
# Epoch:  6 | Step:  30 | loss:  tensor(0.7388, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6050000000000001
# Epoch:  6 | Step:  40 | loss:  tensor(0.6380, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6460000000000001
# Epoch:  6 | Step:  50 | loss:  tensor(0.9344, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.587
# Epoch:  6 | Step:  60 | loss:  tensor(0.7050, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.611
# Epoch:  6 | Step:  70 | loss:  tensor(0.8025, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.588
# Epoch:  6 | Step:  80 | loss:  tensor(0.6932, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.624
# Epoch:  6 | Step:  90 | loss:  tensor(0.9654, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.63
# Epoch:  6 | Step:  100 | loss:  tensor(1.1350, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.629
# Epoch:  6 | Step:  110 | loss:  tensor(0.9222, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.599
# Epoch:  6 | Step:  120 | loss:  tensor(0.8607, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.623
# Epoch:  6 | Step:  130 | loss:  tensor(0.7710, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6599999999999999
# Epoch:  6 | Step:  140 | loss:  tensor(1.0608, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.6380000000000001
# Epoch:  6 | Step:  150 | loss:  tensor(0.9949, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.6369999999999999
# Epoch:  6 | Step:  160 | loss:  tensor(1.4661, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.597
# Epoch:  6 | Step:  170 | loss:  tensor(1.1707, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.567
# Epoch:  6 | Step:  180 | loss:  tensor(0.8576, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.675
# Epoch:  6 | Step:  190 | loss:  tensor(1.7439, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.6050000000000001
# Epoch:  7 | Step:  0 | loss:  tensor(0.5622, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5960000000000001
# Epoch:  7 | Step:  10 | loss:  tensor(0.5374, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.591
# Epoch:  7 | Step:  20 | loss:  tensor(0.9263, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.5980000000000001
# Epoch:  7 | Step:  30 | loss:  tensor(0.7239, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.615
# Epoch:  7 | Step:  40 | loss:  tensor(0.5929, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.653
# Epoch:  7 | Step:  50 | loss:  tensor(0.8543, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6180000000000001
# Epoch:  7 | Step:  60 | loss:  tensor(0.6735, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5890000000000001
# Epoch:  7 | Step:  70 | loss:  tensor(1.0816, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.626
# Epoch:  7 | Step:  80 | loss:  tensor(0.7535, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.657
# Epoch:  7 | Step:  90 | loss:  tensor(1.2704, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.63
# Epoch:  7 | Step:  100 | loss:  tensor(1.4580, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.6399999999999999
# Epoch:  7 | Step:  110 | loss:  tensor(0.8583, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.618
# Epoch:  7 | Step:  120 | loss:  tensor(0.9394, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.642
# Epoch:  7 | Step:  130 | loss:  tensor(0.8797, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.64
# Epoch:  7 | Step:  140 | loss:  tensor(0.9978, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.624
# Epoch:  7 | Step:  150 | loss:  tensor(1.1545, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.603
# Epoch:  7 | Step:  160 | loss:  tensor(1.2990, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.6140000000000001
# Epoch:  7 | Step:  170 | loss:  tensor(0.4472, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6379999999999999
# Epoch:  7 | Step:  180 | loss:  tensor(0.9852, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6359999999999999
# Epoch:  7 | Step:  190 | loss:  tensor(1.0718, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.631
# Epoch:  8 | Step:  0 | loss:  tensor(0.6670, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6100000000000001
# Epoch:  8 | Step:  10 | loss:  tensor(0.5891, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.601
# Epoch:  8 | Step:  20 | loss:  tensor(0.9267, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6779999999999999
# Epoch:  8 | Step:  30 | loss:  tensor(0.5096, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.619
# Epoch:  8 | Step:  40 | loss:  tensor(0.5007, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.592
# Epoch:  8 | Step:  50 | loss:  tensor(0.9895, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.621
# Epoch:  8 | Step:  60 | loss:  tensor(0.7526, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.611
# Epoch:  8 | Step:  70 | loss:  tensor(0.7594, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6279999999999999
# Epoch:  8 | Step:  80 | loss:  tensor(0.7102, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6199999999999999
# Epoch:  8 | Step:  90 | loss:  tensor(0.6077, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.642
# Epoch:  8 | Step:  100 | loss:  tensor(0.4750, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.629
# Epoch:  8 | Step:  110 | loss:  tensor(0.6267, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6289999999999999
# Epoch:  8 | Step:  120 | loss:  tensor(1.1348, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.663
# Epoch:  8 | Step:  130 | loss:  tensor(1.0570, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.616
# Epoch:  8 | Step:  140 | loss:  tensor(0.7101, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.671
# Epoch:  8 | Step:  150 | loss:  tensor(0.5803, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.641
# Epoch:  8 | Step:  160 | loss:  tensor(0.6211, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6500000000000001
# Epoch:  8 | Step:  170 | loss:  tensor(1.0084, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.667
# Epoch:  8 | Step:  180 | loss:  tensor(0.7586, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6319999999999999
# Epoch:  8 | Step:  190 | loss:  tensor(1.0350, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.649
# Epoch:  9 | Step:  0 | loss:  tensor(0.7954, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.609
# Epoch:  9 | Step:  10 | loss:  tensor(0.9515, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.631
# Epoch:  9 | Step:  20 | loss:  tensor(0.5798, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.621
# Epoch:  9 | Step:  30 | loss:  tensor(0.9121, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.6609999999999999
# Epoch:  9 | Step:  40 | loss:  tensor(0.9173, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.615
# Epoch:  9 | Step:  50 | loss:  tensor(0.9317, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6359999999999999
# Epoch:  9 | Step:  60 | loss:  tensor(0.7721, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6890000000000001
# Epoch:  9 | Step:  70 | loss:  tensor(0.3303, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.63
# Epoch:  9 | Step:  80 | loss:  tensor(0.6882, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.589
# Epoch:  9 | Step:  90 | loss:  tensor(0.5780, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6749999999999999
# Epoch:  9 | Step:  100 | loss:  tensor(0.7560, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6220000000000001
# Epoch:  9 | Step:  110 | loss:  tensor(0.6332, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.666
# Epoch:  9 | Step:  120 | loss:  tensor(0.8124, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6359999999999999
# Epoch:  9 | Step:  130 | loss:  tensor(0.3798, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.641
# Epoch:  9 | Step:  140 | loss:  tensor(0.9753, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.635
# Epoch:  9 | Step:  150 | loss:  tensor(1.3705, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.587
# Epoch:  9 | Step:  160 | loss:  tensor(0.4952, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.651
# Epoch:  9 | Step:  170 | loss:  tensor(0.6542, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.629
# Epoch:  9 | Step:  180 | loss:  tensor(0.5410, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.638
# Epoch:  9 | Step:  190 | loss:  tensor(0.7836, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.635
# Epoch:  10 | Step:  0 | loss:  tensor(0.8528, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.647
# Epoch:  10 | Step:  10 | loss:  tensor(0.8918, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.58
# Epoch:  10 | Step:  20 | loss:  tensor(0.8356, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6040000000000001
# Epoch:  10 | Step:  30 | loss:  tensor(0.6508, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6130000000000001
# Epoch:  10 | Step:  40 | loss:  tensor(0.7114, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.65
# Epoch:  10 | Step:  50 | loss:  tensor(1.0493, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6439999999999999
# Epoch:  10 | Step:  60 | loss:  tensor(0.4853, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.591
# Epoch:  10 | Step:  70 | loss:  tensor(0.6301, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6519999999999999
# Epoch:  10 | Step:  80 | loss:  tensor(1.2169, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.64
# Epoch:  10 | Step:  90 | loss:  tensor(0.5937, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.639
# Epoch:  10 | Step:  100 | loss:  tensor(0.5353, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.684
# Epoch:  10 | Step:  110 | loss:  tensor(0.4575, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.645
# Epoch:  10 | Step:  120 | loss:  tensor(0.8200, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.608
# Epoch:  10 | Step:  130 | loss:  tensor(0.8919, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.631
# Epoch:  10 | Step:  140 | loss:  tensor(0.6182, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.619
# Epoch:  10 | Step:  150 | loss:  tensor(0.6934, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6239999999999999
# Epoch:  10 | Step:  160 | loss:  tensor(0.8286, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.627
# Epoch:  10 | Step:  170 | loss:  tensor(0.8854, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6050000000000001
# Epoch:  10 | Step:  180 | loss:  tensor(1.2629, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6479999999999999
# Epoch:  10 | Step:  190 | loss:  tensor(0.9006, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6609999999999999
# Epoch:  11 | Step:  0 | loss:  tensor(1.0091, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.6439999999999999
# Epoch:  11 | Step:  10 | loss:  tensor(0.9214, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.635
# Epoch:  11 | Step:  20 | loss:  tensor(0.3437, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.636
# Epoch:  11 | Step:  30 | loss:  tensor(0.4510, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.647
# Epoch:  11 | Step:  40 | loss:  tensor(0.5195, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.617
# Epoch:  11 | Step:  50 | loss:  tensor(0.5803, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.642
# Epoch:  11 | Step:  60 | loss:  tensor(0.6328, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.61
# Epoch:  11 | Step:  70 | loss:  tensor(0.7847, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.664
# Epoch:  11 | Step:  80 | loss:  tensor(0.5291, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6130000000000001
# Epoch:  11 | Step:  90 | loss:  tensor(0.4750, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5860000000000001
# Epoch:  11 | Step:  100 | loss:  tensor(1.3293, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.6130000000000001
# Epoch:  11 | Step:  110 | loss:  tensor(0.5579, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.63
# Epoch:  11 | Step:  120 | loss:  tensor(0.3893, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.631
# Epoch:  11 | Step:  130 | loss:  tensor(1.3990, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.603
# Epoch:  11 | Step:  140 | loss:  tensor(0.5442, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.628
# Epoch:  11 | Step:  150 | loss:  tensor(0.6862, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.651
# Epoch:  11 | Step:  160 | loss:  tensor(0.7469, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.648
# Epoch:  11 | Step:  170 | loss:  tensor(0.9511, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6639999999999999
# Epoch:  11 | Step:  180 | loss:  tensor(1.5194, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.673
# Epoch:  11 | Step:  190 | loss:  tensor(0.4938, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.643
# Epoch:  12 | Step:  0 | loss:  tensor(0.7161, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.619
# Epoch:  12 | Step:  10 | loss:  tensor(0.5724, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.64
# Epoch:  12 | Step:  20 | loss:  tensor(0.9655, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.635
# Epoch:  12 | Step:  30 | loss:  tensor(0.5813, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.589
# Epoch:  12 | Step:  40 | loss:  tensor(0.7270, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.659
# Epoch:  12 | Step:  50 | loss:  tensor(0.8730, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.619
# Epoch:  12 | Step:  60 | loss:  tensor(0.8026, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6170000000000001
# Epoch:  12 | Step:  70 | loss:  tensor(0.7253, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.602
# Epoch:  12 | Step:  80 | loss:  tensor(0.9516, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.612
# Epoch:  12 | Step:  90 | loss:  tensor(0.3478, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6
# Epoch:  12 | Step:  100 | loss:  tensor(1.0198, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.626
# Epoch:  12 | Step:  110 | loss:  tensor(1.1606, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6539999999999999
# Epoch:  12 | Step:  120 | loss:  tensor(0.5462, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.624
# Epoch:  12 | Step:  130 | loss:  tensor(0.5599, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6449999999999999
# Epoch:  12 | Step:  140 | loss:  tensor(0.7109, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.5820000000000001
# Epoch:  12 | Step:  150 | loss:  tensor(0.8043, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.613
# Epoch:  12 | Step:  160 | loss:  tensor(0.7214, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.607
# Epoch:  12 | Step:  170 | loss:  tensor(0.7726, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.641
# Epoch:  12 | Step:  180 | loss:  tensor(0.7659, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.606
# Epoch:  12 | Step:  190 | loss:  tensor(1.2061, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.637
# Epoch:  13 | Step:  0 | loss:  tensor(0.5043, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.655
# Epoch:  13 | Step:  10 | loss:  tensor(0.5736, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.605
# Epoch:  13 | Step:  20 | loss:  tensor(0.9716, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.623
# Epoch:  13 | Step:  30 | loss:  tensor(0.9769, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.632
# Epoch:  13 | Step:  40 | loss:  tensor(0.5083, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6530000000000001
# Epoch:  13 | Step:  50 | loss:  tensor(0.4119, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.592
# Epoch:  13 | Step:  60 | loss:  tensor(0.7394, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.663
# Epoch:  13 | Step:  70 | loss:  tensor(0.5344, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6529999999999999
# Epoch:  13 | Step:  80 | loss:  tensor(0.5724, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.632
# Epoch:  13 | Step:  90 | loss:  tensor(0.8854, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6540000000000001
# Epoch:  13 | Step:  100 | loss:  tensor(0.6475, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.638
# Epoch:  13 | Step:  110 | loss:  tensor(0.9130, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.648
# Epoch:  13 | Step:  120 | loss:  tensor(0.7808, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.656
# Epoch:  13 | Step:  130 | loss:  tensor(0.6834, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.656
# Epoch:  13 | Step:  140 | loss:  tensor(0.6247, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6649999999999999
# Epoch:  13 | Step:  150 | loss:  tensor(1.2900, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6450000000000001
# Epoch:  13 | Step:  160 | loss:  tensor(0.9025, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.656
# Epoch:  13 | Step:  170 | loss:  tensor(0.6971, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6199999999999999
# Epoch:  13 | Step:  180 | loss:  tensor(0.4196, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6409999999999999
# Epoch:  13 | Step:  190 | loss:  tensor(1.0624, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6479999999999999
# Epoch:  14 | Step:  0 | loss:  tensor(0.8104, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.642
# Epoch:  14 | Step:  10 | loss:  tensor(0.6272, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.62
# Epoch:  14 | Step:  20 | loss:  tensor(0.4025, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.611
# Epoch:  14 | Step:  30 | loss:  tensor(0.9789, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.627
# Epoch:  14 | Step:  40 | loss:  tensor(0.9563, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6369999999999999
# Epoch:  14 | Step:  50 | loss:  tensor(0.7669, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.655
# Epoch:  14 | Step:  60 | loss:  tensor(0.4663, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.657
# Epoch:  14 | Step:  70 | loss:  tensor(0.5732, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.622
# Epoch:  14 | Step:  80 | loss:  tensor(0.7514, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.652
# Epoch:  14 | Step:  90 | loss:  tensor(0.4893, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.651
# Epoch:  14 | Step:  100 | loss:  tensor(1.0153, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.654
# Epoch:  14 | Step:  110 | loss:  tensor(0.7804, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.624
# Epoch:  14 | Step:  120 | loss:  tensor(1.0418, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.628
# Epoch:  14 | Step:  130 | loss:  tensor(0.7231, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.657
# Epoch:  14 | Step:  140 | loss:  tensor(0.4368, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6369999999999999
# Epoch:  14 | Step:  150 | loss:  tensor(1.1019, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.631
# Epoch:  14 | Step:  160 | loss:  tensor(0.8700, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.64
# Epoch:  14 | Step:  170 | loss:  tensor(0.9968, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.6140000000000001
# Epoch:  14 | Step:  180 | loss:  tensor(1.4061, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.621
# Epoch:  14 | Step:  190 | loss:  tensor(1.2876, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6450000000000001
# Epoch:  15 | Step:  0 | loss:  tensor(1.0386, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.663
# Epoch:  15 | Step:  10 | loss:  tensor(0.7208, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.632
# Epoch:  15 | Step:  20 | loss:  tensor(0.5255, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.647
# Epoch:  15 | Step:  30 | loss:  tensor(0.6063, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.655
# Epoch:  15 | Step:  40 | loss:  tensor(0.3641, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.657
# Epoch:  15 | Step:  50 | loss:  tensor(0.3375, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.599
# Epoch:  15 | Step:  60 | loss:  tensor(0.6088, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.666
# Epoch:  15 | Step:  70 | loss:  tensor(0.7815, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.647
# Epoch:  15 | Step:  80 | loss:  tensor(0.6274, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.646
# Epoch:  15 | Step:  90 | loss:  tensor(0.6907, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.664
# Epoch:  15 | Step:  100 | loss:  tensor(0.4486, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.655
# Epoch:  15 | Step:  110 | loss:  tensor(0.5031, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6279999999999999
# Epoch:  15 | Step:  120 | loss:  tensor(0.7849, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6699999999999999
# Epoch:  15 | Step:  130 | loss:  tensor(1.0522, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.661
# Epoch:  15 | Step:  140 | loss:  tensor(0.4251, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.633
# Epoch:  15 | Step:  150 | loss:  tensor(0.9852, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.601
# Epoch:  15 | Step:  160 | loss:  tensor(0.6451, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6130000000000001
# Epoch:  15 | Step:  170 | loss:  tensor(0.8327, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.655
# Epoch:  15 | Step:  180 | loss:  tensor(0.7365, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.633
# Epoch:  15 | Step:  190 | loss:  tensor(0.7770, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6540000000000001
# Epoch:  16 | Step:  0 | loss:  tensor(0.4826, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.616
# Epoch:  16 | Step:  10 | loss:  tensor(0.6550, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.651
# Epoch:  16 | Step:  20 | loss:  tensor(0.6671, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6519999999999999
# Epoch:  16 | Step:  30 | loss:  tensor(0.4432, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.636
# Epoch:  16 | Step:  40 | loss:  tensor(0.7166, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.627
# Epoch:  16 | Step:  50 | loss:  tensor(0.1795, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.6220000000000001
# Epoch:  16 | Step:  60 | loss:  tensor(0.3182, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.659
# Epoch:  16 | Step:  70 | loss:  tensor(0.8754, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.632
# Epoch:  16 | Step:  80 | loss:  tensor(0.2896, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.618
# Epoch:  16 | Step:  90 | loss:  tensor(0.8110, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.607
# Epoch:  16 | Step:  100 | loss:  tensor(0.7073, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6599999999999999
# Epoch:  16 | Step:  110 | loss:  tensor(0.6612, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6569999999999999
# Epoch:  16 | Step:  120 | loss:  tensor(0.5577, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.663
# Epoch:  16 | Step:  130 | loss:  tensor(0.7672, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6420000000000001
# Epoch:  16 | Step:  140 | loss:  tensor(0.4823, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.62
# Epoch:  16 | Step:  150 | loss:  tensor(1.0568, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6140000000000001
# Epoch:  16 | Step:  160 | loss:  tensor(0.3675, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.641
# Epoch:  16 | Step:  170 | loss:  tensor(0.5966, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6489999999999999
# Epoch:  16 | Step:  180 | loss:  tensor(0.5414, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.667
# Epoch:  16 | Step:  190 | loss:  tensor(0.4048, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.598
# Epoch:  17 | Step:  0 | loss:  tensor(0.4322, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.636
# Epoch:  17 | Step:  10 | loss:  tensor(0.5298, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.631
# Epoch:  17 | Step:  20 | loss:  tensor(0.7095, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.658
# Epoch:  17 | Step:  30 | loss:  tensor(0.4924, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.601
# Epoch:  17 | Step:  40 | loss:  tensor(0.2990, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.639
# Epoch:  17 | Step:  50 | loss:  tensor(0.7448, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6689999999999999
# Epoch:  17 | Step:  60 | loss:  tensor(0.3282, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.619
# Epoch:  17 | Step:  70 | loss:  tensor(0.8397, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6649999999999999
# Epoch:  17 | Step:  80 | loss:  tensor(0.4035, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6689999999999999
# Epoch:  17 | Step:  90 | loss:  tensor(1.1630, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.644
# Epoch:  17 | Step:  100 | loss:  tensor(0.7533, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.649
# Epoch:  17 | Step:  110 | loss:  tensor(0.4365, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.665
# Epoch:  17 | Step:  120 | loss:  tensor(0.5778, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.682
# Epoch:  17 | Step:  130 | loss:  tensor(0.5878, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.64
# Epoch:  17 | Step:  140 | loss:  tensor(0.7532, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6370000000000001
# Epoch:  17 | Step:  150 | loss:  tensor(0.6040, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.626
# Epoch:  17 | Step:  160 | loss:  tensor(0.4507, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.635
# Epoch:  17 | Step:  170 | loss:  tensor(0.7615, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.651
# Epoch:  17 | Step:  180 | loss:  tensor(0.5070, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.65
# Epoch:  17 | Step:  190 | loss:  tensor(0.3938, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.625
# Epoch:  18 | Step:  0 | loss:  tensor(0.2754, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6020000000000001
# Epoch:  18 | Step:  10 | loss:  tensor(0.9211, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.636
# Epoch:  18 | Step:  20 | loss:  tensor(0.4574, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.654
# Epoch:  18 | Step:  30 | loss:  tensor(0.6826, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6219999999999999
# Epoch:  18 | Step:  40 | loss:  tensor(0.2543, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6479999999999999
# Epoch:  18 | Step:  50 | loss:  tensor(0.5411, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.635
# Epoch:  18 | Step:  60 | loss:  tensor(0.6835, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.67
# Epoch:  18 | Step:  70 | loss:  tensor(0.5189, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.646
# Epoch:  18 | Step:  80 | loss:  tensor(0.4624, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.633
# Epoch:  18 | Step:  90 | loss:  tensor(1.0977, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.591
# Epoch:  18 | Step:  100 | loss:  tensor(0.6965, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.606
# Epoch:  18 | Step:  110 | loss:  tensor(0.4159, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.656
# Epoch:  18 | Step:  120 | loss:  tensor(1.3319, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6519999999999999
# Epoch:  18 | Step:  130 | loss:  tensor(1.0967, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.651
# Epoch:  18 | Step:  140 | loss:  tensor(0.5966, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.662
# Epoch:  18 | Step:  150 | loss:  tensor(0.4883, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6619999999999999
# Epoch:  18 | Step:  160 | loss:  tensor(0.4734, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6300000000000001
# Epoch:  18 | Step:  170 | loss:  tensor(0.8105, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.639
# Epoch:  18 | Step:  180 | loss:  tensor(0.7899, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6479999999999999
# Epoch:  18 | Step:  190 | loss:  tensor(0.6361, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.7
# Epoch:  19 | Step:  0 | loss:  tensor(0.6506, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.675
# Epoch:  19 | Step:  10 | loss:  tensor(0.6696, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.67
# Epoch:  19 | Step:  20 | loss:  tensor(0.4334, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.662
# Epoch:  19 | Step:  30 | loss:  tensor(0.5833, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.655
# Epoch:  19 | Step:  40 | loss:  tensor(0.5992, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.611
# Epoch:  19 | Step:  50 | loss:  tensor(0.4028, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.615
# Epoch:  19 | Step:  60 | loss:  tensor(0.5462, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.635
# Epoch:  19 | Step:  70 | loss:  tensor(0.4766, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.656
# Epoch:  19 | Step:  80 | loss:  tensor(0.9308, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.632
# Epoch:  19 | Step:  90 | loss:  tensor(0.6716, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6980000000000001
# Epoch:  19 | Step:  100 | loss:  tensor(0.8655, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.663
# Epoch:  19 | Step:  110 | loss:  tensor(0.3981, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6210000000000001
# Epoch:  19 | Step:  120 | loss:  tensor(0.4442, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6010000000000001
# Epoch:  19 | Step:  130 | loss:  tensor(1.3382, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.632
# Epoch:  19 | Step:  140 | loss:  tensor(0.7955, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.639
# Epoch:  19 | Step:  150 | loss:  tensor(0.9904, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.686
# Epoch:  19 | Step:  160 | loss:  tensor(0.7261, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.665
# Epoch:  19 | Step:  170 | loss:  tensor(0.7164, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.644
# Epoch:  19 | Step:  180 | loss:  tensor(0.4686, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.625
# Epoch:  19 | Step:  190 | loss:  tensor(1.0867, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.658
# Epoch:  20 | Step:  0 | loss:  tensor(0.6457, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.659
# Epoch:  20 | Step:  10 | loss:  tensor(0.6134, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.666
# Epoch:  20 | Step:  20 | loss:  tensor(0.4324, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.641
# Epoch:  20 | Step:  30 | loss:  tensor(0.6071, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6460000000000001
# Epoch:  20 | Step:  40 | loss:  tensor(0.5672, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.631
# Epoch:  20 | Step:  50 | loss:  tensor(0.9950, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.612
# Epoch:  20 | Step:  60 | loss:  tensor(0.4817, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6329999999999999
# Epoch:  20 | Step:  70 | loss:  tensor(0.7871, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.628
# Epoch:  20 | Step:  80 | loss:  tensor(0.6299, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6199999999999999
# Epoch:  20 | Step:  90 | loss:  tensor(1.1084, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6180000000000001
# Epoch:  20 | Step:  100 | loss:  tensor(0.7585, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.653
# Epoch:  20 | Step:  110 | loss:  tensor(0.3108, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6120000000000001
# Epoch:  20 | Step:  120 | loss:  tensor(0.7444, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.642
# Epoch:  20 | Step:  130 | loss:  tensor(1.0877, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.669
# Epoch:  20 | Step:  140 | loss:  tensor(0.7872, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6010000000000001
# Epoch:  20 | Step:  150 | loss:  tensor(1.0280, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.621
# Epoch:  20 | Step:  160 | loss:  tensor(0.7469, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.633
# Epoch:  20 | Step:  170 | loss:  tensor(0.6228, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.625
# Epoch:  20 | Step:  180 | loss:  tensor(0.1992, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.663
# Epoch:  20 | Step:  190 | loss:  tensor(0.6296, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.652
# Epoch:  21 | Step:  0 | loss:  tensor(0.6103, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.647
# Epoch:  21 | Step:  10 | loss:  tensor(0.4761, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6759999999999999
# Epoch:  21 | Step:  20 | loss:  tensor(0.6206, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.645
# Epoch:  21 | Step:  30 | loss:  tensor(0.8317, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.652
# Epoch:  21 | Step:  40 | loss:  tensor(0.6219, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.658
# Epoch:  21 | Step:  50 | loss:  tensor(0.2561, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.639
# Epoch:  21 | Step:  60 | loss:  tensor(0.5210, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.651
# Epoch:  21 | Step:  70 | loss:  tensor(0.2557, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.659
# Epoch:  21 | Step:  80 | loss:  tensor(0.5490, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.637
# Epoch:  21 | Step:  90 | loss:  tensor(0.5003, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6380000000000001
# Epoch:  21 | Step:  100 | loss:  tensor(0.5712, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.606
# Epoch:  21 | Step:  110 | loss:  tensor(0.5793, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.631
# Epoch:  21 | Step:  120 | loss:  tensor(0.5734, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.656
# Epoch:  21 | Step:  130 | loss:  tensor(0.6059, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.656
# Epoch:  21 | Step:  140 | loss:  tensor(0.4082, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.627
# Epoch:  21 | Step:  150 | loss:  tensor(0.6925, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.616
# Epoch:  21 | Step:  160 | loss:  tensor(0.7798, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6599999999999999
# Epoch:  21 | Step:  170 | loss:  tensor(0.4575, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.631
# Epoch:  21 | Step:  180 | loss:  tensor(0.5875, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.667
# Epoch:  21 | Step:  190 | loss:  tensor(0.5604, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.656
# Epoch:  22 | Step:  0 | loss:  tensor(0.5824, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6210000000000001
# Epoch:  22 | Step:  10 | loss:  tensor(0.3604, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6930000000000001
# Epoch:  22 | Step:  20 | loss:  tensor(0.3342, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.664
# Epoch:  22 | Step:  30 | loss:  tensor(0.2066, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.622
# Epoch:  22 | Step:  40 | loss:  tensor(0.4895, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6369999999999999
# ...
# Epoch:  22 | Step:  130 | loss:  tensor(0.4318, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6289999999999999
# Epoch:  22 | Step:  140 | loss:  tensor(0.7558, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.64
# Epoch:  22 | Step:  150 | loss:  tensor(0.2641, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.688
# Epoch:  22 | Step:  160 | loss:  tensor(0.4801, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.632
# Epoch:  22 | Step:  170 | loss:  tensor(0.2132, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6119999999999999
# Epoch:  22 | Step:  180 | loss:  tensor(0.4063, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6209999999999999
# Epoch:  22 | Step:  190 | loss:  tensor(0.9658, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.603
# Epoch:  23 | Step:  0 | loss:  tensor(0.6593, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6039999999999999
# Epoch:  23 | Step:  10 | loss:  tensor(0.3241, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6420000000000001
# Epoch:  23 | Step:  20 | loss:  tensor(0.6092, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6130000000000001
# Epoch:  23 | Step:  30 | loss:  tensor(0.5367, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.637
# Epoch:  23 | Step:  40 | loss:  tensor(0.2896, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6620000000000001
# Epoch:  23 | Step:  50 | loss:  tensor(0.5290, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.611
# Epoch:  23 | Step:  60 | loss:  tensor(0.4257, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.644
# Epoch:  23 | Step:  70 | loss:  tensor(0.5260, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.615
# Epoch:  23 | Step:  80 | loss:  tensor(0.4843, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.624
# Epoch:  23 | Step:  90 | loss:  tensor(0.7541, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.663
# Epoch:  23 | Step:  100 | loss:  tensor(1.0345, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.635
# Epoch:  23 | Step:  110 | loss:  tensor(0.5387, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.625
# Epoch:  23 | Step:  120 | loss:  tensor(0.7167, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.666
# Epoch:  23 | Step:  130 | loss:  tensor(0.3565, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.623
# Epoch:  23 | Step:  140 | loss:  tensor(0.3369, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.643
# Epoch:  23 | Step:  150 | loss:  tensor(0.2986, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.667
# Epoch:  23 | Step:  160 | loss:  tensor(0.9556, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6699999999999999
# Epoch:  23 | Step:  170 | loss:  tensor(0.9023, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6330000000000001
# Epoch:  23 | Step:  180 | loss:  tensor(0.7262, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.658
# Epoch:  23 | Step:  190 | loss:  tensor(0.3357, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.655
# Epoch:  24 | Step:  0 | loss:  tensor(0.4898, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6280000000000001
# Epoch:  24 | Step:  10 | loss:  tensor(0.6033, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.666
# Epoch:  24 | Step:  20 | loss:  tensor(0.9597, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.646
# Epoch:  24 | Step:  30 | loss:  tensor(0.7449, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.624
# Epoch:  24 | Step:  40 | loss:  tensor(0.6465, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6290000000000001
# Epoch:  24 | Step:  50 | loss:  tensor(0.3630, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.658
# Epoch:  24 | Step:  60 | loss:  tensor(0.4097, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.639
# Epoch:  24 | Step:  70 | loss:  tensor(0.8436, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.643
# Epoch:  24 | Step:  80 | loss:  tensor(0.2543, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.639
# Epoch:  24 | Step:  90 | loss:  tensor(0.2953, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.62
# Epoch:  24 | Step:  100 | loss:  tensor(0.5390, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.658
# Epoch:  24 | Step:  110 | loss:  tensor(0.4604, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.635
# Epoch:  24 | Step:  120 | loss:  tensor(0.3855, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.648
# Epoch:  24 | Step:  130 | loss:  tensor(0.3668, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.639
# Epoch:  24 | Step:  140 | loss:  tensor(0.4486, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.623
# Epoch:  24 | Step:  150 | loss:  tensor(0.4150, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.684
# Epoch:  24 | Step:  160 | loss:  tensor(0.7062, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.647
# Epoch:  24 | Step:  170 | loss:  tensor(0.7649, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.649
# Epoch:  24 | Step:  180 | loss:  tensor(0.5893, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6619999999999999
# Epoch:  24 | Step:  190 | loss:  tensor(0.6302, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.65
# Epoch:  25 | Step:  0 | loss:  tensor(0.3434, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6809999999999999
# Epoch:  25 | Step:  10 | loss:  tensor(0.3051, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.682
# Epoch:  25 | Step:  20 | loss:  tensor(0.3083, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.65
# Epoch:  25 | Step:  30 | loss:  tensor(0.6027, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.634
# Epoch:  25 | Step:  40 | loss:  tensor(0.3364, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.607
# Epoch:  25 | Step:  50 | loss:  tensor(0.5443, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.621
# Epoch:  25 | Step:  60 | loss:  tensor(0.6909, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6279999999999999
# Epoch:  25 | Step:  70 | loss:  tensor(0.2158, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.595
# Epoch:  25 | Step:  80 | loss:  tensor(0.4186, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.645
# Epoch:  25 | Step:  90 | loss:  tensor(0.3798, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6759999999999999
# Epoch:  25 | Step:  100 | loss:  tensor(0.1428, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.6759999999999999
# Epoch:  25 | Step:  110 | loss:  tensor(0.9106, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6290000000000001
# Epoch:  25 | Step:  120 | loss:  tensor(0.1673, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.646
# Epoch:  25 | Step:  130 | loss:  tensor(0.6065, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6420000000000001
# Epoch:  25 | Step:  140 | loss:  tensor(0.9443, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.65
# Epoch:  25 | Step:  150 | loss:  tensor(0.9862, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.689
# Epoch:  25 | Step:  160 | loss:  tensor(0.8567, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.643
# Epoch:  25 | Step:  170 | loss:  tensor(0.8659, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6679999999999999
# Epoch:  25 | Step:  180 | loss:  tensor(0.7439, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.653
# Epoch:  25 | Step:  190 | loss:  tensor(0.5440, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.664
# Epoch:  26 | Step:  0 | loss:  tensor(0.8078, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.656
# Epoch:  26 | Step:  10 | loss:  tensor(0.6612, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.645
# Epoch:  26 | Step:  20 | loss:  tensor(0.1785, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.633
# Epoch:  26 | Step:  30 | loss:  tensor(0.1868, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.658
# Epoch:  26 | Step:  40 | loss:  tensor(0.6913, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6539999999999999
# Epoch:  26 | Step:  50 | loss:  tensor(0.3697, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.635
# Epoch:  26 | Step:  60 | loss:  tensor(0.5751, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.629
# Epoch:  26 | Step:  70 | loss:  tensor(0.3524, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6319999999999999
# Epoch:  26 | Step:  80 | loss:  tensor(0.9787, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.656
# Epoch:  26 | Step:  90 | loss:  tensor(1.1070, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.645
# Epoch:  26 | Step:  100 | loss:  tensor(0.4681, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6519999999999999
# Epoch:  26 | Step:  110 | loss:  tensor(0.3176, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6769999999999999
# Epoch:  26 | Step:  120 | loss:  tensor(0.5729, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.62
# Epoch:  26 | Step:  130 | loss:  tensor(0.5520, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.61
# Epoch:  26 | Step:  140 | loss:  tensor(0.4335, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6319999999999999
# Epoch:  26 | Step:  150 | loss:  tensor(0.4455, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.639
# Epoch:  26 | Step:  160 | loss:  tensor(0.8218, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.667
# Epoch:  26 | Step:  170 | loss:  tensor(0.5589, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6540000000000001
# Epoch:  26 | Step:  180 | loss:  tensor(0.6977, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.643
# Epoch:  26 | Step:  190 | loss:  tensor(0.4903, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.667
# Epoch:  27 | Step:  0 | loss:  tensor(0.3307, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6609999999999999
# Epoch:  27 | Step:  10 | loss:  tensor(0.5615, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.646
# Epoch:  27 | Step:  20 | loss:  tensor(1.0175, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.6789999999999999
# Epoch:  27 | Step:  30 | loss:  tensor(0.2950, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.666
# Epoch:  27 | Step:  40 | loss:  tensor(0.3405, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6260000000000001
# Epoch:  27 | Step:  50 | loss:  tensor(0.4289, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6639999999999999
# Epoch:  27 | Step:  60 | loss:  tensor(0.5799, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.658
# Epoch:  27 | Step:  70 | loss:  tensor(0.4978, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.623
# Epoch:  27 | Step:  80 | loss:  tensor(0.3885, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.654
# Epoch:  27 | Step:  90 | loss:  tensor(0.5407, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6890000000000001
# Epoch:  27 | Step:  100 | loss:  tensor(0.3153, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.656
# Epoch:  27 | Step:  110 | loss:  tensor(0.8476, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6609999999999999
# Epoch:  27 | Step:  120 | loss:  tensor(0.1782, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.652
# Epoch:  27 | Step:  130 | loss:  tensor(0.4775, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.659
# Epoch:  27 | Step:  140 | loss:  tensor(0.3884, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6129999999999999
# Epoch:  27 | Step:  150 | loss:  tensor(0.4944, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6620000000000001
# Epoch:  27 | Step:  160 | loss:  tensor(0.6762, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.64
# Epoch:  27 | Step:  170 | loss:  tensor(0.6082, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.651
# Epoch:  27 | Step:  180 | loss:  tensor(0.3624, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.63
# Epoch:  27 | Step:  190 | loss:  tensor(0.3961, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.658
# Epoch:  28 | Step:  0 | loss:  tensor(0.7571, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.66
# Epoch:  28 | Step:  10 | loss:  tensor(0.6067, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.678
# Epoch:  28 | Step:  20 | loss:  tensor(0.3321, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.689
# Epoch:  28 | Step:  30 | loss:  tensor(0.3134, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.639
# Epoch:  28 | Step:  40 | loss:  tensor(0.6555, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.657
# Epoch:  28 | Step:  50 | loss:  tensor(0.1891, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6529999999999999
# Epoch:  28 | Step:  60 | loss:  tensor(0.7938, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.683
# Epoch:  28 | Step:  70 | loss:  tensor(0.9824, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.638
# Epoch:  28 | Step:  80 | loss:  tensor(0.8449, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.651
# Epoch:  28 | Step:  90 | loss:  tensor(0.3529, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.65
# Epoch:  28 | Step:  100 | loss:  tensor(0.6038, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.665
# Epoch:  28 | Step:  110 | loss:  tensor(0.8149, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6380000000000001
# Epoch:  28 | Step:  120 | loss:  tensor(0.5769, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.671
# Epoch:  28 | Step:  130 | loss:  tensor(0.8043, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6290000000000001
# Epoch:  28 | Step:  140 | loss:  tensor(0.9251, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.655
# Epoch:  28 | Step:  150 | loss:  tensor(0.5359, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.639
# Epoch:  28 | Step:  160 | loss:  tensor(0.5235, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.656
# Epoch:  28 | Step:  170 | loss:  tensor(0.5679, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.649
# Epoch:  28 | Step:  180 | loss:  tensor(0.8391, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.623
# Epoch:  28 | Step:  190 | loss:  tensor(0.5065, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.667
# Epoch:  29 | Step:  0 | loss:  tensor(0.3927, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.606
# Epoch:  29 | Step:  10 | loss:  tensor(0.8753, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6530000000000001
# Epoch:  29 | Step:  20 | loss:  tensor(0.4247, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.663
# Epoch:  29 | Step:  30 | loss:  tensor(0.4393, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.618
# Epoch:  29 | Step:  40 | loss:  tensor(0.6653, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.588
# Epoch:  29 | Step:  50 | loss:  tensor(0.4092, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.668
# Epoch:  29 | Step:  60 | loss:  tensor(0.3910, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.637
# Epoch:  29 | Step:  70 | loss:  tensor(0.3267, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6769999999999999
# Epoch:  29 | Step:  80 | loss:  tensor(0.5855, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6580000000000001
# Epoch:  29 | Step:  90 | loss:  tensor(0.2363, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.645
# Epoch:  29 | Step:  100 | loss:  tensor(0.3452, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6900000000000001
# Epoch:  29 | Step:  110 | loss:  tensor(0.5348, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6459999999999999
# Epoch:  29 | Step:  120 | loss:  tensor(0.6772, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.651
# Epoch:  29 | Step:  130 | loss:  tensor(0.3670, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.671
# Epoch:  29 | Step:  140 | loss:  tensor(0.1088, device='cuda:0') | Train_acc:  1.0 | Eval_acc:  0.672
# Epoch:  29 | Step:  150 | loss:  tensor(0.4684, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.612
# Epoch:  29 | Step:  160 | loss:  tensor(0.4700, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.651
# Epoch:  29 | Step:  170 | loss:  tensor(0.5180, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6459999999999999
# Epoch:  29 | Step:  180 | loss:  tensor(0.4297, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.692
# Epoch:  29 | Step:  190 | loss:  tensor(0.5073, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.633

# %%
x=np.arange(len(losses))*10
plt.plot(x,losses)
plt.title('CNN7 TRY 2')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN7 TRY2')
plt.xlabel('Step')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Make the CNN8 deeper and has less channles in each Conv2d layer

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
import copy
warnings.filterwarnings("ignore")

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN8(nn.Module):
    def __init__(self):
        super(CNN8,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(3,16,3,1,1,bias=False),               
            nn.BatchNorm2d(16),
            nn.ReLU(), 
            nn.Conv2d(16,16,3,1,1,bias=False),               
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16,16,3,1,1,bias=False),               
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(16,32,3,1,1,bias=False),            
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32,32,3,1,1,bias=False),            
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32,32,3,1,1,bias=False),            
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(32,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),            
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(64,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(128,256,3,1,1,bias=False),            
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )


        self.dense1=nn.Sequential(
            nn.Linear(4*4*128,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(2048,1024),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(1024,512),
            nn.ReLU()
        )
       
        self.out=nn.Linear(512,101)
        
        
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn8=CNN8().cuda()

for m in cnn8.modules():
            if isinstance(m, (nn.Conv2d, nn.Linear)):
                nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('relu'))
            if isinstance(m, ( nn.Linear)):
                nn.init.constant_(m.bias, 0.0)

print(cnn8)
# Out:
# CNN8(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=2048, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense3): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#   )
#   (out): Linear(in_features=512, out_features=101, bias=True)
# )

# %%
EPOCH = 70
BATCH_SIZE=64
LR=0.001
optimizer=torch.optim.Adam(cnn8.parameters(),lr=LR,weight_decay=0.01)
scheduler=torch.optim.lr_scheduler.StepLR(optimizer,step_size=10,gamma=0.5)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),
            torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5),
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=False, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=False, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
best_model_wts = copy.deepcopy(cnn8.state_dict())         #change
best_acc = 0.0

for epoch in range(EPOCH):
    print('Step:')
    cnn8.train()   #change
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn8(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()    
        
        if step%30==0:
            print(step)
            
    scheduler.step()        
    
    losses.append(loss.data)
    with torch.no_grad():
        cnn8.eval()   #change
        
        train_acc=[]
        for x,y in train_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn8(b_x)   #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0) 
            train_acc.append(accuracy)
            torch.cuda.empty_cache()
        train_acc=sum(train_acc)/len(train_acc)
        train_accs.append(train_acc)
        
        eval_acc=[]
        for x,y in eval_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn8(b_x)         #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0)
            eval_acc.append(accuracy)
            torch.cuda.empty_cache()
        eval_acc=sum(eval_acc)/len(eval_acc)
        eval_accs.append(eval_acc)
        
        
        if eval_acc>best_acc:
            best_acc = eval_acc
            best_model_wts = copy.deepcopy(cnn8.state_dict())         #change
            
    
    
    print('Epoch: %4s'%epoch,'| loss: ',loss.data,
            '| Train_acc: %6s'% train_acc.data,'| Eval_acc: %6s'%eval_acc.data) 
print('Best Eval acc: %6s'%best_acc)
# Out:
# Step:
# 0
# 30
# 60
# 90
# Epoch:    0 | loss:  tensor(3.8873, device='cuda:0') | Train_acc: tensor(0.1437, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.1140, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    1 | loss:  tensor(3.5447, device='cuda:0') | Train_acc: tensor(0.2732, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2490, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    2 | loss:  tensor(3.2652, device='cuda:0') | Train_acc: tensor(0.2910, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2470, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    3 | loss:  tensor(3.1997, device='cuda:0') | Train_acc: tensor(0.3254, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2780, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    4 | loss:  tensor(3.0656, device='cuda:0') | Train_acc: tensor(0.3259, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2970, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    5 | loss:  tensor(3.3829, device='cuda:0') | Train_acc: tensor(0.3515, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3400, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    6 | loss:  tensor(2.7461, device='cuda:0') | Train_acc: tensor(0.3275, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2930, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    7 | loss:  tensor(2.9347, device='cuda:0') | Train_acc: tensor(0.3916, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3770, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    8 | loss:  tensor(2.0984, device='cuda:0') | Train_acc: tensor(0.2896, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.2570, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    9 | loss:  tensor(2.3191, device='cuda:0') | Train_acc: tensor(0.4126, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4290, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   10 | loss:  tensor(2.5336, device='cuda:0') | Train_acc: tensor(0.4705, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4700, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   11 | loss:  tensor(2.2151, device='cuda:0') | Train_acc: tensor(0.4270, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.3950, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   12 | loss:  tensor(1.8252, device='cuda:0') | Train_acc: tensor(0.4651, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4570, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   13 | loss:  tensor(2.7962, device='cuda:0') | Train_acc: tensor(0.4722, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4450, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   14 | loss:  tensor(2.7276, device='cuda:0') | Train_acc: tensor(0.4640, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4610, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   15 | loss:  tensor(1.9840, device='cuda:0') | Train_acc: tensor(0.5158, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4780, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   16 | loss:  tensor(1.8076, device='cuda:0') | Train_acc: tensor(0.4807, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4930, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   17 | loss:  tensor(2.1185, device='cuda:0') | Train_acc: tensor(0.4562, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4360, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   18 | loss:  tensor(1.4312, device='cuda:0') | Train_acc: tensor(0.4582, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4290, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   19 | loss:  tensor(2.4999, device='cuda:0') | Train_acc: tensor(0.5173, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.4700, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   20 | loss:  tensor(1.9730, device='cuda:0') | Train_acc: tensor(0.5987, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5680, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   21 | loss:  tensor(1.5950, device='cuda:0') | Train_acc: tensor(0.5998, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5340, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   22 | loss:  tensor(1.3155, device='cuda:0') | Train_acc: tensor(0.5607, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5230, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   23 | loss:  tensor(1.8525, device='cuda:0') | Train_acc: tensor(0.5961, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5360, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   24 | loss:  tensor(1.4471, device='cuda:0') | Train_acc: tensor(0.5687, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5500, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   25 | loss:  tensor(1.7789, device='cuda:0') | Train_acc: tensor(0.6451, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5710, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   26 | loss:  tensor(1.4843, device='cuda:0') | Train_acc: tensor(0.6347, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5840, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   27 | loss:  tensor(1.9957, device='cuda:0') | Train_acc: tensor(0.6514, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6000, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   28 | loss:  tensor(2.6356, device='cuda:0') | Train_acc: tensor(0.6419, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5600, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   29 | loss:  tensor(1.9229, device='cuda:0') | Train_acc: tensor(0.6790, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5870, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   30 | loss:  tensor(1.1997, device='cuda:0') | Train_acc: tensor(0.7045, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6230, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   31 | loss:  tensor(1.2845, device='cuda:0') | Train_acc: tensor(0.7080, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5960, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   32 | loss:  tensor(1.6029, device='cuda:0') | Train_acc: tensor(0.7090, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6000, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   33 | loss:  tensor(1.8123, device='cuda:0') | Train_acc: tensor(0.7429, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6120, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   34 | loss:  tensor(1.0851, device='cuda:0') | Train_acc: tensor(0.7382, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6070, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   35 | loss:  tensor(0.7829, device='cuda:0') | Train_acc: tensor(0.7604, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5880, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   36 | loss:  tensor(1.2917, device='cuda:0') | Train_acc: tensor(0.7682, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6000, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   37 | loss:  tensor(1.3199, device='cuda:0') | Train_acc: tensor(0.7472, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5990, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   38 | loss:  tensor(1.2248, device='cuda:0') | Train_acc: tensor(0.7812, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5960, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   39 | loss:  tensor(0.5795, device='cuda:0') | Train_acc: tensor(0.7434, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5900, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   40 | loss:  tensor(1.0921, device='cuda:0') | Train_acc: tensor(0.8451, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6310, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   41 | loss:  tensor(0.9495, device='cuda:0') | Train_acc: tensor(0.8008, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6290, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   42 | loss:  tensor(0.9522, device='cuda:0') | Train_acc: tensor(0.8635, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5940, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   43 | loss:  tensor(0.4737, device='cuda:0') | Train_acc: tensor(0.8763, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6320, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   44 | loss:  tensor(0.6975, device='cuda:0') | Train_acc: tensor(0.8592, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6190, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   45 | loss:  tensor(0.7705, device='cuda:0') | Train_acc: tensor(0.8683, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6420, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   46 | loss:  tensor(0.5476, device='cuda:0') | Train_acc: tensor(0.8670, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6280, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   47 | loss:  tensor(0.5312, device='cuda:0') | Train_acc: tensor(0.8734, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6220, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   48 | loss:  tensor(0.6293, device='cuda:0') | Train_acc: tensor(0.8993, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6350, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   49 | loss:  tensor(0.7321, device='cuda:0') | Train_acc: tensor(0.8796, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.5960, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   50 | loss:  tensor(0.8679, device='cuda:0') | Train_acc: tensor(0.9355, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6330, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   51 | loss:  tensor(0.5317, device='cuda:0') | Train_acc: tensor(0.9347, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6470, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   52 | loss:  tensor(0.7974, device='cuda:0') | Train_acc: tensor(0.9439, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6280, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   53 | loss:  tensor(0.9852, device='cuda:0') | Train_acc: tensor(0.9458, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6320, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   54 | loss:  tensor(0.3733, device='cuda:0') | Train_acc: tensor(0.9468, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6380, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   55 | loss:  tensor(0.5014, device='cuda:0') | Train_acc: tensor(0.9494, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6320, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   56 | loss:  tensor(0.3397, device='cuda:0') | Train_acc: tensor(0.9442, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6400, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   57 | loss:  tensor(0.4440, device='cuda:0') | Train_acc: tensor(0.9537, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6550, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   58 | loss:  tensor(0.5127, device='cuda:0') | Train_acc: tensor(0.9505, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6550, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   59 | loss:  tensor(0.4938, device='cuda:0') | Train_acc: tensor(0.9507, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6330, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   60 | loss:  tensor(0.4090, device='cuda:0') | Train_acc: tensor(0.9650, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6360, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   61 | loss:  tensor(0.2298, device='cuda:0') | Train_acc: tensor(0.9701, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6480, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   62 | loss:  tensor(0.5239, device='cuda:0') | Train_acc: tensor(0.9706, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6470, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   63 | loss:  tensor(0.6490, device='cuda:0') | Train_acc: tensor(0.9724, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6340, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   64 | loss:  tensor(0.4571, device='cuda:0') | Train_acc: tensor(0.9736, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6440, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   65 | loss:  tensor(0.4315, device='cuda:0') | Train_acc: tensor(0.9715, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6220, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   66 | loss:  tensor(0.2099, device='cuda:0') | Train_acc: tensor(0.9763, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6260, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   67 | loss:  tensor(0.2571, device='cuda:0') | Train_acc: tensor(0.9796, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6230, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   68 | loss:  tensor(0.4350, device='cuda:0') | Train_acc: tensor(0.9815, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6380, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   69 | loss:  tensor(0.5676, device='cuda:0') | Train_acc: tensor(0.9806, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6270, device='cuda:0', dtype=torch.float64)
# Best Eval acc: tensor(0.6550, device='cuda:0', dtype=torch.float64)

# %%
x=np.arange(len(losses))
plt.plot(x,losses)
plt.title('CNN8 TRY 2')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN8 TRY2')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

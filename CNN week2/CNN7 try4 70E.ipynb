# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Xinmeng\AppData\Roaming\Python\Python35\site-packages\pandas\compat\_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.1.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN7(nn.Module):
    def __init__(self):
        super(CNN7,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(
                in_channels=3,    #前面的层有多高
                out_channels=64,   #filter 的个数
                kernel_size=7,
                stride=1,
                padding=(3,3)  # if stride=1, padding=(kernel_size-1)/2
            ), 
            nn.ReLU(),   
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(64,64,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(64,128,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(128,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv7=nn.Sequential(
            nn.Conv2d(256,512,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(512),
            nn.MaxPool2d(2)
        )


        self.dense1=nn.Sequential(
            nn.Linear(2*2*512,4096),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(4096,4096),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(4096,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(2048,101)
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=self.conv7(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn7=CNN7().cuda()
print(cnn7)
# Out:
# CNN7(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv7): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=2048, out_features=4096, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=4096, out_features=4096, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense3): Sequential(
#     (0): Linear(in_features=4096, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=2048, out_features=101, bias=True)
# )

# %%
EPOCH = 70
BATCH_SIZE=64
LR=0.001
optimizer=torch.optim.Adam(cnn7.parameters(),lr=LR,weight_decay=0.001)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),
            torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5),
            torchvision.transforms.ToTensor()]))

eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
    torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=False, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=False, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
for epoch in range(EPOCH):
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn7(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if step%30==0:
            with torch.no_grad():
                pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                train_accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                train_accs.append(train_accuracy)
                losses.append(loss.data)
                torch.cuda.empty_cache()
                eval_acc=[]
                for x,y in eval_loader:
                    b_x=Variable(x).cuda()
                    b_y=Variable(y).cuda()        
                    output=cnn7(b_x)         #change
                    pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                    accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                    eval_acc.append(accuracy)
                eval_accs.append(np.mean(eval_acc))
                print('Epoch: ',epoch,'| Step: ',step,'| loss: ',loss.data,
                      '| Train_acc: ', train_accuracy,'| Eval_acc: ', np.mean(eval_acc))
# Out:
# Epoch:  0 | Step:  0 | loss:  tensor(7.3052, device='cuda:0') | Train_acc:  0.09375 | Eval_acc:  0.089
# Epoch:  0 | Step:  30 | loss:  tensor(4.7706, device='cuda:0') | Train_acc:  0.03125 | Eval_acc:  0.139
# Epoch:  0 | Step:  60 | loss:  tensor(4.3371, device='cuda:0') | Train_acc:  0.109375 | Eval_acc:  0.162
# Epoch:  0 | Step:  90 | loss:  tensor(4.0364, device='cuda:0') | Train_acc:  0.09375 | Eval_acc:  0.201
# Epoch:  1 | Step:  0 | loss:  tensor(3.9494, device='cuda:0') | Train_acc:  0.203125 | Eval_acc:  0.16199999999999998
# Epoch:  1 | Step:  30 | loss:  tensor(3.9873, device='cuda:0') | Train_acc:  0.171875 | Eval_acc:  0.189
# Epoch:  1 | Step:  60 | loss:  tensor(4.0169, device='cuda:0') | Train_acc:  0.15625 | Eval_acc:  0.225
# Epoch:  1 | Step:  90 | loss:  tensor(3.6344, device='cuda:0') | Train_acc:  0.21875 | Eval_acc:  0.238
# Epoch:  2 | Step:  0 | loss:  tensor(3.4955, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.244
# Epoch:  2 | Step:  30 | loss:  tensor(3.4527, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.225
# Epoch:  2 | Step:  60 | loss:  tensor(3.7472, device='cuda:0') | Train_acc:  0.203125 | Eval_acc:  0.301
# Epoch:  2 | Step:  90 | loss:  tensor(3.4618, device='cuda:0') | Train_acc:  0.234375 | Eval_acc:  0.273
# Epoch:  3 | Step:  0 | loss:  tensor(3.1949, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.259
# Epoch:  3 | Step:  30 | loss:  tensor(3.2974, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.292
# Epoch:  3 | Step:  60 | loss:  tensor(3.4665, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.359
# Epoch:  3 | Step:  90 | loss:  tensor(2.7001, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.3430000000000001
# Epoch:  4 | Step:  0 | loss:  tensor(3.1070, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.34199999999999997
# Epoch:  4 | Step:  30 | loss:  tensor(3.5066, device='cuda:0') | Train_acc:  0.25 | Eval_acc:  0.333
# Epoch:  4 | Step:  60 | loss:  tensor(2.7187, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.362
# Epoch:  4 | Step:  90 | loss:  tensor(3.6714, device='cuda:0') | Train_acc:  0.25 | Eval_acc:  0.352
# Epoch:  5 | Step:  0 | loss:  tensor(2.7278, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.321
# Epoch:  5 | Step:  30 | loss:  tensor(3.4136, device='cuda:0') | Train_acc:  0.234375 | Eval_acc:  0.353
# Epoch:  5 | Step:  60 | loss:  tensor(2.8728, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.34800000000000003
# Epoch:  5 | Step:  90 | loss:  tensor(3.3634, device='cuda:0') | Train_acc:  0.25 | Eval_acc:  0.389
# Epoch:  6 | Step:  0 | loss:  tensor(3.1887, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.339
# Epoch:  6 | Step:  30 | loss:  tensor(2.7528, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.33599999999999997
# Epoch:  6 | Step:  60 | loss:  tensor(3.4289, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.35900000000000004
# Epoch:  6 | Step:  90 | loss:  tensor(2.9452, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.36
# Epoch:  7 | Step:  0 | loss:  tensor(2.9867, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.418
# Epoch:  7 | Step:  30 | loss:  tensor(2.9452, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.40199999999999997
# Epoch:  7 | Step:  60 | loss:  tensor(3.8003, device='cuda:0') | Train_acc:  0.15625 | Eval_acc:  0.362
# Epoch:  7 | Step:  90 | loss:  tensor(2.6019, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.391
# Epoch:  8 | Step:  0 | loss:  tensor(2.9265, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.384
# Epoch:  8 | Step:  30 | loss:  tensor(3.0316, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.4290000000000001
# Epoch:  8 | Step:  60 | loss:  tensor(2.6180, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.40599999999999997
# Epoch:  8 | Step:  90 | loss:  tensor(2.7359, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.43800000000000006
# Epoch:  9 | Step:  0 | loss:  tensor(2.8253, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.41600000000000004
# Epoch:  9 | Step:  30 | loss:  tensor(2.2710, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.40099999999999997
# Epoch:  9 | Step:  60 | loss:  tensor(2.6643, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.44000000000000006
# Epoch:  9 | Step:  90 | loss:  tensor(2.7163, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.40800000000000003
# Epoch:  10 | Step:  0 | loss:  tensor(2.3329, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.41999999999999993
# Epoch:  10 | Step:  30 | loss:  tensor(1.7553, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.41899999999999993
# Epoch:  10 | Step:  60 | loss:  tensor(1.9898, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.433
# Epoch:  10 | Step:  90 | loss:  tensor(2.5489, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.45899999999999996
# Epoch:  11 | Step:  0 | loss:  tensor(2.8357, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.45500000000000007
# Epoch:  11 | Step:  30 | loss:  tensor(2.1887, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.4779999999999999
# Epoch:  11 | Step:  60 | loss:  tensor(2.5489, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.46399999999999997
# Epoch:  11 | Step:  90 | loss:  tensor(2.6481, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.492
# Epoch:  12 | Step:  0 | loss:  tensor(2.8014, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.45600000000000007
# Epoch:  12 | Step:  30 | loss:  tensor(2.2336, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.47000000000000003
# Epoch:  12 | Step:  60 | loss:  tensor(2.2525, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.43800000000000006
# Epoch:  12 | Step:  90 | loss:  tensor(2.1131, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.484
# Epoch:  13 | Step:  0 | loss:  tensor(1.9501, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.509
# Epoch:  13 | Step:  30 | loss:  tensor(1.8557, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.49399999999999994
# Epoch:  13 | Step:  60 | loss:  tensor(2.2217, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.48900000000000005
# Epoch:  13 | Step:  90 | loss:  tensor(2.0230, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.47400000000000003
# Epoch:  14 | Step:  0 | loss:  tensor(2.0149, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.508
# Epoch:  14 | Step:  30 | loss:  tensor(2.5000, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.505
# Epoch:  14 | Step:  60 | loss:  tensor(2.2002, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.501
# Epoch:  14 | Step:  90 | loss:  tensor(2.0918, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.493
# Epoch:  15 | Step:  0 | loss:  tensor(1.9612, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.502
# Epoch:  15 | Step:  30 | loss:  tensor(2.0442, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.47300000000000003
# Epoch:  15 | Step:  60 | loss:  tensor(1.9150, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.5210000000000001
# Epoch:  15 | Step:  90 | loss:  tensor(2.3990, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.5269999999999999
# Epoch:  16 | Step:  0 | loss:  tensor(1.7905, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.532
# Epoch:  16 | Step:  30 | loss:  tensor(2.5089, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.5250000000000001
# Epoch:  16 | Step:  60 | loss:  tensor(2.4495, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.508
# Epoch:  16 | Step:  90 | loss:  tensor(1.8699, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.499
# Epoch:  17 | Step:  0 | loss:  tensor(1.5217, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.5509999999999999
# Epoch:  17 | Step:  30 | loss:  tensor(1.7778, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.534
# Epoch:  17 | Step:  60 | loss:  tensor(2.2148, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.54
# Epoch:  17 | Step:  90 | loss:  tensor(1.9053, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.527
# Epoch:  18 | Step:  0 | loss:  tensor(1.7954, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.523
# Epoch:  18 | Step:  30 | loss:  tensor(2.0341, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.524
# Epoch:  18 | Step:  60 | loss:  tensor(2.7919, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.518
# Epoch:  18 | Step:  90 | loss:  tensor(1.4670, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.5229999999999999
# Epoch:  19 | Step:  0 | loss:  tensor(1.9422, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.54
# Epoch:  19 | Step:  30 | loss:  tensor(1.4289, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.537
# Epoch:  19 | Step:  60 | loss:  tensor(1.2307, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.568
# Epoch:  19 | Step:  90 | loss:  tensor(2.0675, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.552
# Epoch:  20 | Step:  0 | loss:  tensor(2.1463, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.518
# Epoch:  20 | Step:  30 | loss:  tensor(2.0078, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.564
# Epoch:  20 | Step:  60 | loss:  tensor(1.6638, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.531
# Epoch:  20 | Step:  90 | loss:  tensor(1.3266, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.556
# Epoch:  21 | Step:  0 | loss:  tensor(1.5942, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.562
# Epoch:  21 | Step:  30 | loss:  tensor(1.6054, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.5599999999999999
# Epoch:  21 | Step:  60 | loss:  tensor(1.6054, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.591
# Epoch:  21 | Step:  90 | loss:  tensor(1.4245, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.557
# Epoch:  22 | Step:  0 | loss:  tensor(1.5037, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.6
# Epoch:  22 | Step:  30 | loss:  tensor(1.6169, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5519999999999999
# Epoch:  22 | Step:  60 | loss:  tensor(1.5620, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.599
# Epoch:  22 | Step:  90 | loss:  tensor(1.6229, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.5640000000000001
# Epoch:  23 | Step:  0 | loss:  tensor(1.4613, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.571
# Epoch:  23 | Step:  30 | loss:  tensor(1.7403, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.599
# Epoch:  23 | Step:  60 | loss:  tensor(1.3044, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.568
# Epoch:  23 | Step:  90 | loss:  tensor(1.2789, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.548
# Epoch:  24 | Step:  0 | loss:  tensor(1.0984, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.615
# Epoch:  24 | Step:  30 | loss:  tensor(1.3642, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.624
# Epoch:  24 | Step:  60 | loss:  tensor(1.3608, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.57
# Epoch:  24 | Step:  90 | loss:  tensor(1.2416, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5980000000000001
# Epoch:  25 | Step:  0 | loss:  tensor(0.7191, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5960000000000001
# Epoch:  25 | Step:  30 | loss:  tensor(1.6009, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.6020000000000001
# Epoch:  25 | Step:  60 | loss:  tensor(1.3993, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.61
# Epoch:  25 | Step:  90 | loss:  tensor(1.0710, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.5980000000000001
# Epoch:  26 | Step:  0 | loss:  tensor(0.8449, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.595
# Epoch:  26 | Step:  30 | loss:  tensor(0.6913, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.621
# Epoch:  26 | Step:  60 | loss:  tensor(1.2195, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.5970000000000001
# Epoch:  26 | Step:  90 | loss:  tensor(1.3438, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.593
# Epoch:  27 | Step:  0 | loss:  tensor(1.1154, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.599
# Epoch:  27 | Step:  30 | loss:  tensor(1.2509, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.591
# Epoch:  27 | Step:  60 | loss:  tensor(1.3422, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.608
# Epoch:  27 | Step:  90 | loss:  tensor(1.3076, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.592
# Epoch:  28 | Step:  0 | loss:  tensor(1.1874, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.616
# Epoch:  28 | Step:  30 | loss:  tensor(1.1529, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.6049999999999999
# Epoch:  28 | Step:  60 | loss:  tensor(1.0160, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.61
# Epoch:  28 | Step:  90 | loss:  tensor(0.9561, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.617
# Epoch:  29 | Step:  0 | loss:  tensor(0.7165, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.645
# Epoch:  29 | Step:  30 | loss:  tensor(0.9010, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5980000000000001
# Epoch:  29 | Step:  60 | loss:  tensor(1.4218, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.606
# Epoch:  29 | Step:  90 | loss:  tensor(1.1714, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.592
# Epoch:  30 | Step:  0 | loss:  tensor(0.7842, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.607
# Epoch:  30 | Step:  30 | loss:  tensor(0.8623, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5820000000000001
# Epoch:  30 | Step:  60 | loss:  tensor(1.0063, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.614
# Epoch:  30 | Step:  90 | loss:  tensor(1.1862, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.6060000000000001
# Epoch:  31 | Step:  0 | loss:  tensor(1.0190, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6060000000000001
# Epoch:  31 | Step:  30 | loss:  tensor(0.9037, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.615
# Epoch:  31 | Step:  60 | loss:  tensor(0.6111, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.601
# Epoch:  31 | Step:  90 | loss:  tensor(0.8145, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.664
# Epoch:  32 | Step:  0 | loss:  tensor(0.8197, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.637
# Epoch:  32 | Step:  30 | loss:  tensor(0.6507, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.635
# Epoch:  32 | Step:  60 | loss:  tensor(1.1724, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6289999999999999
# Epoch:  32 | Step:  90 | loss:  tensor(1.1553, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.616
# Epoch:  33 | Step:  0 | loss:  tensor(0.8033, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.6300000000000001
# Epoch:  33 | Step:  30 | loss:  tensor(0.8040, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6449999999999999
# Epoch:  33 | Step:  60 | loss:  tensor(1.0792, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.616
# Epoch:  33 | Step:  90 | loss:  tensor(0.8076, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.638
# Epoch:  34 | Step:  0 | loss:  tensor(0.5310, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5980000000000001
# Epoch:  34 | Step:  30 | loss:  tensor(0.5695, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6370000000000001
# Epoch:  34 | Step:  60 | loss:  tensor(1.0524, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.6460000000000001
# Epoch:  34 | Step:  90 | loss:  tensor(0.9630, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6220000000000001
# Epoch:  35 | Step:  0 | loss:  tensor(0.7981, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.6450000000000001
# Epoch:  35 | Step:  30 | loss:  tensor(0.7944, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.655
# Epoch:  35 | Step:  60 | loss:  tensor(0.5527, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.603
# Epoch:  35 | Step:  90 | loss:  tensor(1.0377, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.6769999999999999
# Epoch:  36 | Step:  0 | loss:  tensor(0.5101, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.63
# Epoch:  36 | Step:  30 | loss:  tensor(0.5197, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6540000000000001
# Epoch:  36 | Step:  60 | loss:  tensor(0.5838, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6290000000000001
# Epoch:  36 | Step:  90 | loss:  tensor(0.5055, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.617
# Epoch:  37 | Step:  0 | loss:  tensor(0.5188, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.624
# Epoch:  37 | Step:  30 | loss:  tensor(0.5226, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.633
# Epoch:  37 | Step:  60 | loss:  tensor(0.6780, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.6539999999999999
# Epoch:  37 | Step:  90 | loss:  tensor(0.6941, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.643
# Epoch:  38 | Step:  0 | loss:  tensor(0.5998, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6609999999999999
# Epoch:  38 | Step:  30 | loss:  tensor(0.5748, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.634
# Epoch:  38 | Step:  60 | loss:  tensor(0.7425, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6719999999999999
# Epoch:  38 | Step:  90 | loss:  tensor(0.6262, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.65
# Epoch:  39 | Step:  0 | loss:  tensor(0.3275, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.664
# Epoch:  39 | Step:  30 | loss:  tensor(0.5847, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6439999999999999
# Epoch:  39 | Step:  60 | loss:  tensor(0.5981, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6020000000000001
# Epoch:  39 | Step:  90 | loss:  tensor(0.8857, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.6540000000000001
# Epoch:  40 | Step:  0 | loss:  tensor(0.7109, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.6569999999999999
# Epoch:  40 | Step:  30 | loss:  tensor(0.2919, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.646
# Epoch:  40 | Step:  60 | loss:  tensor(0.6832, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.647
# Epoch:  40 | Step:  90 | loss:  tensor(1.1089, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.6199999999999999
# Epoch:  41 | Step:  0 | loss:  tensor(0.4193, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.616
# Epoch:  41 | Step:  30 | loss:  tensor(0.5334, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.624
# Epoch:  41 | Step:  60 | loss:  tensor(0.4381, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.641
# Epoch:  41 | Step:  90 | loss:  tensor(0.4013, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.65
# Epoch:  42 | Step:  0 | loss:  tensor(0.4029, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.649
# Epoch:  42 | Step:  30 | loss:  tensor(0.6923, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.648
# Epoch:  42 | Step:  60 | loss:  tensor(0.5583, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.627
# Epoch:  42 | Step:  90 | loss:  tensor(0.7333, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.635
# Epoch:  43 | Step:  0 | loss:  tensor(0.4964, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.64
# Epoch:  43 | Step:  30 | loss:  tensor(0.4115, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.635
# Epoch:  43 | Step:  60 | loss:  tensor(0.6733, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.655
# Epoch:  43 | Step:  90 | loss:  tensor(0.5264, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6539999999999999
# Epoch:  44 | Step:  0 | loss:  tensor(0.4932, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6
# Epoch:  44 | Step:  30 | loss:  tensor(0.4831, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.707
# Epoch:  44 | Step:  60 | loss:  tensor(0.6978, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.603
# Epoch:  44 | Step:  90 | loss:  tensor(0.8276, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.618
# Epoch:  45 | Step:  0 | loss:  tensor(0.6273, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6609999999999999
# Epoch:  45 | Step:  30 | loss:  tensor(0.5456, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.634
# Epoch:  45 | Step:  60 | loss:  tensor(0.5209, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.655
# Epoch:  45 | Step:  90 | loss:  tensor(0.9387, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.647
# Epoch:  46 | Step:  0 | loss:  tensor(0.1536, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.623
# Epoch:  46 | Step:  30 | loss:  tensor(0.3802, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.655
# Epoch:  46 | Step:  60 | loss:  tensor(0.5642, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6479999999999999
# Epoch:  46 | Step:  90 | loss:  tensor(0.4557, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6279999999999999
# Epoch:  47 | Step:  0 | loss:  tensor(0.3035, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.646
# Epoch:  47 | Step:  30 | loss:  tensor(0.3641, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.631
# Epoch:  47 | Step:  60 | loss:  tensor(0.5610, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.655
# Epoch:  47 | Step:  90 | loss:  tensor(0.3974, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.655
# Epoch:  48 | Step:  0 | loss:  tensor(0.2951, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.667
# Epoch:  48 | Step:  30 | loss:  tensor(0.3459, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.651
# Epoch:  48 | Step:  60 | loss:  tensor(0.5212, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.653
# Epoch:  48 | Step:  90 | loss:  tensor(0.5699, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.688
# Epoch:  49 | Step:  0 | loss:  tensor(0.4197, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.648
# Epoch:  49 | Step:  30 | loss:  tensor(0.3162, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6620000000000001
# Epoch:  49 | Step:  60 | loss:  tensor(0.2565, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.653
# Epoch:  49 | Step:  90 | loss:  tensor(0.3941, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.658
# Epoch:  50 | Step:  0 | loss:  tensor(0.2296, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6289999999999999
# Epoch:  50 | Step:  30 | loss:  tensor(0.5454, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.665
# Epoch:  50 | Step:  60 | loss:  tensor(0.5132, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.645
# Epoch:  50 | Step:  90 | loss:  tensor(0.5279, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.688
# Epoch:  51 | Step:  0 | loss:  tensor(0.1676, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.641
# Epoch:  51 | Step:  30 | loss:  tensor(0.5102, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.6689999999999999
# Epoch:  51 | Step:  60 | loss:  tensor(0.3409, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.652
# Epoch:  51 | Step:  90 | loss:  tensor(0.9623, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.655
# Epoch:  52 | Step:  0 | loss:  tensor(0.6251, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6759999999999999
# Epoch:  52 | Step:  30 | loss:  tensor(0.4307, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6679999999999999
# Epoch:  52 | Step:  60 | loss:  tensor(0.2734, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6780000000000002
# Epoch:  52 | Step:  90 | loss:  tensor(0.5863, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.6719999999999999
# Epoch:  53 | Step:  0 | loss:  tensor(0.3500, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.688
# Epoch:  53 | Step:  30 | loss:  tensor(0.3165, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6849999999999999
# Epoch:  53 | Step:  60 | loss:  tensor(0.4337, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.659
# Epoch:  53 | Step:  90 | loss:  tensor(0.5010, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.637
# Epoch:  54 | Step:  0 | loss:  tensor(0.2714, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6629999999999999
# Epoch:  54 | Step:  30 | loss:  tensor(0.2409, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.695
# Epoch:  54 | Step:  60 | loss:  tensor(0.4144, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6849999999999999
# Epoch:  54 | Step:  90 | loss:  tensor(0.5279, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.632
# Epoch:  55 | Step:  0 | loss:  tensor(0.2341, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.617
# Epoch:  55 | Step:  30 | loss:  tensor(0.2511, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.6100000000000001
# Epoch:  55 | Step:  60 | loss:  tensor(0.2946, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.655
# Epoch:  55 | Step:  90 | loss:  tensor(0.2516, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.654
# Epoch:  56 | Step:  0 | loss:  tensor(0.4506, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.664
# Epoch:  56 | Step:  30 | loss:  tensor(0.5164, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6849999999999999
# Epoch:  56 | Step:  60 | loss:  tensor(0.3645, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.7040000000000001
# Epoch:  56 | Step:  90 | loss:  tensor(0.3405, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.665
# Epoch:  57 | Step:  0 | loss:  tensor(0.4198, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6439999999999999
# Epoch:  57 | Step:  30 | loss:  tensor(0.4076, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6359999999999999
# Epoch:  57 | Step:  60 | loss:  tensor(0.3511, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6380000000000001
# Epoch:  57 | Step:  90 | loss:  tensor(0.3588, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.644
# Epoch:  58 | Step:  0 | loss:  tensor(0.2069, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.664
# Epoch:  58 | Step:  30 | loss:  tensor(0.3534, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6609999999999999
# Epoch:  58 | Step:  60 | loss:  tensor(0.2527, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.655
# Epoch:  58 | Step:  90 | loss:  tensor(0.2836, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.646
# Epoch:  59 | Step:  0 | loss:  tensor(0.3007, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.663
# Epoch:  59 | Step:  30 | loss:  tensor(0.3244, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.675
# Epoch:  59 | Step:  60 | loss:  tensor(0.3789, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.651
# Epoch:  59 | Step:  90 | loss:  tensor(0.4198, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.633
# Epoch:  60 | Step:  0 | loss:  tensor(0.3144, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.652
# Epoch:  60 | Step:  30 | loss:  tensor(0.3989, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.662
# Epoch:  60 | Step:  60 | loss:  tensor(0.3292, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6469999999999999
# Epoch:  60 | Step:  90 | loss:  tensor(0.3172, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6320000000000001
# Epoch:  61 | Step:  0 | loss:  tensor(0.2986, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.667
# Epoch:  61 | Step:  30 | loss:  tensor(0.2665, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.653
# Epoch:  61 | Step:  60 | loss:  tensor(0.1629, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.661
# Epoch:  61 | Step:  90 | loss:  tensor(0.3651, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.683
# Epoch:  62 | Step:  0 | loss:  tensor(0.3218, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6860000000000002
# Epoch:  62 | Step:  30 | loss:  tensor(0.3419, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6779999999999999
# Epoch:  62 | Step:  60 | loss:  tensor(0.2119, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.633
# Epoch:  62 | Step:  90 | loss:  tensor(0.1290, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.663
# Epoch:  63 | Step:  0 | loss:  tensor(0.3048, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6379999999999999
# Epoch:  63 | Step:  30 | loss:  tensor(0.3467, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.651
# Epoch:  63 | Step:  60 | loss:  tensor(0.3623, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6370000000000001
# Epoch:  63 | Step:  90 | loss:  tensor(0.2744, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.641
# Epoch:  64 | Step:  0 | loss:  tensor(0.2855, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.65
# Epoch:  64 | Step:  30 | loss:  tensor(0.4431, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.647
# Epoch:  64 | Step:  60 | loss:  tensor(0.2331, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.642
# Epoch:  64 | Step:  90 | loss:  tensor(0.4668, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.646
# Epoch:  65 | Step:  0 | loss:  tensor(0.5172, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6380000000000001
# Epoch:  65 | Step:  30 | loss:  tensor(0.5928, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.627
# Epoch:  65 | Step:  60 | loss:  tensor(0.4564, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.601
# Epoch:  65 | Step:  90 | loss:  tensor(0.6170, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.633
# Epoch:  66 | Step:  0 | loss:  tensor(0.3462, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6700000000000002
# Epoch:  66 | Step:  30 | loss:  tensor(0.4010, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.6599999999999999
# Epoch:  66 | Step:  60 | loss:  tensor(0.3345, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.645
# Epoch:  66 | Step:  90 | loss:  tensor(0.8162, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.659
# Epoch:  67 | Step:  0 | loss:  tensor(0.2991, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6679999999999999
# Epoch:  67 | Step:  30 | loss:  tensor(0.4705, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.635
# Epoch:  67 | Step:  60 | loss:  tensor(0.1737, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.643
# Epoch:  67 | Step:  90 | loss:  tensor(0.1725, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.663
# Epoch:  68 | Step:  0 | loss:  tensor(0.3189, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.6460000000000001
# Epoch:  68 | Step:  30 | loss:  tensor(0.2102, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.641
# Epoch:  68 | Step:  60 | loss:  tensor(0.2233, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.7010000000000001
# Epoch:  68 | Step:  90 | loss:  tensor(0.2367, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.6609999999999999
# Epoch:  69 | Step:  0 | loss:  tensor(0.1276, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.682
# Epoch:  69 | Step:  30 | loss:  tensor(0.2484, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.696
# Epoch:  69 | Step:  60 | loss:  tensor(0.4451, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.658
# Epoch:  69 | Step:  90 | loss:  tensor(0.2164, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.679

# %%
x=np.arange(len(losses))
plt.plot(x,losses)
plt.title('CNN7 TRY 5')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN7 TRY 5')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
torch.save(cnn7.state_dict(),'CNN7 try4.pkl')
#torch.save(cnn1,'CNN1_model.pkl')

# %%
train_acc=[]
with torch.no_grad():
    for x,y in train_loader:
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()        
        output=cnn7(b_x)
        pred_y=torch.max(output,1)[1].cuda().data.squeeze()
        accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
        train_acc.append(accuracy)
train_acc
# Out:
# [0.921875,
#  0.921875,
#  0.9375,
#  0.953125,
#  0.953125,
#  0.9375,
#  0.9375,
#  0.953125,
#  0.953125,
#  0.9375,
#  0.90625,
#  0.96875,
#  0.9375,
#  0.921875,
#  0.890625,
#  0.96875,
#  0.921875,
#  0.953125,
#  0.875,
#  0.984375,
#  0.9375,
#  0.921875,
#  0.9375,
#  0.9375,
#  0.953125,
#  0.859375,
#  0.984375,
#  0.890625,
#  0.90625,
#  0.890625,
#  0.921875,
#  0.90625,
#  0.90625,
#  0.890625,
#  0.953125,
#  0.9375,
#  1.0,
#  0.953125,
#  0.921875,
#  0.953125,
#  0.953125,
#  0.96875,
#  0.921875,
#  0.90625,
#  0.90625,
#  0.921875,
#  0.953125,
#  0.9375,
#  0.96875,
#  0.90625,
#  0.9375,
#  0.90625,
#  0.96875,
#  0.96875,
#  0.921875,
#  0.953125,
#  0.96875,
#  0.9375,
#  0.9375,
#  0.984375,
#  0.890625,
#  0.890625,
#  0.953125,
#  0.921875,
#  0.9375,
#  0.90625,
#  0.9375,
#  0.9375,
#  0.953125,
#  0.90625,
#  0.84375,
#  0.96875,
#  0.9375,
#  0.890625,
#  0.953125,
#  0.890625,
#  0.96875,
#  0.953125,
#  0.96875,
#  0.90625,
#  0.984375,
#  0.96875,
#  0.96875,
#  0.953125,
#  0.921875,
#  0.9375,
#  0.859375,
#  0.984375,
#  0.953125,
#  0.953125,
#  0.953125,
#  0.953125,
#  0.9375,
#  0.921875,
#  0.96875,
#  0.9375,
#  0.9444444444444444]

# %%
eval_acc=[]
with torch.no_grad():
    for x,y in eval_loader:
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()        
        output=cnn7(b_x)
        pred_y=torch.max(output,1)[1].cuda().data.squeeze()
        accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
        eval_acc.append(accuracy)
eval_acc
# Out:
# [0.89, 0.62, 0.465, 0.525, 0.55]

# %%
test_acc=[]
with torch.no_grad():
    for x,y in eval_loader:
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()        
        output=cnn7(b_x)
        pred_y=torch.max(output,1)[1].cuda().data.squeeze()
        accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
        test_acc.append(accuracy)
test_acc
# Out:
# [0.895, 0.65, 0.445, 0.485, 0.5]

# %%
np.mean(train_acc)
# Out:
# 0.935477520045819

# %%
np.mean(eval_acc)
# Out:
# 0.61

# %%
np.mean(test_acc)
# Out:
# 0.595

# %% [markdown]
# 90E+30E+30E+30E Based on 0.79 version

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
import copy
warnings.filterwarnings("ignore")

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN8(nn.Module):
    def __init__(self):
        super(CNN8,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(3,16,3,1,1,bias=False),               
            nn.BatchNorm2d(16),
            nn.ReLU(), 
            nn.Conv2d(16,16,3,1,1,bias=False),               
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16,16,3,1,1,bias=False),               
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(16,32,3,1,1,bias=False),            
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32,32,3,1,1,bias=False),            
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32,32,3,1,1,bias=False),            
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(32,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),            
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(64,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(128,256,3,1,1,bias=False),            
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )


        self.dense1=nn.Sequential(
            nn.Linear(4*4*128,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(2048,1024),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(1024,101)
        
        
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        output=self.out(x)
        return output       
cnn8=CNN8().cuda()


cnn8.load_state_dict(torch.load('/kaggle/input/cnn8-try3-weight/CNN8 continue 2 best.pkl'))

print(cnn8)
# Out:
# CNN8(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=2048, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=1024, out_features=101, bias=True)
# )

# %%
EPOCH = 30
BATCH_SIZE=64
LR=1.25e-5
optimizer=torch.optim.Adam(cnn8.parameters(),lr=LR,weight_decay=0.01)
scheduler=torch.optim.lr_scheduler.StepLR(optimizer,step_size=10,gamma=0.5)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),
            torchvision.transforms.RandomCrop(256,padding=32),
            torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5),
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=False, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=False, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
best_model_wts = copy.deepcopy(cnn8.state_dict())         #change
best_acc = 0.0


for epoch in range(EPOCH):
    print('Step:')
    cnn8.train()   #change
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn8(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()    
        
        if step%30==0:
            print(step)
            
    scheduler.step()        
    
    losses.append(loss.data)
    with torch.no_grad():
        cnn8.eval()   #change
        
        train_acc=[]
        for x,y in train_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn8(b_x)   #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0) 
            train_acc.append(accuracy)
            torch.cuda.empty_cache()
        train_acc=sum(train_acc)/len(train_acc)
        train_accs.append(train_acc)
        
        eval_acc=[]
        for x,y in eval_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn8(b_x)         #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0)
            eval_acc.append(accuracy)
            torch.cuda.empty_cache()
        eval_acc=sum(eval_acc)/len(eval_acc)
        eval_accs.append(eval_acc)
        
        
        if eval_acc>best_acc:
            best_acc = eval_acc
            best_model_wts = copy.deepcopy(cnn8.state_dict())         #change
            
    
    
    print('Epoch: %4s'%epoch,'| loss: ',loss.data,
            '| Train_acc: %6s'% train_acc.data,'| Eval_acc: %6s'%eval_acc.data) 
print('Best Eval acc: %6s'%best_acc)
# Out:
# Step:
# 0
# 30
# 60
# 90
# Epoch:    0 | loss:  tensor(0.0868, device='cuda:0') | Train_acc: tensor(0.9800, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7740, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    1 | loss:  tensor(0.0854, device='cuda:0') | Train_acc: tensor(0.9813, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7830, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    2 | loss:  tensor(0.0685, device='cuda:0') | Train_acc: tensor(0.9849, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7860, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    3 | loss:  tensor(0.0948, device='cuda:0') | Train_acc: tensor(0.9831, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7800, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    4 | loss:  tensor(0.0620, device='cuda:0') | Train_acc: tensor(0.9821, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7830, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    5 | loss:  tensor(0.1313, device='cuda:0') | Train_acc: tensor(0.9844, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7640, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    6 | loss:  tensor(0.0400, device='cuda:0') | Train_acc: tensor(0.9850, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7590, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    7 | loss:  tensor(0.0681, device='cuda:0') | Train_acc: tensor(0.9812, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7840, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    8 | loss:  tensor(0.0355, device='cuda:0') | Train_acc: tensor(0.9850, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7740, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    9 | loss:  tensor(0.0739, device='cuda:0') | Train_acc: tensor(0.9844, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7820, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   10 | loss:  tensor(0.1334, device='cuda:0') | Train_acc: tensor(0.9882, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7710, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   11 | loss:  tensor(0.0927, device='cuda:0') | Train_acc: tensor(0.9870, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7790, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   12 | loss:  tensor(0.0535, device='cuda:0') | Train_acc: tensor(0.9892, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7810, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   13 | loss:  tensor(0.0459, device='cuda:0') | Train_acc: tensor(0.9889, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7880, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   14 | loss:  tensor(0.1114, device='cuda:0') | Train_acc: tensor(0.9846, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7910, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   15 | loss:  tensor(0.0775, device='cuda:0') | Train_acc: tensor(0.9882, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7830, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   16 | loss:  tensor(0.0392, device='cuda:0') | Train_acc: tensor(0.9887, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7770, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   17 | loss:  tensor(0.0808, device='cuda:0') | Train_acc: tensor(0.9903, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7780, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   18 | loss:  tensor(0.0651, device='cuda:0') | Train_acc: tensor(0.9882, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7870, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   19 | loss:  tensor(0.1168, device='cuda:0') | Train_acc: tensor(0.9876, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7770, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   20 | loss:  tensor(0.0495, device='cuda:0') | Train_acc: tensor(0.9897, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7740, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   21 | loss:  tensor(0.0779, device='cuda:0') | Train_acc: tensor(0.9910, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7790, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   22 | loss:  tensor(0.2650, device='cuda:0') | Train_acc: tensor(0.9873, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7750, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   23 | loss:  tensor(0.4397, device='cuda:0') | Train_acc: tensor(0.9903, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7770, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   24 | loss:  tensor(0.1993, device='cuda:0') | Train_acc: tensor(0.9880, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7770, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   25 | loss:  tensor(0.2435, device='cuda:0') | Train_acc: tensor(0.9886, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7900, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   26 | loss:  tensor(0.1176, device='cuda:0') | Train_acc: tensor(0.9890, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7780, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   27 | loss:  tensor(0.3093, device='cuda:0') | Train_acc: tensor(0.9908, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7780, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   28 | loss:  tensor(0.6029, device='cuda:0') | Train_acc: tensor(0.9910, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7880, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   29 | loss:  tensor(0.4032, device='cuda:0') | Train_acc: tensor(0.9873, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7940, device='cuda:0', dtype=torch.float64)
# Best Eval acc: tensor(0.7940, device='cuda:0', dtype=torch.float64)

# %%
x=np.arange(len(losses))
plt.plot(x,losses)
plt.title('CNN8 continue 3')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN8 continue 3')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
torch.save(best_model_wts,'CNN8 continue 3 best.pkl')
torch.save(cnn8.state_dict(),'CNN8 continue 3.pkl')

# %%
optimizer.state_dict
# Out:
# <bound method Optimizer.state_dict of Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 1.25e-05
#     lr: 1.5625e-06
#     weight_decay: 0.01
# )>

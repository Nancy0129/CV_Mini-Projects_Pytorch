# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
warnings.filterwarnings("ignore")

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN5(nn.Module):
    def __init__(self):
        super(CNN5,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(
                in_channels=3,    #前面的层有多高
                out_channels=32,   #filter 的个数
                kernel_size=7,
                stride=1,
                padding=(3,3)  # if stride=1, padding=(kernel_size-1)/2
            ), 
            nn.ReLU(),   
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(32,64,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(64,128,7,1,3),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(128,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,128,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
        )


        self.dense1=nn.Sequential(
            nn.Linear(8*8*128,4096),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(4096,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(2048,1024),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(1024,101)
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn5=CNN5().cuda()
print(cnn5)
# Out:
# CNN5(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=8192, out_features=4096, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=4096, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense3): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=1024, out_features=101, bias=True)
# )

# %%
EPOCH = 30
BATCH_SIZE=64
LR=0.001
optimizer=torch.optim.Adam(cnn2.parameters(),lr=LR,weight_decay=0.01)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))
eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
    torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=True, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=True, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
for epoch in range(EPOCH):
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn5(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if step%10==0:
            with torch.no_grad():
                pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                train_accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                train_accs.append(train_accuracy)
                losses.append(loss.data)
                torch.cuda.empty_cache()
                eval_acc=[]
                for x,y in eval_loader:
                    b_x=Variable(x).cuda()
                    b_y=Variable(y).cuda()        
                    output=cnn5(b_x)         #change
                    pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                    accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                    eval_acc.append(accuracy)
                eval_accs.append(np.mean(eval_acc))
                print('Epoch: ',epoch,'| Step: ',step,'| loss: ',loss.data,
                      '| Train_acc: ', train_accuracy,'| Eval_acc: ', np.mean(eval_acc))
# Out:
# Epoch:  0 | Step:  0 | loss:  tensor(4.6280, device='cuda:0') | Train_acc:  0.015625 | Eval_acc:  0.064
# Epoch:  0 | Step:  10 | loss:  tensor(3.9719, device='cuda:0') | Train_acc:  0.203125 | Eval_acc:  0.181
# Epoch:  0 | Step:  20 | loss:  tensor(3.9736, device='cuda:0') | Train_acc:  0.1875 | Eval_acc:  0.24100000000000002
# Epoch:  0 | Step:  30 | loss:  tensor(3.8084, device='cuda:0') | Train_acc:  0.25 | Eval_acc:  0.255
# Epoch:  0 | Step:  40 | loss:  tensor(3.5608, device='cuda:0') | Train_acc:  0.25 | Eval_acc:  0.28500000000000003
# Epoch:  0 | Step:  50 | loss:  tensor(3.8953, device='cuda:0') | Train_acc:  0.21875 | Eval_acc:  0.306
# Epoch:  0 | Step:  60 | loss:  tensor(3.0435, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.31400000000000006
# Epoch:  0 | Step:  70 | loss:  tensor(3.3001, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.305
# Epoch:  0 | Step:  80 | loss:  tensor(3.4536, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.34400000000000003
# Epoch:  0 | Step:  90 | loss:  tensor(3.0232, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.357
# Epoch:  1 | Step:  0 | loss:  tensor(3.2579, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.316
# Epoch:  1 | Step:  10 | loss:  tensor(2.8843, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.354
# Epoch:  1 | Step:  20 | loss:  tensor(2.9353, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.36499999999999994
# Epoch:  1 | Step:  30 | loss:  tensor(3.1160, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.374
# Epoch:  1 | Step:  40 | loss:  tensor(2.9173, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.362
# Epoch:  1 | Step:  50 | loss:  tensor(3.5828, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.35700000000000004
# Epoch:  1 | Step:  60 | loss:  tensor(2.9876, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.333
# Epoch:  1 | Step:  70 | loss:  tensor(3.0360, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.34800000000000003
# Epoch:  1 | Step:  80 | loss:  tensor(3.3083, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.376
# Epoch:  1 | Step:  90 | loss:  tensor(3.0571, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.384
# Epoch:  2 | Step:  0 | loss:  tensor(2.9664, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.403
# Epoch:  2 | Step:  10 | loss:  tensor(2.2457, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.39
# Epoch:  2 | Step:  20 | loss:  tensor(2.9932, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.40099999999999997
# Epoch:  2 | Step:  30 | loss:  tensor(3.3665, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.41800000000000004
# Epoch:  2 | Step:  40 | loss:  tensor(2.4456, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.403
# Epoch:  2 | Step:  50 | loss:  tensor(2.4935, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.43200000000000005
# Epoch:  2 | Step:  60 | loss:  tensor(3.0560, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.396
# Epoch:  2 | Step:  70 | loss:  tensor(2.6035, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.433
# Epoch:  2 | Step:  80 | loss:  tensor(3.1426, device='cuda:0') | Train_acc:  0.265625 | Eval_acc:  0.4149999999999999
# Epoch:  2 | Step:  90 | loss:  tensor(2.8480, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.417
# Epoch:  3 | Step:  0 | loss:  tensor(2.8030, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.472
# Epoch:  3 | Step:  10 | loss:  tensor(2.8009, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.39099999999999996
# Epoch:  3 | Step:  20 | loss:  tensor(2.3607, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.40499999999999997
# Epoch:  3 | Step:  30 | loss:  tensor(2.6055, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.421
# Epoch:  3 | Step:  40 | loss:  tensor(2.9645, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.44299999999999995
# Epoch:  3 | Step:  50 | loss:  tensor(2.3373, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.398
# Epoch:  3 | Step:  60 | loss:  tensor(2.3553, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.479
# Epoch:  3 | Step:  70 | loss:  tensor(2.6212, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.45
# Epoch:  3 | Step:  80 | loss:  tensor(2.6112, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.403
# Epoch:  3 | Step:  90 | loss:  tensor(1.7602, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.45499999999999996
# Epoch:  4 | Step:  0 | loss:  tensor(2.3788, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.502
# Epoch:  4 | Step:  10 | loss:  tensor(2.5968, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.49700000000000005
# Epoch:  4 | Step:  20 | loss:  tensor(2.8239, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.488
# Epoch:  4 | Step:  30 | loss:  tensor(2.4605, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.429
# Epoch:  4 | Step:  40 | loss:  tensor(2.4187, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.437
# Epoch:  4 | Step:  50 | loss:  tensor(2.3548, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.46299999999999997
# Epoch:  4 | Step:  60 | loss:  tensor(2.5195, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.445
# Epoch:  4 | Step:  70 | loss:  tensor(3.1085, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.485
# Epoch:  4 | Step:  80 | loss:  tensor(2.2998, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.458
# Epoch:  4 | Step:  90 | loss:  tensor(2.5637, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.484
# Epoch:  5 | Step:  0 | loss:  tensor(2.5566, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.487
# Epoch:  5 | Step:  10 | loss:  tensor(2.4680, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.44799999999999995
# Epoch:  5 | Step:  20 | loss:  tensor(2.0945, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.504
# Epoch:  5 | Step:  30 | loss:  tensor(2.0929, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.5109999999999999
# Epoch:  5 | Step:  40 | loss:  tensor(1.8140, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.511
# Epoch:  5 | Step:  50 | loss:  tensor(1.7972, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.504
# Epoch:  5 | Step:  60 | loss:  tensor(1.6004, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.49000000000000005
# Epoch:  5 | Step:  70 | loss:  tensor(2.3263, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.48600000000000004
# Epoch:  5 | Step:  80 | loss:  tensor(2.5155, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.527
# Epoch:  5 | Step:  90 | loss:  tensor(1.4873, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.508
# Epoch:  6 | Step:  0 | loss:  tensor(2.0736, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.479
# Epoch:  6 | Step:  10 | loss:  tensor(2.2704, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.495
# Epoch:  6 | Step:  20 | loss:  tensor(1.9129, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.46699999999999997
# Epoch:  6 | Step:  30 | loss:  tensor(1.6104, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.492
# Epoch:  6 | Step:  40 | loss:  tensor(1.7200, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.528
# Epoch:  6 | Step:  50 | loss:  tensor(2.3242, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.533
# Epoch:  6 | Step:  60 | loss:  tensor(1.8173, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.5599999999999999
# Epoch:  6 | Step:  70 | loss:  tensor(1.7623, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.5429999999999999
# Epoch:  6 | Step:  80 | loss:  tensor(1.8535, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.507
# Epoch:  6 | Step:  90 | loss:  tensor(2.0370, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.5130000000000001
# Epoch:  7 | Step:  0 | loss:  tensor(1.7186, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.5229999999999999
# Epoch:  7 | Step:  10 | loss:  tensor(1.8272, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.5399999999999999
# Epoch:  7 | Step:  20 | loss:  tensor(1.6609, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.508
# Epoch:  7 | Step:  30 | loss:  tensor(1.8778, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.515
# Epoch:  7 | Step:  40 | loss:  tensor(1.6412, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.563
# Epoch:  7 | Step:  50 | loss:  tensor(2.1015, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.518
# Epoch:  7 | Step:  60 | loss:  tensor(1.5841, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.5050000000000001
# Epoch:  7 | Step:  70 | loss:  tensor(1.8747, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.53
# Epoch:  7 | Step:  80 | loss:  tensor(1.9144, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.5559999999999999
# Epoch:  7 | Step:  90 | loss:  tensor(1.8260, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.524
# Epoch:  8 | Step:  0 | loss:  tensor(1.1938, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.519
# Epoch:  8 | Step:  10 | loss:  tensor(1.3472, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.497
# Epoch:  8 | Step:  20 | loss:  tensor(1.4692, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.49799999999999994
# Epoch:  8 | Step:  30 | loss:  tensor(1.1146, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.5290000000000001
# Epoch:  8 | Step:  40 | loss:  tensor(1.4901, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5429999999999999
# Epoch:  8 | Step:  50 | loss:  tensor(1.9250, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.541
# Epoch:  8 | Step:  60 | loss:  tensor(0.9477, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.518
# Epoch:  8 | Step:  70 | loss:  tensor(1.2519, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.562
# Epoch:  8 | Step:  80 | loss:  tensor(1.9035, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.513
# Epoch:  8 | Step:  90 | loss:  tensor(1.4081, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.529
# Epoch:  9 | Step:  0 | loss:  tensor(1.4573, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.525
# Epoch:  9 | Step:  10 | loss:  tensor(1.2004, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.541
# Epoch:  9 | Step:  20 | loss:  tensor(0.7566, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.48
# Epoch:  9 | Step:  30 | loss:  tensor(1.4685, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.525
# Epoch:  9 | Step:  40 | loss:  tensor(1.4236, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.514
# Epoch:  9 | Step:  50 | loss:  tensor(1.5608, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.5370000000000001
# Epoch:  9 | Step:  60 | loss:  tensor(1.8579, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.51
# Epoch:  9 | Step:  70 | loss:  tensor(1.3452, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.537
# Epoch:  9 | Step:  80 | loss:  tensor(1.0097, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.518
# Epoch:  9 | Step:  90 | loss:  tensor(1.4989, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.545
# Epoch:  10 | Step:  0 | loss:  tensor(1.1850, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.549
# Epoch:  10 | Step:  10 | loss:  tensor(1.7022, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.534
# Epoch:  10 | Step:  20 | loss:  tensor(1.0887, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.576
# Epoch:  10 | Step:  30 | loss:  tensor(0.9163, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.533
# Epoch:  10 | Step:  40 | loss:  tensor(0.9118, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.579
# Epoch:  10 | Step:  50 | loss:  tensor(1.4794, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.584
# Epoch:  10 | Step:  60 | loss:  tensor(0.9848, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.591
# Epoch:  10 | Step:  70 | loss:  tensor(0.9907, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.524
# Epoch:  10 | Step:  80 | loss:  tensor(1.2059, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.5690000000000001
# Epoch:  10 | Step:  90 | loss:  tensor(1.6459, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5370000000000001
# Epoch:  11 | Step:  0 | loss:  tensor(0.7267, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.579
# Epoch:  11 | Step:  10 | loss:  tensor(1.1803, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.556
# Epoch:  11 | Step:  20 | loss:  tensor(0.6679, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.553
# Epoch:  11 | Step:  30 | loss:  tensor(0.7878, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5370000000000001
# Epoch:  11 | Step:  40 | loss:  tensor(1.1633, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.568
# Epoch:  11 | Step:  50 | loss:  tensor(1.0926, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.558
# Epoch:  11 | Step:  60 | loss:  tensor(0.8507, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5820000000000001
# Epoch:  11 | Step:  70 | loss:  tensor(0.8231, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.541
# Epoch:  11 | Step:  80 | loss:  tensor(0.8776, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.5349999999999999
# Epoch:  11 | Step:  90 | loss:  tensor(0.6635, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.554
# Epoch:  12 | Step:  0 | loss:  tensor(0.8531, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.5740000000000001
# Epoch:  12 | Step:  10 | loss:  tensor(1.0100, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.562
# Epoch:  12 | Step:  20 | loss:  tensor(0.8754, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.553
# Epoch:  12 | Step:  30 | loss:  tensor(0.4776, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5710000000000001
# Epoch:  12 | Step:  40 | loss:  tensor(0.7953, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.552
# Epoch:  12 | Step:  50 | loss:  tensor(0.8788, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.585
# Epoch:  12 | Step:  60 | loss:  tensor(1.4359, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.5389999999999999
# Epoch:  12 | Step:  70 | loss:  tensor(1.3259, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.522
# Epoch:  12 | Step:  80 | loss:  tensor(0.9255, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5900000000000001
# Epoch:  12 | Step:  90 | loss:  tensor(1.4814, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.558
# Epoch:  13 | Step:  0 | loss:  tensor(0.5361, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.528
# Epoch:  13 | Step:  10 | loss:  tensor(0.3707, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.558
# Epoch:  13 | Step:  20 | loss:  tensor(0.4823, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.567
# Epoch:  13 | Step:  30 | loss:  tensor(0.8981, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.531
# Epoch:  13 | Step:  40 | loss:  tensor(0.6430, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5549999999999999
# Epoch:  13 | Step:  50 | loss:  tensor(0.6567, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5959999999999999
# Epoch:  13 | Step:  60 | loss:  tensor(0.3607, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5529999999999999
# Epoch:  13 | Step:  70 | loss:  tensor(0.8302, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.538
# Epoch:  13 | Step:  80 | loss:  tensor(0.8237, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.548
# Epoch:  13 | Step:  90 | loss:  tensor(0.5416, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.58
# Epoch:  14 | Step:  0 | loss:  tensor(0.7177, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5609999999999999
# Epoch:  14 | Step:  10 | loss:  tensor(0.8215, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.572
# Epoch:  14 | Step:  20 | loss:  tensor(0.7880, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.518
# Epoch:  14 | Step:  30 | loss:  tensor(0.6443, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.55
# Epoch:  14 | Step:  40 | loss:  tensor(0.3886, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.522
# Epoch:  14 | Step:  50 | loss:  tensor(0.6229, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.568
# Epoch:  14 | Step:  60 | loss:  tensor(0.4601, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.56
# Epoch:  14 | Step:  70 | loss:  tensor(0.8446, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.5800000000000001
# Epoch:  14 | Step:  80 | loss:  tensor(0.4782, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.55
# Epoch:  14 | Step:  90 | loss:  tensor(1.2751, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.572
# Epoch:  15 | Step:  0 | loss:  tensor(0.5612, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.556
# Epoch:  15 | Step:  10 | loss:  tensor(0.5299, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.571
# Epoch:  15 | Step:  20 | loss:  tensor(0.5305, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.591
# Epoch:  15 | Step:  30 | loss:  tensor(0.3196, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5399999999999999
# Epoch:  15 | Step:  40 | loss:  tensor(0.7528, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.592
# Epoch:  15 | Step:  50 | loss:  tensor(0.5719, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5740000000000001
# Epoch:  15 | Step:  60 | loss:  tensor(0.7764, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.582
# Epoch:  15 | Step:  70 | loss:  tensor(0.6735, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5519999999999999
# Epoch:  15 | Step:  80 | loss:  tensor(0.5898, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.585
# Epoch:  15 | Step:  90 | loss:  tensor(0.3334, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5740000000000001
# Epoch:  16 | Step:  0 | loss:  tensor(0.4700, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5730000000000001
# Epoch:  16 | Step:  10 | loss:  tensor(0.7142, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.611
# Epoch:  16 | Step:  20 | loss:  tensor(0.6262, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.607
# Epoch:  16 | Step:  30 | loss:  tensor(0.6862, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5760000000000001
# Epoch:  16 | Step:  40 | loss:  tensor(0.3733, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5880000000000001
# Epoch:  16 | Step:  50 | loss:  tensor(0.6923, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.545
# Epoch:  16 | Step:  60 | loss:  tensor(0.6887, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5680000000000001
# Epoch:  16 | Step:  70 | loss:  tensor(0.5290, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.585
# Epoch:  16 | Step:  80 | loss:  tensor(0.8868, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.557
# Epoch:  16 | Step:  90 | loss:  tensor(0.6509, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5599999999999999
# Epoch:  17 | Step:  0 | loss:  tensor(0.6754, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.533
# Epoch:  17 | Step:  10 | loss:  tensor(0.5644, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.505
# Epoch:  17 | Step:  20 | loss:  tensor(0.3761, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.561
# Epoch:  17 | Step:  30 | loss:  tensor(0.5856, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5980000000000001
# Epoch:  17 | Step:  40 | loss:  tensor(0.5150, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.581
# Epoch:  17 | Step:  50 | loss:  tensor(0.6804, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.567
# Epoch:  17 | Step:  60 | loss:  tensor(0.6284, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.552
# Epoch:  17 | Step:  70 | loss:  tensor(0.4068, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.553
# Epoch:  17 | Step:  80 | loss:  tensor(0.4688, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.617
# Epoch:  17 | Step:  90 | loss:  tensor(0.2780, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5850000000000001
# Epoch:  18 | Step:  0 | loss:  tensor(0.3541, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5870000000000001
# Epoch:  18 | Step:  10 | loss:  tensor(0.4551, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.579
# Epoch:  18 | Step:  20 | loss:  tensor(0.7949, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.571
# Epoch:  18 | Step:  30 | loss:  tensor(0.1923, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.5700000000000001
# Epoch:  18 | Step:  40 | loss:  tensor(0.3895, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.585
# Epoch:  18 | Step:  50 | loss:  tensor(0.4293, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5760000000000001
# Epoch:  18 | Step:  60 | loss:  tensor(0.5985, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.608
# Epoch:  18 | Step:  70 | loss:  tensor(0.2277, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.611
# Epoch:  18 | Step:  80 | loss:  tensor(0.5536, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.536
# Epoch:  18 | Step:  90 | loss:  tensor(0.2380, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.542
# Epoch:  19 | Step:  0 | loss:  tensor(0.2682, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.542
# Epoch:  19 | Step:  10 | loss:  tensor(0.3147, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5549999999999999
# Epoch:  19 | Step:  20 | loss:  tensor(0.3837, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.53
# Epoch:  19 | Step:  30 | loss:  tensor(0.2284, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5750000000000001
# Epoch:  19 | Step:  40 | loss:  tensor(0.6009, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.541
# Epoch:  19 | Step:  50 | loss:  tensor(0.6587, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.584
# Epoch:  19 | Step:  60 | loss:  tensor(0.5339, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.553
# Epoch:  19 | Step:  70 | loss:  tensor(0.4702, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.578
# Epoch:  19 | Step:  80 | loss:  tensor(1.0113, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.6250000000000001
# Epoch:  19 | Step:  90 | loss:  tensor(0.2156, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5469999999999999
# Epoch:  20 | Step:  0 | loss:  tensor(0.2204, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.595
# Epoch:  20 | Step:  10 | loss:  tensor(0.5035, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.609
# Epoch:  20 | Step:  20 | loss:  tensor(0.3077, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.586
# Epoch:  20 | Step:  30 | loss:  tensor(0.2435, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.584
# Epoch:  20 | Step:  40 | loss:  tensor(0.7287, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.589
# Epoch:  20 | Step:  50 | loss:  tensor(0.4429, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.616
# Epoch:  20 | Step:  60 | loss:  tensor(0.6552, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5449999999999999
# Epoch:  20 | Step:  70 | loss:  tensor(0.4746, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.583
# Epoch:  20 | Step:  80 | loss:  tensor(0.1955, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.583
# Epoch:  20 | Step:  90 | loss:  tensor(0.8752, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.6050000000000001
# Epoch:  21 | Step:  0 | loss:  tensor(0.2329, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.548
# Epoch:  21 | Step:  10 | loss:  tensor(0.3688, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5919999999999999
# Epoch:  21 | Step:  20 | loss:  tensor(0.2938, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.568
# Epoch:  21 | Step:  30 | loss:  tensor(0.1454, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.553
# Epoch:  21 | Step:  40 | loss:  tensor(0.3813, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.548
# Epoch:  21 | Step:  50 | loss:  tensor(0.2969, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5589999999999999
# Epoch:  21 | Step:  60 | loss:  tensor(0.2564, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.633
# Epoch:  21 | Step:  70 | loss:  tensor(0.6833, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.573
# Epoch:  21 | Step:  80 | loss:  tensor(0.4894, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5589999999999999
# Epoch:  21 | Step:  90 | loss:  tensor(0.3755, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.593
# Epoch:  22 | Step:  0 | loss:  tensor(0.3662, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.5760000000000001
# Epoch:  22 | Step:  10 | loss:  tensor(0.1887, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.561
# Epoch:  22 | Step:  20 | loss:  tensor(0.5448, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.585
# Epoch:  22 | Step:  30 | loss:  tensor(0.2199, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.585
# Epoch:  22 | Step:  40 | loss:  tensor(0.3942, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5639999999999998
# Epoch:  22 | Step:  50 | loss:  tensor(0.0560, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.5680000000000001
# Epoch:  22 | Step:  60 | loss:  tensor(0.5611, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5810000000000001
# Epoch:  22 | Step:  70 | loss:  tensor(0.2034, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.57
# Epoch:  22 | Step:  80 | loss:  tensor(0.5912, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5589999999999999
# Epoch:  22 | Step:  90 | loss:  tensor(0.1659, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.535
# Epoch:  23 | Step:  0 | loss:  tensor(0.3964, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5449999999999999
# Epoch:  23 | Step:  10 | loss:  tensor(0.6599, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5469999999999999
# Epoch:  23 | Step:  20 | loss:  tensor(0.3085, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.549
# Epoch:  23 | Step:  30 | loss:  tensor(0.0177, device='cuda:0') | Train_acc:  1.0 | Eval_acc:  0.569
# Epoch:  23 | Step:  40 | loss:  tensor(0.2486, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5980000000000001
# Epoch:  23 | Step:  50 | loss:  tensor(0.1881, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.5599999999999999
# Epoch:  23 | Step:  60 | loss:  tensor(0.3680, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.577
# Epoch:  23 | Step:  70 | loss:  tensor(0.1845, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.594
# Epoch:  23 | Step:  80 | loss:  tensor(0.3869, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5630000000000001
# Epoch:  23 | Step:  90 | loss:  tensor(0.1155, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6
# Epoch:  24 | Step:  0 | loss:  tensor(0.3195, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.607
# Epoch:  24 | Step:  10 | loss:  tensor(0.1283, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.576
# Epoch:  24 | Step:  20 | loss:  tensor(0.1733, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.557
# Epoch:  24 | Step:  30 | loss:  tensor(0.7301, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5690000000000001
# Epoch:  24 | Step:  40 | loss:  tensor(0.6825, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5619999999999999
# Epoch:  24 | Step:  50 | loss:  tensor(0.3000, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5700000000000001
# Epoch:  24 | Step:  60 | loss:  tensor(0.6282, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5509999999999999
# Epoch:  24 | Step:  70 | loss:  tensor(0.5826, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.59
# Epoch:  24 | Step:  80 | loss:  tensor(0.6761, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5589999999999999
# Epoch:  24 | Step:  90 | loss:  tensor(0.3608, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.58
# Epoch:  25 | Step:  0 | loss:  tensor(0.3728, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.6130000000000001
# Epoch:  25 | Step:  10 | loss:  tensor(0.5152, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.538
# Epoch:  25 | Step:  20 | loss:  tensor(0.2285, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.592
# Epoch:  25 | Step:  30 | loss:  tensor(0.3949, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.589
# Epoch:  25 | Step:  40 | loss:  tensor(0.4112, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5720000000000001
# Epoch:  25 | Step:  50 | loss:  tensor(0.2452, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.627
# Epoch:  25 | Step:  60 | loss:  tensor(0.2583, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5660000000000001
# Epoch:  25 | Step:  70 | loss:  tensor(0.1914, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.576
# Epoch:  25 | Step:  80 | loss:  tensor(0.3989, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.567
# Epoch:  25 | Step:  90 | loss:  tensor(0.5080, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5720000000000001
# Epoch:  26 | Step:  0 | loss:  tensor(0.3889, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.595
# Epoch:  26 | Step:  10 | loss:  tensor(0.6247, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.603
# Epoch:  26 | Step:  20 | loss:  tensor(0.2182, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.587
# Epoch:  26 | Step:  30 | loss:  tensor(0.4523, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.583
# Epoch:  26 | Step:  40 | loss:  tensor(0.1917, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.581
# Epoch:  26 | Step:  50 | loss:  tensor(0.3233, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.549
# Epoch:  26 | Step:  60 | loss:  tensor(0.2043, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.567
# Epoch:  26 | Step:  70 | loss:  tensor(0.3536, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5730000000000001
# Epoch:  26 | Step:  80 | loss:  tensor(0.4538, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.609
# Epoch:  26 | Step:  90 | loss:  tensor(0.0438, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.601
# Epoch:  27 | Step:  0 | loss:  tensor(0.3839, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.587
# Epoch:  27 | Step:  10 | loss:  tensor(0.4834, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5599999999999999
# Epoch:  27 | Step:  20 | loss:  tensor(0.3364, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.593
# Epoch:  27 | Step:  30 | loss:  tensor(0.3521, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.544
# Epoch:  27 | Step:  40 | loss:  tensor(0.1930, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5980000000000001
# Epoch:  27 | Step:  50 | loss:  tensor(0.1591, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.546
# Epoch:  27 | Step:  60 | loss:  tensor(0.0628, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.5640000000000001
# Epoch:  27 | Step:  70 | loss:  tensor(0.2143, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.603
# Epoch:  27 | Step:  80 | loss:  tensor(0.2784, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.579
# Epoch:  27 | Step:  90 | loss:  tensor(0.4087, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.564
# Epoch:  28 | Step:  0 | loss:  tensor(0.2859, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.591
# Epoch:  28 | Step:  10 | loss:  tensor(0.7597, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.5449999999999999
# Epoch:  28 | Step:  20 | loss:  tensor(0.1197, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.5449999999999999
# Epoch:  28 | Step:  30 | loss:  tensor(0.1538, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.582
# Epoch:  28 | Step:  40 | loss:  tensor(0.2382, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.585
# Epoch:  28 | Step:  50 | loss:  tensor(0.3307, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.592
# Epoch:  28 | Step:  60 | loss:  tensor(0.2666, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5900000000000001
# Epoch:  28 | Step:  70 | loss:  tensor(0.4028, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5599999999999999
# Epoch:  28 | Step:  80 | loss:  tensor(0.0919, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.584
# Epoch:  28 | Step:  90 | loss:  tensor(0.2032, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.568
# Epoch:  29 | Step:  0 | loss:  tensor(0.2996, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.552
# Epoch:  29 | Step:  10 | loss:  tensor(0.2024, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.528
# Epoch:  29 | Step:  20 | loss:  tensor(0.1190, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.575
# Epoch:  29 | Step:  30 | loss:  tensor(0.1027, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.623
# Epoch:  29 | Step:  40 | loss:  tensor(0.3752, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.6140000000000001
# Epoch:  29 | Step:  50 | loss:  tensor(0.6158, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.592
# Epoch:  29 | Step:  60 | loss:  tensor(0.2722, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.576
# Epoch:  29 | Step:  70 | loss:  tensor(0.1165, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.578
# Epoch:  29 | Step:  80 | loss:  tensor(0.2371, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.573
# Epoch:  29 | Step:  90 | loss:  tensor(0.1283, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.553

# %%
x=np.arange(len(losses))*10
plt.plot(x,losses)
plt.title('CNN5 TRY 1')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN5 TRY 1')
plt.xlabel('Step')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

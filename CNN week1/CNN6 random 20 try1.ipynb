# %% [markdown]
# ###   参考 VGG 结构

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
warnings.filterwarnings("ignore")

# %%
torch.cuda.empty_cache()

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN6(nn.Module):
    def __init__(self):
        super(CNN6,self).__init__()
        
        self.conv1=nn.Sequential(
           nn.Conv2d(3,32,3,1,1),
            nn.ReLU(),   
            nn.Conv2d(32,32,3,1,1),
            nn.ReLU(),   
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(32,64,3,1,1),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(64,128,3,1,1),
            nn.ReLU(),
            nn.Conv2d(128,128,3,1,1),
            nn.ReLU(),
            nn.Conv2d(128,128,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(128,256,3,1,1),
            nn.ReLU(),
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.Conv2d(256,256,3,1,1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2)
        )
        


        self.dense1=nn.Sequential(
            nn.Linear(8*8*256,2048),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(2048,1024),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(1024,512),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(512,101)
        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn6=CNN6().cuda()
print(cnn6)
# Out:
# CNN6(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=16384, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense3): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=512, out_features=101, bias=True)
# )

# %%
EPOCH = 30
BATCH_SIZE=64
LR=0.001
optimizer=torch.optim.Adam(cnn6.parameters(),lr=LR,weight_decay=0.001)
torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, 
    verbose=False, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))
eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
    torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor()]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=True, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=True, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
for epoch in range(EPOCH):
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn6(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if step%10==0:
            with torch.no_grad():
                pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                train_accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                train_accs.append(train_accuracy)
                losses.append(loss.data)
                torch.cuda.empty_cache()
                eval_acc=[]
                for x,y in eval_loader:
                    b_x=Variable(x).cuda()
                    b_y=Variable(y).cuda()        
                    output=cnn6(b_x)         #change
                    pred_y=torch.max(output,1)[1].cuda().data.squeeze()
                    accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
                    eval_acc.append(accuracy)
                eval_accs.append(np.mean(eval_acc))
                print('Epoch: ',epoch,'| Step: ',step,'| loss: ',loss.data,
                      '| Train_acc: ', train_accuracy,'| Eval_acc: ', np.mean(eval_acc))
# Out:
# Epoch:  0 | Step:  0 | loss:  tensor(4.6431, device='cuda:0') | Train_acc:  0.0 | Eval_acc:  0.031999999999999994
# Epoch:  0 | Step:  10 | loss:  tensor(4.4898, device='cuda:0') | Train_acc:  0.078125 | Eval_acc:  0.10700000000000001
# Epoch:  0 | Step:  20 | loss:  tensor(4.4390, device='cuda:0') | Train_acc:  0.15625 | Eval_acc:  0.175
# Epoch:  0 | Step:  30 | loss:  tensor(4.1010, device='cuda:0') | Train_acc:  0.125 | Eval_acc:  0.20700000000000002
# Epoch:  0 | Step:  40 | loss:  tensor(3.8268, device='cuda:0') | Train_acc:  0.203125 | Eval_acc:  0.229
# Epoch:  0 | Step:  50 | loss:  tensor(3.9681, device='cuda:0') | Train_acc:  0.140625 | Eval_acc:  0.246
# Epoch:  0 | Step:  60 | loss:  tensor(3.5256, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.233
# Epoch:  0 | Step:  70 | loss:  tensor(3.6197, device='cuda:0') | Train_acc:  0.21875 | Eval_acc:  0.27799999999999997
# Epoch:  0 | Step:  80 | loss:  tensor(3.8278, device='cuda:0') | Train_acc:  0.1875 | Eval_acc:  0.31499999999999995
# Epoch:  0 | Step:  90 | loss:  tensor(3.3944, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.29500000000000004
# Epoch:  1 | Step:  0 | loss:  tensor(3.5049, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.27299999999999996
# Epoch:  1 | Step:  10 | loss:  tensor(2.8696, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.305
# Epoch:  1 | Step:  20 | loss:  tensor(3.2006, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.34199999999999997
# Epoch:  1 | Step:  30 | loss:  tensor(3.2505, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.32199999999999995
# Epoch:  1 | Step:  40 | loss:  tensor(3.0652, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.33199999999999996
# Epoch:  1 | Step:  50 | loss:  tensor(3.4694, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.37
# Epoch:  1 | Step:  60 | loss:  tensor(3.4937, device='cuda:0') | Train_acc:  0.21875 | Eval_acc:  0.341
# Epoch:  1 | Step:  70 | loss:  tensor(3.7131, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.345
# Epoch:  1 | Step:  80 | loss:  tensor(3.1289, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.376
# Epoch:  1 | Step:  90 | loss:  tensor(2.9761, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.362
# Epoch:  2 | Step:  0 | loss:  tensor(3.2814, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.361
# Epoch:  2 | Step:  10 | loss:  tensor(3.1442, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.395
# Epoch:  2 | Step:  20 | loss:  tensor(2.7705, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.403
# Epoch:  2 | Step:  30 | loss:  tensor(3.0091, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.371
# Epoch:  2 | Step:  40 | loss:  tensor(3.2190, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.42299999999999993
# Epoch:  2 | Step:  50 | loss:  tensor(2.9995, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.392
# Epoch:  2 | Step:  60 | loss:  tensor(2.8725, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.40099999999999997
# Epoch:  2 | Step:  70 | loss:  tensor(3.2221, device='cuda:0') | Train_acc:  0.25 | Eval_acc:  0.421
# Epoch:  2 | Step:  80 | loss:  tensor(2.8508, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.369
# Epoch:  2 | Step:  90 | loss:  tensor(2.8151, device='cuda:0') | Train_acc:  0.375 | Eval_acc:  0.469
# Epoch:  3 | Step:  0 | loss:  tensor(2.2663, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.41800000000000004
# Epoch:  3 | Step:  10 | loss:  tensor(3.5392, device='cuda:0') | Train_acc:  0.203125 | Eval_acc:  0.399
# Epoch:  3 | Step:  20 | loss:  tensor(3.1053, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.425
# Epoch:  3 | Step:  30 | loss:  tensor(2.7764, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.445
# Epoch:  3 | Step:  40 | loss:  tensor(2.5758, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.40599999999999997
# Epoch:  3 | Step:  50 | loss:  tensor(2.3081, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.403
# Epoch:  3 | Step:  60 | loss:  tensor(2.6662, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.392
# Epoch:  3 | Step:  70 | loss:  tensor(3.1530, device='cuda:0') | Train_acc:  0.28125 | Eval_acc:  0.41500000000000004
# Epoch:  3 | Step:  80 | loss:  tensor(2.5208, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.438
# Epoch:  3 | Step:  90 | loss:  tensor(2.7643, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.4109999999999999
# Epoch:  4 | Step:  0 | loss:  tensor(2.8218, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.41500000000000004
# Epoch:  4 | Step:  10 | loss:  tensor(2.6565, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.433
# Epoch:  4 | Step:  20 | loss:  tensor(2.6794, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.45
# Epoch:  4 | Step:  30 | loss:  tensor(2.8611, device='cuda:0') | Train_acc:  0.359375 | Eval_acc:  0.43899999999999995
# Epoch:  4 | Step:  40 | loss:  tensor(2.4457, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.44300000000000006
# Epoch:  4 | Step:  50 | loss:  tensor(2.0216, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.40199999999999997
# Epoch:  4 | Step:  60 | loss:  tensor(2.9593, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.429
# Epoch:  4 | Step:  70 | loss:  tensor(2.7384, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.421
# Epoch:  4 | Step:  80 | loss:  tensor(2.7659, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.422
# Epoch:  4 | Step:  90 | loss:  tensor(1.8115, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.45500000000000007
# Epoch:  5 | Step:  0 | loss:  tensor(2.2478, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.45500000000000007
# Epoch:  5 | Step:  10 | loss:  tensor(2.7654, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.44299999999999995
# Epoch:  5 | Step:  20 | loss:  tensor(2.6130, device='cuda:0') | Train_acc:  0.4375 | Eval_acc:  0.47300000000000003
# Epoch:  5 | Step:  30 | loss:  tensor(2.4899, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.44800000000000006
# Epoch:  5 | Step:  40 | loss:  tensor(2.6664, device='cuda:0') | Train_acc:  0.328125 | Eval_acc:  0.457
# Epoch:  5 | Step:  50 | loss:  tensor(3.1050, device='cuda:0') | Train_acc:  0.3125 | Eval_acc:  0.477
# Epoch:  5 | Step:  60 | loss:  tensor(3.0094, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.44299999999999995
# Epoch:  5 | Step:  70 | loss:  tensor(1.8976, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.465
# Epoch:  5 | Step:  80 | loss:  tensor(2.1455, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.4640000000000001
# Epoch:  5 | Step:  90 | loss:  tensor(2.4965, device='cuda:0') | Train_acc:  0.40625 | Eval_acc:  0.44400000000000006
# Epoch:  6 | Step:  0 | loss:  tensor(2.7196, device='cuda:0') | Train_acc:  0.34375 | Eval_acc:  0.4800000000000001
# Epoch:  6 | Step:  10 | loss:  tensor(3.3491, device='cuda:0') | Train_acc:  0.296875 | Eval_acc:  0.479
# Epoch:  6 | Step:  20 | loss:  tensor(2.5850, device='cuda:0') | Train_acc:  0.390625 | Eval_acc:  0.426
# Epoch:  6 | Step:  30 | loss:  tensor(1.7548, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.476
# Epoch:  6 | Step:  40 | loss:  tensor(2.1427, device='cuda:0') | Train_acc:  0.421875 | Eval_acc:  0.446
# Epoch:  6 | Step:  50 | loss:  tensor(2.1719, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.489
# Epoch:  6 | Step:  60 | loss:  tensor(2.2189, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.433
# Epoch:  6 | Step:  70 | loss:  tensor(2.1229, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.46699999999999997
# Epoch:  6 | Step:  80 | loss:  tensor(2.3734, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.442
# Epoch:  6 | Step:  90 | loss:  tensor(2.3823, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.5
# Epoch:  7 | Step:  0 | loss:  tensor(2.2388, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.483
# Epoch:  7 | Step:  10 | loss:  tensor(2.4359, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.475
# Epoch:  7 | Step:  20 | loss:  tensor(2.1918, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.4800000000000001
# Epoch:  7 | Step:  30 | loss:  tensor(2.3300, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.47400000000000003
# Epoch:  7 | Step:  40 | loss:  tensor(1.8162, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.48600000000000004
# Epoch:  7 | Step:  50 | loss:  tensor(2.2983, device='cuda:0') | Train_acc:  0.453125 | Eval_acc:  0.5349999999999999
# Epoch:  7 | Step:  60 | loss:  tensor(1.9578, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.5069999999999999
# Epoch:  7 | Step:  70 | loss:  tensor(1.9343, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.496
# Epoch:  7 | Step:  80 | loss:  tensor(2.4294, device='cuda:0') | Train_acc:  0.46875 | Eval_acc:  0.47700000000000004
# Epoch:  7 | Step:  90 | loss:  tensor(1.7151, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.489
# Epoch:  8 | Step:  0 | loss:  tensor(1.7541, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.48500000000000004
# Epoch:  8 | Step:  10 | loss:  tensor(2.2046, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.48599999999999993
# Epoch:  8 | Step:  20 | loss:  tensor(1.7758, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.5
# Epoch:  8 | Step:  30 | loss:  tensor(1.9008, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.516
# Epoch:  8 | Step:  40 | loss:  tensor(2.2913, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.457
# Epoch:  8 | Step:  50 | loss:  tensor(1.8090, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.48500000000000004
# Epoch:  8 | Step:  60 | loss:  tensor(1.9150, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.507
# Epoch:  8 | Step:  70 | loss:  tensor(1.6931, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.495
# Epoch:  8 | Step:  80 | loss:  tensor(1.5796, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.527
# Epoch:  8 | Step:  90 | loss:  tensor(2.1525, device='cuda:0') | Train_acc:  0.484375 | Eval_acc:  0.4750000000000001
# Epoch:  9 | Step:  0 | loss:  tensor(1.8884, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.4920000000000001
# Epoch:  9 | Step:  10 | loss:  tensor(1.6010, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.466
# Epoch:  9 | Step:  20 | loss:  tensor(2.1180, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.5119999999999999
# Epoch:  9 | Step:  30 | loss:  tensor(1.6010, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.504
# Epoch:  9 | Step:  40 | loss:  tensor(2.3097, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.5050000000000001
# Epoch:  9 | Step:  50 | loss:  tensor(1.8015, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.541
# Epoch:  9 | Step:  60 | loss:  tensor(2.0611, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.4760000000000001
# Epoch:  9 | Step:  70 | loss:  tensor(1.7364, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.52
# Epoch:  9 | Step:  80 | loss:  tensor(2.0570, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.527
# Epoch:  9 | Step:  90 | loss:  tensor(1.6058, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.538
# Epoch:  10 | Step:  0 | loss:  tensor(1.8069, device='cuda:0') | Train_acc:  0.515625 | Eval_acc:  0.516
# Epoch:  10 | Step:  10 | loss:  tensor(1.1563, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.499
# Epoch:  10 | Step:  20 | loss:  tensor(1.5743, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5549999999999999
# Epoch:  10 | Step:  30 | loss:  tensor(1.8503, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.5130000000000001
# Epoch:  10 | Step:  40 | loss:  tensor(1.4533, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.5199999999999999
# Epoch:  10 | Step:  50 | loss:  tensor(2.1281, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.488
# Epoch:  10 | Step:  60 | loss:  tensor(1.9360, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.5010000000000001
# Epoch:  10 | Step:  70 | loss:  tensor(1.4173, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.48
# Epoch:  10 | Step:  80 | loss:  tensor(1.8037, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.518
# Epoch:  10 | Step:  90 | loss:  tensor(1.2679, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.541
# Epoch:  11 | Step:  0 | loss:  tensor(1.1184, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.504
# Epoch:  11 | Step:  10 | loss:  tensor(1.0395, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.5449999999999999
# Epoch:  11 | Step:  20 | loss:  tensor(1.6174, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.529
# Epoch:  11 | Step:  30 | loss:  tensor(1.7827, device='cuda:0') | Train_acc:  0.5 | Eval_acc:  0.48599999999999993
# Epoch:  11 | Step:  40 | loss:  tensor(1.7254, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.5
# Epoch:  11 | Step:  50 | loss:  tensor(1.4127, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.509
# Epoch:  11 | Step:  60 | loss:  tensor(1.5383, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.528
# Epoch:  11 | Step:  70 | loss:  tensor(1.5775, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5309999999999999
# Epoch:  11 | Step:  80 | loss:  tensor(1.7612, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.511
# Epoch:  11 | Step:  90 | loss:  tensor(1.3584, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.55
# Epoch:  12 | Step:  0 | loss:  tensor(1.6556, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.4840000000000001
# Epoch:  12 | Step:  10 | loss:  tensor(1.4677, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.5010000000000001
# Epoch:  12 | Step:  20 | loss:  tensor(1.6667, device='cuda:0') | Train_acc:  0.546875 | Eval_acc:  0.5279999999999999
# Epoch:  12 | Step:  30 | loss:  tensor(1.2283, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.523
# Epoch:  12 | Step:  40 | loss:  tensor(1.3418, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.547
# Epoch:  12 | Step:  50 | loss:  tensor(1.5064, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5429999999999999
# Epoch:  12 | Step:  60 | loss:  tensor(1.5478, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.562
# Epoch:  12 | Step:  70 | loss:  tensor(1.6525, device='cuda:0') | Train_acc:  0.5625 | Eval_acc:  0.49800000000000005
# Epoch:  12 | Step:  80 | loss:  tensor(1.5595, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.532
# Epoch:  12 | Step:  90 | loss:  tensor(1.3403, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.6040000000000001
# Epoch:  13 | Step:  0 | loss:  tensor(1.1592, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.572
# Epoch:  13 | Step:  10 | loss:  tensor(1.4709, device='cuda:0') | Train_acc:  0.578125 | Eval_acc:  0.5429999999999999
# Epoch:  13 | Step:  20 | loss:  tensor(1.2408, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.503
# Epoch:  13 | Step:  30 | loss:  tensor(1.4019, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.549
# Epoch:  13 | Step:  40 | loss:  tensor(1.3483, device='cuda:0') | Train_acc:  0.59375 | Eval_acc:  0.531
# Epoch:  13 | Step:  50 | loss:  tensor(1.2127, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.575
# Epoch:  13 | Step:  60 | loss:  tensor(1.3752, device='cuda:0') | Train_acc:  0.609375 | Eval_acc:  0.522
# Epoch:  13 | Step:  70 | loss:  tensor(1.2778, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.56
# Epoch:  13 | Step:  80 | loss:  tensor(1.4013, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.513
# Epoch:  13 | Step:  90 | loss:  tensor(0.8464, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.49399999999999994
# Epoch:  14 | Step:  0 | loss:  tensor(1.0650, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.575
# Epoch:  14 | Step:  10 | loss:  tensor(0.8481, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5760000000000001
# Epoch:  14 | Step:  20 | loss:  tensor(0.9269, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.571
# Epoch:  14 | Step:  30 | loss:  tensor(1.1258, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.517
# Epoch:  14 | Step:  40 | loss:  tensor(1.2365, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.552
# Epoch:  14 | Step:  50 | loss:  tensor(1.0680, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.5369999999999999
# Epoch:  14 | Step:  60 | loss:  tensor(1.1224, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.541
# Epoch:  14 | Step:  70 | loss:  tensor(1.3207, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.555
# Epoch:  14 | Step:  80 | loss:  tensor(1.4899, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.564
# Epoch:  14 | Step:  90 | loss:  tensor(1.8179, device='cuda:0') | Train_acc:  0.53125 | Eval_acc:  0.5429999999999999
# Epoch:  15 | Step:  0 | loss:  tensor(1.3102, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.5069999999999999
# Epoch:  15 | Step:  10 | loss:  tensor(0.8228, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.572
# Epoch:  15 | Step:  20 | loss:  tensor(1.0937, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.5519999999999999
# Epoch:  15 | Step:  30 | loss:  tensor(0.9317, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.556
# Epoch:  15 | Step:  40 | loss:  tensor(1.3024, device='cuda:0') | Train_acc:  0.65625 | Eval_acc:  0.543
# Epoch:  15 | Step:  50 | loss:  tensor(1.0607, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.5349999999999999
# Epoch:  15 | Step:  60 | loss:  tensor(1.0562, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.5459999999999999
# Epoch:  15 | Step:  70 | loss:  tensor(1.1769, device='cuda:0') | Train_acc:  0.625 | Eval_acc:  0.5040000000000001
# Epoch:  15 | Step:  80 | loss:  tensor(1.2624, device='cuda:0') | Train_acc:  0.640625 | Eval_acc:  0.5519999999999999
# Epoch:  15 | Step:  90 | loss:  tensor(1.1579, device='cuda:0') | Train_acc:  0.703125 | Eval_acc:  0.51
# Epoch:  16 | Step:  0 | loss:  tensor(0.9047, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.5589999999999999
# Epoch:  16 | Step:  10 | loss:  tensor(0.4926, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.558
# Epoch:  16 | Step:  20 | loss:  tensor(0.6826, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.547
# Epoch:  16 | Step:  30 | loss:  tensor(0.4856, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.546
# Epoch:  16 | Step:  40 | loss:  tensor(0.9195, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.5239999999999999
# Epoch:  16 | Step:  50 | loss:  tensor(0.6552, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.563
# Epoch:  16 | Step:  60 | loss:  tensor(0.7840, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.571
# Epoch:  16 | Step:  70 | loss:  tensor(1.2830, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.499
# Epoch:  16 | Step:  80 | loss:  tensor(1.2383, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5630000000000001
# Epoch:  16 | Step:  90 | loss:  tensor(0.9810, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.567
# Epoch:  17 | Step:  0 | loss:  tensor(0.5923, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.557
# Epoch:  17 | Step:  10 | loss:  tensor(0.8388, device='cuda:0') | Train_acc:  0.71875 | Eval_acc:  0.56
# Epoch:  17 | Step:  20 | loss:  tensor(0.4780, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5660000000000001
# Epoch:  17 | Step:  30 | loss:  tensor(0.9801, device='cuda:0') | Train_acc:  0.6875 | Eval_acc:  0.545
# Epoch:  17 | Step:  40 | loss:  tensor(0.9491, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5780000000000001
# Epoch:  17 | Step:  50 | loss:  tensor(1.0477, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5609999999999999
# Epoch:  17 | Step:  60 | loss:  tensor(1.1528, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5429999999999999
# Epoch:  17 | Step:  70 | loss:  tensor(0.7637, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.5439999999999999
# Epoch:  17 | Step:  80 | loss:  tensor(0.7501, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.594
# Epoch:  17 | Step:  90 | loss:  tensor(1.0210, device='cuda:0') | Train_acc:  0.734375 | Eval_acc:  0.5660000000000001
# Epoch:  18 | Step:  0 | loss:  tensor(0.5261, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5449999999999999
# Epoch:  18 | Step:  10 | loss:  tensor(0.5407, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.538
# Epoch:  18 | Step:  20 | loss:  tensor(0.8475, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.542
# Epoch:  18 | Step:  30 | loss:  tensor(0.5840, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5309999999999999
# Epoch:  18 | Step:  40 | loss:  tensor(0.6912, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.558
# Epoch:  18 | Step:  50 | loss:  tensor(0.6356, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5770000000000001
# Epoch:  18 | Step:  60 | loss:  tensor(0.9902, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.558
# Epoch:  18 | Step:  70 | loss:  tensor(0.9235, device='cuda:0') | Train_acc:  0.671875 | Eval_acc:  0.543
# Epoch:  18 | Step:  80 | loss:  tensor(0.6846, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5740000000000001
# Epoch:  18 | Step:  90 | loss:  tensor(0.7803, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.5670000000000001
# Epoch:  19 | Step:  0 | loss:  tensor(0.5459, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5389999999999999
# Epoch:  19 | Step:  10 | loss:  tensor(0.7778, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.571
# Epoch:  19 | Step:  20 | loss:  tensor(0.3918, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5519999999999999
# Epoch:  19 | Step:  30 | loss:  tensor(0.4831, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.536
# Epoch:  19 | Step:  40 | loss:  tensor(0.6179, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5429999999999999
# Epoch:  19 | Step:  50 | loss:  tensor(0.8008, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.5509999999999999
# Epoch:  19 | Step:  60 | loss:  tensor(0.4094, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.538
# Epoch:  19 | Step:  70 | loss:  tensor(0.9440, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5650000000000001
# Epoch:  19 | Step:  80 | loss:  tensor(1.1575, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.503
# Epoch:  19 | Step:  90 | loss:  tensor(0.8380, device='cuda:0') | Train_acc:  0.75 | Eval_acc:  0.556
# Epoch:  20 | Step:  0 | loss:  tensor(0.6451, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.58
# Epoch:  20 | Step:  10 | loss:  tensor(0.4876, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.562
# Epoch:  20 | Step:  20 | loss:  tensor(0.5964, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.534
# Epoch:  20 | Step:  30 | loss:  tensor(0.5349, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.543
# Epoch:  20 | Step:  40 | loss:  tensor(0.6534, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.575
# Epoch:  20 | Step:  50 | loss:  tensor(0.4379, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5650000000000001
# Epoch:  20 | Step:  60 | loss:  tensor(0.6402, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.604
# Epoch:  20 | Step:  70 | loss:  tensor(0.8767, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5429999999999999
# Epoch:  20 | Step:  80 | loss:  tensor(0.6785, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.558
# Epoch:  20 | Step:  90 | loss:  tensor(0.6082, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5660000000000001
# Epoch:  21 | Step:  0 | loss:  tensor(0.5057, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.574
# Epoch:  21 | Step:  10 | loss:  tensor(0.5409, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5680000000000001
# Epoch:  21 | Step:  20 | loss:  tensor(0.3745, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.549
# Epoch:  21 | Step:  30 | loss:  tensor(0.3180, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.509
# Epoch:  21 | Step:  40 | loss:  tensor(0.3861, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5509999999999999
# Epoch:  21 | Step:  50 | loss:  tensor(0.5625, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.525
# Epoch:  21 | Step:  60 | loss:  tensor(0.7625, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5800000000000001
# Epoch:  21 | Step:  70 | loss:  tensor(0.6717, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.597
# Epoch:  21 | Step:  80 | loss:  tensor(0.5397, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.576
# Epoch:  21 | Step:  90 | loss:  tensor(0.8396, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.563
# Epoch:  22 | Step:  0 | loss:  tensor(0.5077, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.534
# Epoch:  22 | Step:  10 | loss:  tensor(0.4178, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5529999999999999
# Epoch:  22 | Step:  20 | loss:  tensor(0.3667, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.536
# Epoch:  22 | Step:  30 | loss:  tensor(0.4481, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.5599999999999999
# Epoch:  22 | Step:  40 | loss:  tensor(0.4687, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.5359999999999999
# Epoch:  22 | Step:  50 | loss:  tensor(0.4684, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.566
# Epoch:  22 | Step:  60 | loss:  tensor(0.5457, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.53
# Epoch:  22 | Step:  70 | loss:  tensor(0.4393, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.565
# Epoch:  22 | Step:  80 | loss:  tensor(0.4328, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5010000000000001
# Epoch:  22 | Step:  90 | loss:  tensor(0.7269, device='cuda:0') | Train_acc:  0.765625 | Eval_acc:  0.5389999999999999
# Epoch:  23 | Step:  0 | loss:  tensor(0.7067, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.564
# Epoch:  23 | Step:  10 | loss:  tensor(0.6851, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.588
# Epoch:  23 | Step:  20 | loss:  tensor(0.3133, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5900000000000001
# Epoch:  23 | Step:  30 | loss:  tensor(0.6639, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.585
# Epoch:  23 | Step:  40 | loss:  tensor(0.6513, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.518
# Epoch:  23 | Step:  50 | loss:  tensor(0.7999, device='cuda:0') | Train_acc:  0.78125 | Eval_acc:  0.558
# Epoch:  23 | Step:  60 | loss:  tensor(0.3924, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5730000000000001
# Epoch:  23 | Step:  70 | loss:  tensor(0.4465, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.579
# Epoch:  23 | Step:  80 | loss:  tensor(0.7338, device='cuda:0') | Train_acc:  0.796875 | Eval_acc:  0.5650000000000001
# Epoch:  23 | Step:  90 | loss:  tensor(0.4220, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.506
# Epoch:  24 | Step:  0 | loss:  tensor(0.5695, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5759999999999998
# Epoch:  24 | Step:  10 | loss:  tensor(0.4915, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5589999999999999
# Epoch:  24 | Step:  20 | loss:  tensor(0.3844, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.547
# Epoch:  24 | Step:  30 | loss:  tensor(0.3383, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.579
# Epoch:  24 | Step:  40 | loss:  tensor(0.2347, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.566
# Epoch:  24 | Step:  50 | loss:  tensor(0.4856, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.532
# Epoch:  24 | Step:  60 | loss:  tensor(0.6961, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.5810000000000001
# Epoch:  24 | Step:  70 | loss:  tensor(0.6144, device='cuda:0') | Train_acc:  0.828125 | Eval_acc:  0.5360000000000001
# Epoch:  24 | Step:  80 | loss:  tensor(0.6785, device='cuda:0') | Train_acc:  0.8125 | Eval_acc:  0.505
# Epoch:  24 | Step:  90 | loss:  tensor(0.1677, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.5619999999999999
# Epoch:  25 | Step:  0 | loss:  tensor(0.1566, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.567
# Epoch:  25 | Step:  10 | loss:  tensor(0.2397, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.517
# Epoch:  25 | Step:  20 | loss:  tensor(0.4418, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5309999999999999
# Epoch:  25 | Step:  30 | loss:  tensor(0.2944, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.516
# Epoch:  25 | Step:  40 | loss:  tensor(0.4613, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.545
# Epoch:  25 | Step:  50 | loss:  tensor(0.2229, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.586
# Epoch:  25 | Step:  60 | loss:  tensor(0.3660, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.533
# Epoch:  25 | Step:  70 | loss:  tensor(0.3516, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.553
# Epoch:  25 | Step:  80 | loss:  tensor(0.6898, device='cuda:0') | Train_acc:  0.859375 | Eval_acc:  0.5439999999999999
# Epoch:  25 | Step:  90 | loss:  tensor(0.4003, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.591
# Epoch:  26 | Step:  0 | loss:  tensor(0.4376, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.54
# Epoch:  26 | Step:  10 | loss:  tensor(0.3699, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.541
# Epoch:  26 | Step:  20 | loss:  tensor(0.3058, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.58
# Epoch:  26 | Step:  30 | loss:  tensor(0.2316, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.541
# Epoch:  26 | Step:  40 | loss:  tensor(0.3392, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.519
# Epoch:  26 | Step:  50 | loss:  tensor(0.2397, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5410000000000001
# Epoch:  26 | Step:  60 | loss:  tensor(0.6028, device='cuda:0') | Train_acc:  0.875 | Eval_acc:  0.533
# Epoch:  26 | Step:  70 | loss:  tensor(0.2125, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5239999999999999
# Epoch:  26 | Step:  80 | loss:  tensor(0.2753, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.576
# Epoch:  26 | Step:  90 | loss:  tensor(0.4926, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5609999999999999
# Epoch:  27 | Step:  0 | loss:  tensor(0.2575, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5800000000000001
# Epoch:  27 | Step:  10 | loss:  tensor(0.2934, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.595
# Epoch:  27 | Step:  20 | loss:  tensor(0.3501, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.581
# Epoch:  27 | Step:  30 | loss:  tensor(0.2611, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.571
# Epoch:  27 | Step:  40 | loss:  tensor(0.2849, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5519999999999999
# Epoch:  27 | Step:  50 | loss:  tensor(0.2524, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.567
# Epoch:  27 | Step:  60 | loss:  tensor(0.2536, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5650000000000001
# Epoch:  27 | Step:  70 | loss:  tensor(0.3151, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.554
# Epoch:  27 | Step:  80 | loss:  tensor(0.4395, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.522
# Epoch:  27 | Step:  90 | loss:  tensor(0.3401, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.5519999999999999
# Epoch:  28 | Step:  0 | loss:  tensor(0.1547, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.549
# Epoch:  28 | Step:  10 | loss:  tensor(0.2399, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.5650000000000001
# Epoch:  28 | Step:  20 | loss:  tensor(0.0526, device='cuda:0') | Train_acc:  0.984375 | Eval_acc:  0.5439999999999999
# Epoch:  28 | Step:  30 | loss:  tensor(0.1828, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.5700000000000001
# Epoch:  28 | Step:  40 | loss:  tensor(0.5791, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.573
# Epoch:  28 | Step:  50 | loss:  tensor(0.4399, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.518
# Epoch:  28 | Step:  60 | loss:  tensor(0.2728, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.5660000000000001
# Epoch:  28 | Step:  70 | loss:  tensor(0.1232, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.549
# Epoch:  28 | Step:  80 | loss:  tensor(0.3544, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.579
# Epoch:  28 | Step:  90 | loss:  tensor(0.1426, device='cuda:0') | Train_acc:  0.953125 | Eval_acc:  0.587
# Epoch:  29 | Step:  0 | loss:  tensor(0.2636, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.554
# Epoch:  29 | Step:  10 | loss:  tensor(0.3860, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5479999999999999
# Epoch:  29 | Step:  20 | loss:  tensor(0.1160, device='cuda:0') | Train_acc:  0.96875 | Eval_acc:  0.5950000000000001
# Epoch:  29 | Step:  30 | loss:  tensor(0.2799, device='cuda:0') | Train_acc:  0.9375 | Eval_acc:  0.555
# Epoch:  29 | Step:  40 | loss:  tensor(0.3882, device='cuda:0') | Train_acc:  0.84375 | Eval_acc:  0.5720000000000001
# Epoch:  29 | Step:  50 | loss:  tensor(0.3988, device='cuda:0') | Train_acc:  0.90625 | Eval_acc:  0.553
# Epoch:  29 | Step:  60 | loss:  tensor(0.3356, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.532
# Epoch:  29 | Step:  70 | loss:  tensor(0.2876, device='cuda:0') | Train_acc:  0.890625 | Eval_acc:  0.576
# Epoch:  29 | Step:  80 | loss:  tensor(0.2724, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.5519999999999999
# Epoch:  29 | Step:  90 | loss:  tensor(0.3339, device='cuda:0') | Train_acc:  0.921875 | Eval_acc:  0.581

# %%
x=np.arange(len(losses))*10
plt.plot(x,losses)
plt.title('CNN6 TRY 1')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN6 TRY 1')
plt.xlabel('Step')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

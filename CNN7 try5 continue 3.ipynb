# %% [markdown]
# CNN 7 0.75 + Random Rotation  (CNN7 100E+30E+30E+50E)

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import matplotlib.pyplot as plt
import os
from PIL import Image, ImageChops
import numpy as np
import pandas as pd
import torchvision
import warnings
import copy
warnings.filterwarnings("ignore")

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     torch.backends.cudnn.deterministic = True
# 设置随机数种子
setup_seed(20)

# %%
class CNN7(nn.Module):
    def __init__(self):
        super(CNN7,self).__init__()
        
        self.conv1=nn.Sequential(
            nn.Conv2d(3,32,3,1,1,bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(), 
            nn.Conv2d(32,32,3,1,1,bias=False),               
            nn.BatchNorm2d(32),
            nn.ReLU(), 
            nn.Conv2d(32,32,3,1,1,bias=False),               
            nn.BatchNorm2d(32),
            nn.ReLU(), 
            nn.MaxPool2d(2)
        )
        
        self.conv2=nn.Sequential(
            nn.Conv2d(32,64,3,1,1,bias=False),            
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),               
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,1,1,bias=False),               
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        
        self.conv3=nn.Sequential(
            nn.Conv2d(64,128,3,1,1,bias=False),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        
        self.conv4=nn.Sequential(
            nn.Conv2d(128,256,3,1,1,bias=False),            
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv5=nn.Sequential(
            nn.Conv2d(256,256,3,1,1,bias=False),            
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv6=nn.Sequential(
            nn.Conv2d(256,128,3,1,1),            
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )        


        self.dense1=nn.Sequential(
            nn.Linear(4*4*128,2048,bias=True),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense2=nn.Sequential(
            nn.Linear(2048,1024,bias=True),
            nn.Dropout(0.5),
            nn.ReLU()
        )
        
        self.dense3=nn.Sequential(
            nn.Linear(1024,512,bias=True),
            nn.Dropout(0.5),
            nn.ReLU()
        )
       
        self.out=nn.Linear(512,101)
        
        

        
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        x=self.conv3(x)
        x=self.conv4(x)
        x=self.conv5(x)
        x=self.conv6(x)
        x=x.view(x.size(0),-1)
        x=self.dense1(x)
        x=self.dense2(x)
        x=self.dense3(x)
        output=self.out(x)
        return output       
cnn7=CNN7().cuda()

cnn7.load_state_dict(torch.load('/kaggle/input/cnn7-5-weight/CNN7 continue2 best.pkl'))

print(cnn7)
# Out:
# CNN7(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense1): Sequential(
#     (0): Linear(in_features=2048, out_features=2048, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense2): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (dense3): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#   )
#   (out): Linear(in_features=512, out_features=101, bias=True)
# )

# %%
EPOCH = 60
BATCH_SIZE=64
LR=2e-4
optimizer=torch.optim.Adam(cnn7.parameters(),lr=LR,weight_decay=0.001)
scheduler=torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5, 
    verbose=True, threshold=0.0001, threshold_mode='rel', cooldown=2, min_lr=1e-08, eps=1e-08)
loss_func=nn.CrossEntropyLoss()

# %%
train_data = torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/train',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),
            torchvision.transforms.RandomCrop(256,padding=32),
            torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.RandomRotation(25),
            torchvision.transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5),
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

eval_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/eval',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

test_data=torchvision.datasets.ImageFolder('/kaggle/input/caltech101/Caltech101/test',transform=torchvision.transforms.Compose([
            torchvision.transforms.Resize((256,256)),torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ]))

train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=200,
                             shuffle=False, num_workers=2)
test_loader=Data.DataLoader(dataset=test_data,batch_size=200,
                             shuffle=False, num_workers=2)

# %%
losses=[]
train_accs=[]
eval_accs=[]
best_model_wts = copy.deepcopy(cnn7.state_dict())         #change
best_acc = 0.0


for epoch in range(EPOCH):
    print('Step:')
    cnn7.train()   #change
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=cnn7(b_x)   #change
        loss=loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()    
        
        if step%30==0:
            print(step)
           

    losses.append(loss.data)
    with torch.no_grad():
        cnn7.eval()   #change
        
        train_acc=[]
        for x,y in train_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn7(b_x)   #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0) 
            train_acc.append(accuracy)
            torch.cuda.empty_cache()
        train_acc=sum(train_acc)/len(train_acc)
        train_accs.append(train_acc)
        
        eval_acc=[]
        for x,y in eval_loader:
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()        
            output=cnn7(b_x)         #change
            pred_y=torch.max(output,1)[1].cuda().data.squeeze()
            accuracy=sum(pred_y==b_y).double()/b_y.size(0)
            eval_acc.append(accuracy)
            torch.cuda.empty_cache()
        eval_acc=sum(eval_acc)/len(eval_acc)
        eval_accs.append(eval_acc)
        
        
        if eval_acc>best_acc:
            best_acc = eval_acc
            best_model_wts = copy.deepcopy(cnn7.state_dict())         #change
            
    scheduler.step(train_acc) 
    
    print('Epoch: %4s'%epoch,'| loss: ',loss.data,
            '| Train_acc: %6s'% train_acc.data,'| Eval_acc: %6s'%eval_acc.data) 
print('Best Eval acc: %6s'%best_acc)
# Out:
# Step:
# 0
# 30
# 60
# 90
# Epoch:    0 | loss:  tensor(0.8133, device='cuda:0') | Train_acc: tensor(0.7096, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6970, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    1 | loss:  tensor(1.0035, device='cuda:0') | Train_acc: tensor(0.7285, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7040, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    2 | loss:  tensor(1.4787, device='cuda:0') | Train_acc: tensor(0.7462, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.6940, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    3 | loss:  tensor(1.4875, device='cuda:0') | Train_acc: tensor(0.7464, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7030, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    4 | loss:  tensor(0.6214, device='cuda:0') | Train_acc: tensor(0.7590, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7190, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    5 | loss:  tensor(1.5312, device='cuda:0') | Train_acc: tensor(0.7511, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7320, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    6 | loss:  tensor(1.1176, device='cuda:0') | Train_acc: tensor(0.7594, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7180, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    7 | loss:  tensor(1.1561, device='cuda:0') | Train_acc: tensor(0.7289, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7160, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    8 | loss:  tensor(1.5891, device='cuda:0') | Train_acc: tensor(0.7637, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7270, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:    9 | loss:  tensor(1.1263, device='cuda:0') | Train_acc: tensor(0.7430, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7220, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   10 | loss:  tensor(1.5790, device='cuda:0') | Train_acc: tensor(0.7638, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7010, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   11 | loss:  tensor(0.8018, device='cuda:0') | Train_acc: tensor(0.7850, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7490, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   12 | loss:  tensor(1.6799, device='cuda:0') | Train_acc: tensor(0.7786, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7340, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   13 | loss:  tensor(1.4540, device='cuda:0') | Train_acc: tensor(0.7737, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7070, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   14 | loss:  tensor(1.5913, device='cuda:0') | Train_acc: tensor(0.7682, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7320, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   15 | loss:  tensor(0.9599, device='cuda:0') | Train_acc: tensor(0.7889, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7380, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   16 | loss:  tensor(0.8426, device='cuda:0') | Train_acc: tensor(0.7696, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7060, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   17 | loss:  tensor(0.8034, device='cuda:0') | Train_acc: tensor(0.7956, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7220, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   18 | loss:  tensor(0.7268, device='cuda:0') | Train_acc: tensor(0.7923, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7370, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   19 | loss:  tensor(0.9107, device='cuda:0') | Train_acc: tensor(0.7920, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7370, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   20 | loss:  tensor(0.9641, device='cuda:0') | Train_acc: tensor(0.7928, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7360, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   21 | loss:  tensor(1.4127, device='cuda:0') | Train_acc: tensor(0.8035, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7310, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   22 | loss:  tensor(1.0538, device='cuda:0') | Train_acc: tensor(0.7906, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7170, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   23 | loss:  tensor(0.7506, device='cuda:0') | Train_acc: tensor(0.7957, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7360, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   24 | loss:  tensor(0.6964, device='cuda:0') | Train_acc: tensor(0.8085, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7450, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   25 | loss:  tensor(0.6328, device='cuda:0') | Train_acc: tensor(0.7889, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7320, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   26 | loss:  tensor(0.3910, device='cuda:0') | Train_acc: tensor(0.7884, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7290, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   27 | loss:  tensor(1.0125, device='cuda:0') | Train_acc: tensor(0.8029, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7380, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   28 | loss:  tensor(0.5843, device='cuda:0') | Train_acc: tensor(0.7968, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7360, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   29 | loss:  tensor(0.7803, device='cuda:0') | Train_acc: tensor(0.7856, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7200, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch    31: reducing learning rate of group 0 to 1.0000e-04.
# Epoch:   30 | loss:  tensor(1.1300, device='cuda:0') | Train_acc: tensor(0.7852, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7320, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   31 | loss:  tensor(1.3599, device='cuda:0') | Train_acc: tensor(0.8270, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7480, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   32 | loss:  tensor(0.9957, device='cuda:0') | Train_acc: tensor(0.8205, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7460, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   33 | loss:  tensor(0.9058, device='cuda:0') | Train_acc: tensor(0.8338, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7620, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   34 | loss:  tensor(0.8732, device='cuda:0') | Train_acc: tensor(0.8291, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7550, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   35 | loss:  tensor(1.2069, device='cuda:0') | Train_acc: tensor(0.8403, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7540, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   36 | loss:  tensor(0.7709, device='cuda:0') | Train_acc: tensor(0.8342, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7630, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   37 | loss:  tensor(1.1602, device='cuda:0') | Train_acc: tensor(0.8404, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7570, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   38 | loss:  tensor(0.8231, device='cuda:0') | Train_acc: tensor(0.8368, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7390, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   39 | loss:  tensor(1.3243, device='cuda:0') | Train_acc: tensor(0.8283, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7530, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   40 | loss:  tensor(1.0796, device='cuda:0') | Train_acc: tensor(0.8333, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7400, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   41 | loss:  tensor(0.5428, device='cuda:0') | Train_acc: tensor(0.8374, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7530, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   42 | loss:  tensor(0.5193, device='cuda:0') | Train_acc: tensor(0.8430, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7590, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   43 | loss:  tensor(0.9714, device='cuda:0') | Train_acc: tensor(0.8379, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7640, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   44 | loss:  tensor(0.3855, device='cuda:0') | Train_acc: tensor(0.8418, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7600, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   45 | loss:  tensor(0.7509, device='cuda:0') | Train_acc: tensor(0.8451, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7510, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   46 | loss:  tensor(0.7764, device='cuda:0') | Train_acc: tensor(0.8403, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7520, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   47 | loss:  tensor(1.1651, device='cuda:0') | Train_acc: tensor(0.8370, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7520, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   48 | loss:  tensor(1.1283, device='cuda:0') | Train_acc: tensor(0.8525, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7530, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   49 | loss:  tensor(0.3573, device='cuda:0') | Train_acc: tensor(0.8475, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7540, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   50 | loss:  tensor(0.3077, device='cuda:0') | Train_acc: tensor(0.8439, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7480, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   51 | loss:  tensor(0.3896, device='cuda:0') | Train_acc: tensor(0.8489, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7540, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   52 | loss:  tensor(0.9173, device='cuda:0') | Train_acc: tensor(0.8503, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7670, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   53 | loss:  tensor(0.5995, device='cuda:0') | Train_acc: tensor(0.8468, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7760, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   54 | loss:  tensor(1.0527, device='cuda:0') | Train_acc: tensor(0.8555, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7670, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   55 | loss:  tensor(0.9965, device='cuda:0') | Train_acc: tensor(0.8520, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7710, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   56 | loss:  tensor(0.5887, device='cuda:0') | Train_acc: tensor(0.8577, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7370, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   57 | loss:  tensor(0.7036, device='cuda:0') | Train_acc: tensor(0.8550, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7610, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   58 | loss:  tensor(0.9043, device='cuda:0') | Train_acc: tensor(0.8452, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7530, device='cuda:0', dtype=torch.float64)
# Step:
# 0
# 30
# 60
# 90
# Epoch:   59 | loss:  tensor(0.6346, device='cuda:0') | Train_acc: tensor(0.8554, device='cuda:0', dtype=torch.float64) | Eval_acc: tensor(0.7630, device='cuda:0', dtype=torch.float64)
# Best Eval acc: tensor(0.7760, device='cuda:0', dtype=torch.float64)

# %%
x=np.arange(len(losses))
plt.plot(x,losses)
plt.title('CNN7 Continue 3')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(x,eval_accs,label='eval')
plt.plot(x,train_accs,label='train')
plt.title('CNN7 Continue 3')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
torch.save(best_model_wts,'CNN7 continue3 best.pkl')

# %%
test_acc=[]
with torch.no_grad():
    cnn7.eval()
    for x,y in test_loader:
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()        
        output=cnn7(b_x)
        pred_y=torch.max(output,1)[1].cuda().data.squeeze()
        accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
        test_acc.append(accuracy)
test_acc
# Out:
# [0.985, 0.98, 0.805, 0.695, 0.595, 0.725, 0.66, 0.715, 0.7052631578947368]

# %%
np.mean(test_acc)
# Out:
# 0.7628070175438597

# %%
eval_acc=[]
with torch.no_grad():
    cnn7.eval()
    for x,y in eval_loader:
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()        
        output=cnn7(b_x)
        pred_y=torch.max(output,1)[1].cuda().data.squeeze()
        accuracy=sum(pred_y==b_y).cpu().numpy()/b_y.size(0)
        eval_acc.append(accuracy)
eval_acc
# Out:
# [0.99, 0.81, 0.635, 0.68, 0.7]

# %%
np.mean(eval_acc)
# Out:
# 0.7630000000000001

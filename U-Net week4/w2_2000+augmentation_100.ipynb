# %%
from numpy.random import normal
from math import sqrt
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch
import torchvision.transforms as transforms
import os
from torch.autograd import Variable
import torch.utils.data as Data
from torch.utils.data import Dataset
from PIL import Image, ImageChops
import matplotlib.pyplot as plt
import torchvision
import warnings
torch.set_default_tensor_type(torch.FloatTensor)
import copy
warnings.filterwarnings("ignore")

# %%
def make_txt_file(path):
    
    # Classes: train, eval, test
    img_path=os.path.join(path,'TrainVal_images')
    label_path=os.path.join(path,'TrainVal_parsing_annotations')
    train_data=open('train.txt', 'w')
    eval_data=open('eval.txt','w')
    test_data=open('test.txt','w')
    train_data.truncate()
    eval_data.truncate()
    test_data.truncate()
    train_id=open(os.path.join(path,'train_id.txt'))
    val_id=open(os.path.join(path,'val_id.txt'))
    
    train_data_path=os.path.join(img_path,'train_images')
    val_data_path=os.path.join(img_path,'val_images')
    train_label_path=os.path.join(label_path,'train_segmentations')
    val_label_path=os.path.join(label_path,'val_segmentations')
    
    lines=train_id.readlines()
    count=0
    for line in lines:
        if count>=3000:
            line=line.strip()
            name=os.path.join(train_data_path,line+'.jpg')+'*'+os.path.join(train_label_path,line+'.png')+'\n'
            train_data.write(name)
        count+=1
        if count>=5000:
            break
    train_data.close()
    train_id.close()
    
    lines=val_id.readlines()
    s=0
    count=0
    for line in lines:
        line=line.strip()
        name=os.path.join(val_data_path,line+'.jpg')+'*'+os.path.join(val_label_path,line+'.png')+'\n'
        if s%2==0:
            eval_data.write(name)
        else:
            test_data.write(name)
        s+=1
        
#         count+=1
#         if count>=3000:
#             break
            
    val_id.close() 
    eval_data.close()
    test_data.close()

# %%
class MyDataSet(Dataset):
    def __init__(self, dataset_type, transform=None,update_dataset=False):
        """
        dataset_type: [train, eval, test]
        """
 
        dataset_path = '/kaggle/input/pil-data/LIP'
        read_path=''
 
        if update_dataset:
            make_txt_file(dataset_path) 
 
        self.transform = transform
        self.sample_list = list()
        self.dataset_type = dataset_type
        f = open(os.path.join(read_path , self.dataset_type + '.txt'))
        lines = f.readlines()
        for line in lines:
            self.sample_list.append(line.strip())
        f.close()
 
    def __getitem__(self, index):
        item = self.sample_list[index]
        img = Image.open(item.split('*')[0]).convert('RGB')       
        label = Image.open(item.split('*')[1]).convert('L')
        
        if self.transform is not None:
            img,label = self.transform(img,label)
           
        return img, label
 
    def __len__(self):
        return len(self.sample_list)

# %%
def train_transform(data,label):
    data=transforms.functional.resize(data,(256,256))
    label=transforms.functional.resize(label,(256,256))  
    if np.random.rand()>0.2:
        data=transforms.ColorJitter(brightness=0.1, contrast=0.1, hue=0.1)(data)
    if np.random.rand()>0.5:
        data=transforms.functional.hflip(data)
        label=transforms.functional.hflip(label)
    if np.random.rand()>0.8:
        data=transforms.functional.vflip(data)
        label=transforms.functional.vflip(label)
        
    angle = transforms.RandomRotation.get_params([-25, 25]) 
    data=transforms.functional.rotate(data,angle)
    label=transforms.functional.rotate(label,angle)
    

    data=transforms.functional.to_tensor(data).float()
    
    label=np.array(label)
    label=(label>=1).astype(int) 
    label=transforms.functional.to_tensor(label).float()
    return data,label

def test_transfrom(data,label):
    data=transforms.functional.resize(data,(256,256))
    label=transforms.functional.resize(label,(256,256))
    data=transforms.functional.to_tensor(data).float()

    label=np.array(label)
    label=(label>=1).astype(int)  
    label=transforms.functional.to_tensor(label).float()
    return data,label

# %%
train_data=MyDataSet('train',transform=train_transform,update_dataset=True)
eval_data=MyDataSet('eval',test_transfrom)

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3,padding=1),
            nn.BatchNorm2d(out_ch), 
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3,padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )
 
    def forward(self, input):        
        return self.conv(input)

# %%
class UNet(nn.Module):
    def __init__(self,colordim =1):
        super(UNet, self).__init__()
        self.conv1=DoubleConv(3,64)
        self.conv2=DoubleConv(64,128)
        self.conv3=DoubleConv(128,256)
        self.conv4=DoubleConv(256,512)
        
        self.conv5=DoubleConv(512,1024)
        self.upconv5=nn.Conv2d(1024, 512, 1)
        
        self.conv6=DoubleConv(1024,512)
        self.upconv6=nn.Conv2d(512, 256, 1)
        self.conv7=DoubleConv(512,256)
        self.upconv7=nn.Conv2d(256,128, 1)
        self.conv8=DoubleConv(256,128)
        self.upconv8=nn.Conv2d(128,64, 1)
        self.conv9=DoubleConv(128,64)
        
        self.maxpool=nn.MaxPool2d(2, stride=2)
        self.upsample = nn.UpsamplingBilinear2d(scale_factor=2)

        self.output=nn.Sequential(
            nn.Conv2d(64, colordim, 1),
            nn.Sigmoid()
        )
        self._initialize_weights()
    
    def forward(self, x):
        x1=self.conv1(x)
        x2=self.conv2(self.maxpool(x1))
        x3=self.conv3(self.maxpool(x2))
        x4=self.conv4(self.maxpool(x3))
        upx=self.conv5(self.maxpool(x4))
        
        upx=self.upconv5(self.upsample(upx))     

        upx=self.conv6(torch.cat((x4, upx), 1))
        upx=self.upconv6(self.upsample(upx))   

        upx=self.conv7(torch.cat((x3, upx), 1))
        upx=self.upconv7(self.upsample(upx))  

        upx=self.conv8(torch.cat((x2, upx), 1))
        upx=self.upconv8(self.upsample(upx)) 

        upx=self.conv9(torch.cat((x1, upx), 1))
        upx=self.output(upx)
        
        return upx
        
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
unet = UNet().cuda()
unet.load_state_dict(torch.load('../input/unet-weight/U_10000_30.pkl'))
# Out:
# <All keys matched successfully>

# %%
EPOCH = 100
BATCH_SIZE=32
LR=0.001

optimizer=torch.optim.Adam(unet.parameters(),lr=LR)
scheduler=torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, 
    verbose=True, threshold=0.0001, threshold_mode='rel', cooldown=2, min_lr=1e-08, eps=1e-08)

loss_func=nn.MSELoss()


train_loader=Data.DataLoader(dataset=train_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)
eval_loader=Data.DataLoader(dataset=eval_data,batch_size=BATCH_SIZE,
                             shuffle=True, num_workers=2)

# %%
train_losses=[]
eval_losses=[]



for epoch in range(EPOCH):
    print('Epoch: %4s'%epoch)
    

    batch_loss=0
    unet.train()  
    
    for step,(x,y) in enumerate(train_loader):
        b_x=Variable(x).cuda()
        b_y=Variable(y).cuda()
        
        output=unet(b_x)   
        loss=loss_func(output,b_y)
        batch_loss+=loss.data
        optimizer.zero_grad()
        loss.backward()
        optimizer.step() 
        torch.cuda.empty_cache() 

    train_loss=batch_loss/(step+b_y.size(0)/BATCH_SIZE)
    train_losses.append(train_loss)
    scheduler.step(train_loss) 
    
    print('| train loss: ',train_loss)
    
    
    
    with torch.no_grad():
        unet.eval()         

        batch_loss=0
        for step,(x,y) in enumerate(eval_loader):
            b_x=Variable(x).cuda()
            b_y=Variable(y).cuda()    
            output=unet(b_x)  
            batch_loss+=loss_func(output,b_y).data            
            torch.cuda.empty_cache()            

        eval_loss=batch_loss/(step+b_y.size(0)/BATCH_SIZE)
        eval_losses.append(eval_loss)

    
    print('| eval loss: ',eval_loss)
# Out:
# Epoch:    0
# | train loss:  tensor(0.1379, device='cuda:0')
# | eval loss:  tensor(0.0995, device='cuda:0')
# Epoch:    1
# | train loss:  tensor(0.1253, device='cuda:0')
# | eval loss:  tensor(0.0967, device='cuda:0')
# Epoch:    2
# | train loss:  tensor(0.1203, device='cuda:0')
# | eval loss:  tensor(0.0987, device='cuda:0')
# Epoch:    3
# | train loss:  tensor(0.1162, device='cuda:0')
# | eval loss:  tensor(0.0975, device='cuda:0')
# Epoch:    4
# | train loss:  tensor(0.1110, device='cuda:0')
# | eval loss:  tensor(0.0981, device='cuda:0')
# Epoch:    5
# | train loss:  tensor(0.1070, device='cuda:0')
# | eval loss:  tensor(0.0964, device='cuda:0')
# Epoch:    6
# | train loss:  tensor(0.1075, device='cuda:0')
# | eval loss:  tensor(0.1032, device='cuda:0')
# Epoch:    7
# | train loss:  tensor(0.1042, device='cuda:0')
# | eval loss:  tensor(0.0973, device='cuda:0')
# Epoch:    8
# | train loss:  tensor(0.1013, device='cuda:0')
# | eval loss:  tensor(0.0978, device='cuda:0')
# Epoch:    9
# | train loss:  tensor(0.0993, device='cuda:0')
# | eval loss:  tensor(0.1026, device='cuda:0')
# Epoch:   10
# | train loss:  tensor(0.0970, device='cuda:0')
# | eval loss:  tensor(0.1135, device='cuda:0')
# Epoch:   11
# | train loss:  tensor(0.0937, device='cuda:0')
# | eval loss:  tensor(0.0990, device='cuda:0')
# Epoch:   12
# | train loss:  tensor(0.0932, device='cuda:0')
# | eval loss:  tensor(0.1008, device='cuda:0')
# Epoch:   13
# | train loss:  tensor(0.0885, device='cuda:0')
# | eval loss:  tensor(0.1014, device='cuda:0')
# Epoch:   14
# | train loss:  tensor(0.0867, device='cuda:0')
# | eval loss:  tensor(0.0994, device='cuda:0')
# Epoch:   15
# | train loss:  tensor(0.0838, device='cuda:0')
# | eval loss:  tensor(0.1029, device='cuda:0')
# Epoch:   16
# | train loss:  tensor(0.0834, device='cuda:0')
# | eval loss:  tensor(0.1011, device='cuda:0')
# Epoch:   17
# | train loss:  tensor(0.0810, device='cuda:0')
# | eval loss:  tensor(0.1033, device='cuda:0')
# Epoch:   18
# | train loss:  tensor(0.0796, device='cuda:0')
# | eval loss:  tensor(0.1052, device='cuda:0')
# Epoch:   19
# | train loss:  tensor(0.0785, device='cuda:0')
# | eval loss:  tensor(0.1036, device='cuda:0')
# Epoch:   20
# | train loss:  tensor(0.0761, device='cuda:0')
# | eval loss:  tensor(0.1027, device='cuda:0')
# Epoch:   21
# | train loss:  tensor(0.0753, device='cuda:0')
# | eval loss:  tensor(0.1022, device='cuda:0')
# Epoch:   22
# | train loss:  tensor(0.0732, device='cuda:0')
# | eval loss:  tensor(0.1014, device='cuda:0')
# Epoch:   23
# | train loss:  tensor(0.0725, device='cuda:0')
# | eval loss:  tensor(0.1053, device='cuda:0')
# Epoch:   24
# | train loss:  tensor(0.0698, device='cuda:0')
# | eval loss:  tensor(0.1047, device='cuda:0')
# Epoch:   25
# | train loss:  tensor(0.0695, device='cuda:0')
# | eval loss:  tensor(0.1033, device='cuda:0')
# Epoch:   26
# | train loss:  tensor(0.0680, device='cuda:0')
# | eval loss:  tensor(0.1032, device='cuda:0')
# Epoch:   27
# | train loss:  tensor(0.0668, device='cuda:0')
# | eval loss:  tensor(0.1030, device='cuda:0')
# Epoch:   28
# | train loss:  tensor(0.0667, device='cuda:0')
# | eval loss:  tensor(0.1097, device='cuda:0')
# Epoch:   29
# | train loss:  tensor(0.0641, device='cuda:0')
# | eval loss:  tensor(0.1025, device='cuda:0')
# Epoch:   30
# | train loss:  tensor(0.0638, device='cuda:0')
# | eval loss:  tensor(0.1044, device='cuda:0')
# Epoch:   31
# | train loss:  tensor(0.0636, device='cuda:0')
# | eval loss:  tensor(0.1081, device='cuda:0')
# Epoch:   32
# | train loss:  tensor(0.0625, device='cuda:0')
# | eval loss:  tensor(0.1062, device='cuda:0')
# Epoch:   33
# | train loss:  tensor(0.0606, device='cuda:0')
# | eval loss:  tensor(0.1051, device='cuda:0')
# Epoch:   34
# | train loss:  tensor(0.0591, device='cuda:0')
# | eval loss:  tensor(0.1088, device='cuda:0')
# Epoch:   35
# | train loss:  tensor(0.0588, device='cuda:0')
# | eval loss:  tensor(0.1060, device='cuda:0')
# Epoch:   36
# | train loss:  tensor(0.0585, device='cuda:0')
# | eval loss:  tensor(0.1059, device='cuda:0')
# Epoch:   37
# | train loss:  tensor(0.0595, device='cuda:0')
# | eval loss:  tensor(0.1089, device='cuda:0')
# Epoch:   38
# | train loss:  tensor(0.0559, device='cuda:0')
# | eval loss:  tensor(0.1144, device='cuda:0')
# Epoch:   39
# | train loss:  tensor(0.0564, device='cuda:0')
# | eval loss:  tensor(0.1090, device='cuda:0')
# Epoch:   40
# | train loss:  tensor(0.0561, device='cuda:0')
# | eval loss:  tensor(0.1087, device='cuda:0')
# Epoch:   41
# | train loss:  tensor(0.0559, device='cuda:0')
# | eval loss:  tensor(0.1068, device='cuda:0')
# Epoch:   42
# | train loss:  tensor(0.0527, device='cuda:0')
# | eval loss:  tensor(0.1077, device='cuda:0')
# Epoch:   43
# | train loss:  tensor(0.0535, device='cuda:0')
# | eval loss:  tensor(0.1088, device='cuda:0')
# Epoch:   44
# | train loss:  tensor(0.0508, device='cuda:0')
# | eval loss:  tensor(0.1075, device='cuda:0')
# Epoch:   45
# | train loss:  tensor(0.0516, device='cuda:0')
# | eval loss:  tensor(0.1093, device='cuda:0')
# Epoch:   46
# | train loss:  tensor(0.0516, device='cuda:0')
# | eval loss:  tensor(0.1093, device='cuda:0')
# Epoch:   47
# | train loss:  tensor(0.0493, device='cuda:0')
# | eval loss:  tensor(0.1084, device='cuda:0')
# Epoch:   48
# | train loss:  tensor(0.0507, device='cuda:0')
# | eval loss:  tensor(0.1126, device='cuda:0')
# Epoch:   49
# | train loss:  tensor(0.0494, device='cuda:0')
# | eval loss:  tensor(0.1096, device='cuda:0')
# Epoch:   50
# | train loss:  tensor(0.0472, device='cuda:0')
# | eval loss:  tensor(0.1109, device='cuda:0')
# Epoch:   51
# | train loss:  tensor(0.0476, device='cuda:0')
# | eval loss:  tensor(0.1077, device='cuda:0')
# Epoch:   52
# | train loss:  tensor(0.0482, device='cuda:0')
# | eval loss:  tensor(0.1084, device='cuda:0')
# Epoch:   53
# | train loss:  tensor(0.0475, device='cuda:0')
# | eval loss:  tensor(0.1105, device='cuda:0')
# Epoch:   54
# | train loss:  tensor(0.0479, device='cuda:0')
# | eval loss:  tensor(0.1101, device='cuda:0')
# Epoch:   55
# | train loss:  tensor(0.0465, device='cuda:0')
# | eval loss:  tensor(0.1091, device='cuda:0')
# Epoch:   56
# | train loss:  tensor(0.0465, device='cuda:0')
# | eval loss:  tensor(0.1113, device='cuda:0')
# Epoch:   57
# | train loss:  tensor(0.0454, device='cuda:0')
# | eval loss:  tensor(0.1090, device='cuda:0')
# Epoch:   58
# | train loss:  tensor(0.0456, device='cuda:0')
# | eval loss:  tensor(0.1087, device='cuda:0')
# Epoch:   59
# | train loss:  tensor(0.0473, device='cuda:0')
# | eval loss:  tensor(0.1101, device='cuda:0')
# Epoch:   60
# | train loss:  tensor(0.0459, device='cuda:0')
# | eval loss:  tensor(0.1066, device='cuda:0')
# Epoch:   61
# | train loss:  tensor(0.0445, device='cuda:0')
# | eval loss:  tensor(0.1126, device='cuda:0')
# Epoch:   62
# | train loss:  tensor(0.0449, device='cuda:0')
# | eval loss:  tensor(0.1147, device='cuda:0')
# Epoch:   63
# | train loss:  tensor(0.0438, device='cuda:0')
# | eval loss:  tensor(0.1072, device='cuda:0')
# Epoch:   64
# | train loss:  tensor(0.0425, device='cuda:0')
# | eval loss:  tensor(0.1153, device='cuda:0')
# Epoch:   65
# | train loss:  tensor(0.0423, device='cuda:0')
# | eval loss:  tensor(0.1132, device='cuda:0')
# Epoch:   66
# | train loss:  tensor(0.0429, device='cuda:0')
# | eval loss:  tensor(0.1145, device='cuda:0')
# Epoch:   67
# | train loss:  tensor(0.0426, device='cuda:0')
# | eval loss:  tensor(0.1122, device='cuda:0')
# Epoch:   68
# | train loss:  tensor(0.0428, device='cuda:0')
# | eval loss:  tensor(0.1133, device='cuda:0')
# Epoch:   69
# | train loss:  tensor(0.0416, device='cuda:0')
# | eval loss:  tensor(0.1100, device='cuda:0')
# Epoch:   70
# | train loss:  tensor(0.0405, device='cuda:0')
# | eval loss:  tensor(0.1116, device='cuda:0')
# Epoch:   71
# | train loss:  tensor(0.0397, device='cuda:0')
# | eval loss:  tensor(0.1153, device='cuda:0')
# Epoch:   72
# | train loss:  tensor(0.0406, device='cuda:0')
# | eval loss:  tensor(0.1140, device='cuda:0')
# Epoch:   73
# | train loss:  tensor(0.0410, device='cuda:0')
# | eval loss:  tensor(0.1098, device='cuda:0')
# Epoch:   74
# | train loss:  tensor(0.0413, device='cuda:0')
# | eval loss:  tensor(0.1126, device='cuda:0')
# Epoch:   75
# | train loss:  tensor(0.0408, device='cuda:0')
# | eval loss:  tensor(0.1122, device='cuda:0')
# Epoch:   76
# | train loss:  tensor(0.0401, device='cuda:0')
# | eval loss:  tensor(0.1097, device='cuda:0')
# Epoch:   77
# Epoch    78: reducing learning rate of group 0 to 1.0000e-04.
# | train loss:  tensor(0.0400, device='cuda:0')
# | eval loss:  tensor(0.1095, device='cuda:0')
# Epoch:   78
# | train loss:  tensor(0.0379, device='cuda:0')
# | eval loss:  tensor(0.1078, device='cuda:0')
# Epoch:   79
# | train loss:  tensor(0.0350, device='cuda:0')
# | eval loss:  tensor(0.1083, device='cuda:0')
# Epoch:   80
# | train loss:  tensor(0.0345, device='cuda:0')
# | eval loss:  tensor(0.1090, device='cuda:0')
# Epoch:   81
# | train loss:  tensor(0.0338, device='cuda:0')
# | eval loss:  tensor(0.1083, device='cuda:0')
# Epoch:   82
# | train loss:  tensor(0.0335, device='cuda:0')
# | eval loss:  tensor(0.1089, device='cuda:0')
# Epoch:   83
# | train loss:  tensor(0.0334, device='cuda:0')
# | eval loss:  tensor(0.1095, device='cuda:0')
# Epoch:   84
# | train loss:  tensor(0.0334, device='cuda:0')
# | eval loss:  tensor(0.1088, device='cuda:0')
# Epoch:   85
# | train loss:  tensor(0.0334, device='cuda:0')
# | eval loss:  tensor(0.1089, device='cuda:0')
# Epoch:   86
# | train loss:  tensor(0.0332, device='cuda:0')
# | eval loss:  tensor(0.1088, device='cuda:0')
# Epoch:   87
# | train loss:  tensor(0.0328, device='cuda:0')
# | eval loss:  tensor(0.1089, device='cuda:0')
# Epoch:   88
# | train loss:  tensor(0.0320, device='cuda:0')
# | eval loss:  tensor(0.1088, device='cuda:0')
# Epoch:   89
# | train loss:  tensor(0.0330, device='cuda:0')
# | eval loss:  tensor(0.1085, device='cuda:0')
# Epoch:   90
# | train loss:  tensor(0.0319, device='cuda:0')
# | eval loss:  tensor(0.1094, device='cuda:0')
# Epoch:   91
# | train loss:  tensor(0.0315, device='cuda:0')
# | eval loss:  tensor(0.1094, device='cuda:0')
# Epoch:   92
# | train loss:  tensor(0.0310, device='cuda:0')
# | eval loss:  tensor(0.1096, device='cuda:0')
# Epoch:   93
# | train loss:  tensor(0.0314, device='cuda:0')
# | eval loss:  tensor(0.1099, device='cuda:0')
# Epoch:   94
# | train loss:  tensor(0.0318, device='cuda:0')
# | eval loss:  tensor(0.1088, device='cuda:0')
# Epoch:   95
# | train loss:  tensor(0.0315, device='cuda:0')
# | eval loss:  tensor(0.1090, device='cuda:0')
# Epoch:   96
# | train loss:  tensor(0.0310, device='cuda:0')
# | eval loss:  tensor(0.1095, device='cuda:0')
# Epoch:   97
# | train loss:  tensor(0.0312, device='cuda:0')
# | eval loss:  tensor(0.1103, device='cuda:0')
# Epoch:   98
# | train loss:  tensor(0.0306, device='cuda:0')
# | eval loss:  tensor(0.1100, device='cuda:0')
# Epoch:   99
# | train loss:  tensor(0.0313, device='cuda:0')
# | eval loss:  tensor(0.1097, device='cuda:0')

# %%
x=np.arange(len(train_losses))
plt.plot(x,train_losses,label='train')
plt.plot(x,eval_losses,label='eval')
plt.title('2000 images')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
num_figure=8
imgs=np.arange(num_figure)*10

# %%
plt.figure(figsize=(9,24))
count=1
for i in imgs:
    
    img,label=train_data.__getitem__(i)
    
    plt.subplot(num_figure,3,count)
    plt.imshow(np.transpose(img.numpy(),(1,2,0)))
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    plt.imshow(label.numpy()[0],cmap = plt.get_cmap('gray'))
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    img=torch.unsqueeze(img,dim=0)
    b_x=Variable(img).cuda()
    output=unet(b_x).to(torch.float64)
    plt.imshow(output.cpu().detach().numpy()[0][0],cmap = plt.get_cmap('gray'))
    
    count+=1
plt.title('train')    
plt.show()

# %%
plt.figure(figsize=(9,24))
count=1
for i in imgs:
    
    img,label=eval_data.__getitem__(i)
    
    plt.subplot(num_figure,3,count)
    plt.imshow(np.transpose(img.numpy(),(1,2,0)))
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    plt.imshow(label.numpy()[0],cmap = plt.get_cmap('gray'))
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    img=torch.unsqueeze(img,dim=0)
    b_x=Variable(img).cuda()
    output=unet(b_x).to(torch.float64)
    plt.imshow(output.cpu().detach().numpy()[0][0],cmap = plt.get_cmap('gray'))
    
    count+=1
plt.title('eval')    
plt.show()

# %%
test_data=MyDataSet('test',test_transfrom)
plt.figure(figsize=(9,24))
count=1
for i in imgs:
    
    img,label=test_data.__getitem__(i)
    
    plt.subplot(num_figure,3,count)
    plt.imshow(np.transpose(img.numpy(),(1,2,0)))
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    plt.imshow(label.numpy()[0],cmap = plt.get_cmap('gray'))
    count+=1
    
    
    plt.subplot(num_figure,3,count)
    img=torch.unsqueeze(img,dim=0)
    b_x=Variable(img).cuda()
    output=unet(b_x).to(torch.float64)
    plt.imshow(output.cpu().detach().numpy()[0][0],cmap = plt.get_cmap('gray'))
    
    count+=1
plt.title('test')    
plt.show()

# %%
torch.save(unet.state_dict(),'U_w2_3000_100 2.pkl')
